# %% [markdown]
# ## Analysis of geometric parameters in relaxed structures
#
# This notebook provides the functions to save and plot geometric quantities such bond lengths, angles and dihedrals extracted from PDB files, and RMSD computed with respect to the original structures. With small modifications in the main function, it can be used to analyse the trajectories obtained with all the different parameters.

# %%
import mdtraj as md
import numpy as np
import sys
import pickle
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
from matplotlib.ticker import FormatStrFormatter
from matplotlib import rc
import matplotlib.backends.backend_pdf
from os.path import exists
from os.path import getsize
import math
from cmath import rect, phase
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

plt.style.use('default')
plt.rcParams["font.family"] = "serif"
rc('text.latex', preamble=r'\usepackage{cmbright}')

# %%
# computes bond lengths for a given frame in the trajectory, for all the combinations of particles considered, 
# contained in bdict
def compute_bonds_lengths(P,O,C,R4,R1,C1,U1,A1,G1,bdict,last_frame):

    bdict['P-O'].extend(md.compute_distances(last_frame,np.array([P,O[1:]]).transpose()).reshape(-1,).tolist())
    bdict['O-C'].extend(md.compute_distances(last_frame,np.array([O,C]).transpose()).reshape(-1,).tolist())
    bdict['C-R4'].extend(md.compute_distances(last_frame,np.array([C,R4]).transpose()).reshape(-1,).tolist())
    bdict['R4-P'].extend(md.compute_distances(last_frame,np.array([R4[:-1],P]).transpose()).reshape(-1,).tolist())
    bdict['R4-R1'].extend(md.compute_distances(last_frame,np.array([R4,R1]).transpose()).reshape(-1,).tolist())

    if C1.size > 0:
        bdict['R1-C1'].extend(md.compute_distances(last_frame,np.array([C1-1,C1]).transpose()).reshape(-1,).tolist())
    if U1.size > 0:
        bdict['R1-U1'].extend(md.compute_distances(last_frame,np.array([U1-1,U1]).transpose()).reshape(-1,).tolist())
    if A1.size > 0:
        bdict['R1-A1'].extend(md.compute_distances(last_frame,np.array([A1-1,A1]).transpose()).reshape(-1,).tolist())
        bdict['A1-A2'].extend(md.compute_distances(last_frame,np.array([A1,A1+1]).transpose()).reshape(-1,).tolist())
    if G1.size > 0:
        bdict['R1-G1'].extend(md.compute_distances(last_frame,np.array([G1-1,G1]).transpose()).reshape(-1,).tolist())
        bdict['G1-G2'].extend(md.compute_distances(last_frame,np.array([G1,G1+1]).transpose()).reshape(-1,).tolist())

    return


# computes angles for a given frame in the trajectory, for all the combinations of particles considered, 
# contained in adict
def compute_bonds_angles(P,O,C,R4,R1,C1,U1,A1,G1,adict,last_frame):

    adict['P-O-C'].extend(md.compute_angles(last_frame,np.array([P,O[1:],C[1:]]).transpose()).reshape(-1,).tolist())
    adict['O-C-R4'].extend(md.compute_angles(last_frame,np.array([O,C,R4]).transpose()).reshape(-1,).tolist())
    adict['C-R4-P'].extend(md.compute_angles(last_frame,np.array([C[:-1],R4[:-1],P]).transpose()).reshape(-1,).tolist())
    adict['R4-P-O'].extend(md.compute_angles(last_frame,np.array([R4[:-1],P,O[1:]]).transpose()).reshape(-1,).tolist())
    adict['C-R4-R1'].extend(md.compute_angles(last_frame,np.array([C,R4,R1]).transpose()).reshape(-1,).tolist())
    adict['R1-R4-P'].extend(md.compute_angles(last_frame,np.array([R1[:-1],R4[:-1],P]).transpose()).reshape(-1,).tolist())

    if A1.size > 0:
        adict['R4-R1-A1'].extend(md.compute_angles(last_frame,np.array([A1-2,A1-1,A1]).transpose()).reshape(-1,).tolist())
        adict['R1-A1-A2'].extend(md.compute_angles(last_frame,np.array([A1-1,A1,A1+1]).transpose()).reshape(-1,).tolist())
    if U1.size > 0:
        adict['R4-R1-U1'].extend(md.compute_angles(last_frame,np.array([U1-2,U1-1,U1]).transpose()).reshape(-1,).tolist())
    if G1.size > 0:
        adict['R4-R1-G1'].extend(md.compute_angles(last_frame,np.array([G1-2,G1-1,G1]).transpose()).reshape(-1,).tolist())
        adict['R1-G1-G2'].extend(md.compute_angles(last_frame,np.array([G1-1,G1,G1+1]).transpose()).reshape(-1,).tolist())
    if C1.size > 0:
        adict['R4-R1-C1'].extend(md.compute_angles(last_frame,np.array([C1-2,C1-1,C1]).transpose()).reshape(-1,).tolist())

    return


# computes dihedrals for a given frame in the trajectory, for all the combinations of particles considered, 
# contained in bdict
def compute_dihedrals_angles(P,O,C,R4,R1,C1,U1,A1,G1,ddict,last_frame,top):

    ddict['C-R4-P-O'].extend(md.compute_dihedrals(last_frame,np.array([C[:-1],R4[:-1],P,O[1:]]).transpose()).reshape(-1,).tolist())
    ddict['R1-R4-P-O'].extend(md.compute_dihedrals(last_frame,np.array([R1[:-1],R4[:-1],P,O[1:]]).transpose()).reshape(-1,).tolist())
    ddict['O-C-R4-P'].extend(md.compute_dihedrals(last_frame,np.array([O[:-1],C[:-1],R4[:-1],P]).transpose()).reshape(-1,).tolist())
    ddict['O-C-R4-R1'].extend(md.compute_dihedrals(last_frame,np.array([O,C,R4,R1]).transpose()).reshape(-1,).tolist())
    ddict['P-O-C-R4'].extend(md.compute_dihedrals(last_frame,np.array([P,O[1:],C[1:],R4[1:]]).transpose()).reshape(-1,).tolist())
    ddict['R4-P-O-C'].extend(md.compute_dihedrals(last_frame,np.array([R4[:-1],P,O[1:],C[1:]]).transpose()).reshape(-1,).tolist())

    if A1.size > 0:
        ddict['R4-R1-A1-A2'].extend(md.compute_dihedrals(last_frame,np.array([A1-2,A1-1,A1,A1+1]).transpose()).reshape(-1,).tolist())
        ddict['R4-A1-A2-R1'].extend(md.compute_dihedrals(last_frame,np.array([A1-2,A1,A1+1,A1-1]).transpose()).reshape(-1,).tolist())
        ddict['C-R4-R1-A1'].extend(md.compute_dihedrals(last_frame,np.array([A1-3,A1-2,A1-1,A1]).transpose()).reshape(-1,).tolist())
        if A1[-1]+2 > top.n_atoms:
            ddict['P-R4-R1-A1'].extend(md.compute_dihedrals(last_frame,np.array([A1+2,A1-2,A1-1,A1]).transpose()).reshape(-1,).tolist())  # check it is not the last residue
        else:
            if A1.size > 1:
                ddict['P-R4-R1-A1'].extend(md.compute_dihedrals(last_frame,np.array([A1[:-1]+2,A1[:-1]-2,A1[:-1]-1,A1[:-1]]).transpose()).reshape(-1,).tolist())
    if U1.size > 0:
        ddict['C-R4-R1-U1'].extend(md.compute_dihedrals(last_frame,np.array([U1-3,U1-2,U1-1,U1]).transpose()).reshape(-1,).tolist())
        if U1[-1]+1 > top.n_atoms:
            ddict['P-R4-R1-U1'].extend(md.compute_dihedrals(last_frame,np.array([U1+2,U1-2,U1-1,U1]).transpose()).reshape(-1,).tolist())  # check it is not the last residue
        else:
            if U1.size > 1:
                ddict['P-R4-R1-U1'].extend(md.compute_dihedrals(last_frame,np.array([U1[:-1]+2,U1[:-1]-2,U1[:-1]-1,U1[:-1]]).transpose()).reshape(-1,).tolist())
    if G1.size > 0:
        ddict['R4-R1-G1-G2'].extend(md.compute_dihedrals(last_frame,np.array([G1-2,G1-1,G1,G1+1]).transpose()).reshape(-1,).tolist())
        ddict['R4-G1-G2-R1'].extend(md.compute_dihedrals(last_frame,np.array([G1-2,G1,G1+1,G1-1]).transpose()).reshape(-1,).tolist())
        ddict['C-R4-R1-G1'].extend(md.compute_dihedrals(last_frame,np.array([G1-3,G1-2,G1-1,G1]).transpose()).reshape(-1,).tolist())
        if G1[-1]+2 > top.n_atoms:
            ddict['P-R4-R1-G1'].extend(md.compute_dihedrals(last_frame,np.array([G1+2,G1-2,G1-1,G1]).transpose()).reshape(-1,).tolist())  # check it is not the last residue
        else:
            if G1.size > 1:
                ddict['P-R4-R1-G1'].extend(md.compute_dihedrals(last_frame,np.array([G1[:-1]+2,G1[:-1]-2,G1[:-1]-1,G1[:-1]]).transpose()).reshape(-1,).tolist())
    if C1.size > 0:
        ddict['C-R4-R1-C1'].extend(md.compute_dihedrals(last_frame,np.array([C1-3,C1-2,C1-1,C1]).transpose()).reshape(-1,).tolist())
        if C1[-1]+1 > top.n_atoms:
            ddict['P-R4-R1-C1'].extend(md.compute_dihedrals(last_frame,np.array([C1+2,C1-2,C1-1,C1]).transpose()).reshape(-1,).tolist())  # check it is not the last residue
        else:
            if C1.size > 1:
                ddict['P-R4-R1-C1'].extend(md.compute_dihedrals(last_frame,np.array([C1[:-1]+2,C1[:-1]-2,C1[:-1]-1,C1[:-1]]).transpose()).reshape(-1,).tolist())

    return

# %%
def main():

    # Dictionaries definitions
    bond_pairs = ['R4-P','R4-R1','R1-G1','R1-A1','R1-U1','R1-C1','G1-G2','A1-A2','C-R4','P-O','O-C']
    bdict = {key: [] for key in bond_pairs}

    angle_triplets = ['R4-R1-A1','R4-R1-U1','R4-R1-G1','R4-R1-C1','R1-A1-A2','R1-G1-G2','P-O-C',
    'O-C-R4','C-R4-P','R4-P-O','C-R4-R1','R1-R4-P']
    adict = {key: [] for key in angle_triplets}

    dihedrals_quadruplets = ['R4-R1-G1-G2','R4-R1-A1-A2','R4-A1-A2-R1','R4-G1-G2-R1','C-R4-R1-A1',
    'C-R4-R1-G1','C-R4-R1-C1','C-R4-R1-U1','P-R4-R1-A1','P-R4-R1-G1','P-R4-R1-C1','P-R4-R1-U1',
    'C-R4-P-O','R1-R4-P-O','O-C-R4-P','O-C-R4-R1','P-O-C-R4','R4-P-O-C']
    ddict = {key: [] for key in dihedrals_quadruplets}
    
    rmsd = []

    # Execution
    with open('relaxation_names.txt','r') as f:
        file_list = f.read().splitlines()

    for i,file in enumerate(file_list):
        
        # check if all files exist
        file_amber = file.split('_',maxsplit=1)[1]  
        print(file+",    %i/%i" %(i+1,len(file_list)))
    
        if not exists('Amber/Minimized/'+file_amber+'.pdb'):
            continue

        if not exists('FreeMin/Relaxation/'+file+'.pdb'):   # for relaxation with other parameters, change folder
            continue
        
        # load initial configuration, last configuration and topology (necessary to parse by atom names)
        ref = md.load('Amber/Minimized/'+file_amber+'.pdb')
        last_frame = md.load_frame('FreeMin/Relaxation/'+file+'.pdb',-1)
        top = last_frame.topology
        
        # compute rmsd between last and initial configuration
        rmsd_tmp = md.rmsd(last_frame,ref) 
        rmsd.append(rmsd_tmp)

        P = top.select("name == P")
        if len(P) < 6:
            continue

        O = top.select("symbol == O")  # all sequences start from oxygen, doesn't read name == O5*
        C = O+1                        # doesn't read name == C5* nor symbol == C
        R4 = top.select("name == CA")
        R1 = top.select("name == CY")
        C1 = top.select("name == C1")
        U1 = top.select("name == U1")
        A1 = top.select("name == A1")
        G1 = top.select("name == G1")
        
        # compute bond lengths, angles and dihedrals for 
        compute_bonds_lengths(P,O,C,R4,R1,C1,U1,A1,G1,bdict,last_frame)
        compute_bonds_angles(P,O,C,R4,R1,C1,U1,A1,G1,adict,last_frame)
        compute_dihedrals_angles(P,O,C,R4,R1,C1,U1,A1,G1,ddict,last_frame,top)
    
    # save dictionaries for geometrical quantities and rmsd in correct folder
    with open('FreeMin/bonds.pkl', 'wb') as f: pickle.dump(bdict, f)
    with open('FreeMin/angles.pkl', 'wb') as f: pickle.dump(adict, f)
    with open('FreeMin/dihedrals.pkl', 'wb') as f: pickle.dump(ddict, f)
        
    rmsd = np.array(rmsd)
    np.save('FreeMin/rmsd.npy',rmsd)

    return bdict, adict, ddict

# %%
main()
# Out:
# relaxation_1ato_c1,    1/1225
# relaxation_1ato_c2,    2/1225
# relaxation_1ato_c3,    3/1225
# relaxation_1ato_c4,    4/1225
# relaxation_1ato_c5,    5/1225
# relaxation_1ato_c6,    6/1225
# relaxation_1atv_c1,    7/1225
# relaxation_1atv_c2,    8/1225
# relaxation_1atv_c3,    9/1225
# relaxation_1atv_c4,    10/1225
# relaxation_1atv_c5,    11/1225
# relaxation_1atw_c1,    12/1225
# relaxation_1atw_c2,    13/1225
# relaxation_1atw_c3,    14/1225
# relaxation_1atw_c4,    15/1225
# relaxation_1atw_c5,    16/1225
# relaxation_1b36_c10,    17/1225
# relaxation_1b36_c11,    18/1225
# relaxation_1b36_c12,    19/1225
# relaxation_1b36_c1,    20/1225
# relaxation_1b36_c2,    21/1225
# relaxation_1b36_c3,    22/1225
# relaxation_1b36_c4,    23/1225
# relaxation_1b36_c5,    24/1225
# relaxation_1b36_c6,    25/1225
# relaxation_1b36_c7,    26/1225
# relaxation_1b36_c8,    27/1225
# relaxation_1b36_c9,    28/1225
# relaxation_1bgz_c1,    29/1225
# relaxation_1bgz_c2,    30/1225
# relaxation_1bgz_c3,    31/1225
# relaxation_1bgz_c4,    32/1225
# relaxation_1bgz_c5,    33/1225
# relaxation_1bgz_c6,    34/1225
# relaxation_1bgz_c7,    35/1225
# relaxation_1bn0_c1,    36/1225
# relaxation_1bn0_c2,    37/1225
# relaxation_1bn0_c3,    38/1225
# relaxation_1bn0_c4,    39/1225
# relaxation_1bn0_c5,    40/1225
# relaxation_1bn0_c6,    41/1225
# relaxation_1byj_c1,    42/1225
# relaxation_1byj_c2,    43/1225
# relaxation_1byj_c3,    44/1225
# relaxation_1byj_c4,    45/1225
# relaxation_1byj_c5,    46/1225
# relaxation_1byj_c6,    47/1225
# relaxation_1byj_c7,    48/1225
# relaxation_1byj_c8,    49/1225
# relaxation_1byj_c9,    50/1225
# relaxation_1bz2_c1,    51/1225
# relaxation_1bz2_c2,    52/1225
# relaxation_1bz2_c3,    53/1225
# relaxation_1bz2_c4,    54/1225
# relaxation_1bz2_c5,    55/1225
# relaxation_1bz3_c1,    56/1225
# relaxation_1bz3_c2,    57/1225
# relaxation_1bz3_c3,    58/1225
# relaxation_1bz3_c4,    59/1225
# relaxation_1bz3_c5,    60/1225
# relaxation_1bzu_c1,    61/1225
# relaxation_1bzu_c2,    62/1225
# relaxation_1bzu_c3,    63/1225
# relaxation_1bzu_c4,    64/1225
# relaxation_1bzu_c5,    65/1225
# relaxation_1c0o_c1,    66/1225
# relaxation_1c0o_c2,    67/1225
# relaxation_1c0o_c3,    68/1225
# relaxation_1c0o_c4,    69/1225
# relaxation_1cq5_c10,    70/1225
# relaxation_1cq5_c11,    71/1225
# relaxation_1cq5_c12,    72/1225
# relaxation_1cq5_c13,    73/1225
# relaxation_1cq5_c14,    74/1225
# relaxation_1cq5_c1,    75/1225
# relaxation_1cq5_c2,    76/1225
# relaxation_1cq5_c3,    77/1225
# relaxation_1cq5_c4,    78/1225
# relaxation_1cq5_c5,    79/1225
# relaxation_1cq5_c6,    80/1225
# relaxation_1cq5_c7,    81/1225
# relaxation_1cq5_c8,    82/1225
# relaxation_1cq5_c9,    83/1225
# relaxation_1cql_c10,    84/1225
# relaxation_1cql_c11,    85/1225
# relaxation_1cql_c12,    86/1225
# relaxation_1cql_c13,    87/1225
# relaxation_1cql_c14,    88/1225
# relaxation_1cql_c1,    89/1225
# relaxation_1cql_c2,    90/1225
# relaxation_1cql_c3,    91/1225
# relaxation_1cql_c4,    92/1225
# relaxation_1cql_c5,    93/1225
# relaxation_1cql_c6,    94/1225
# relaxation_1cql_c7,    95/1225
# relaxation_1cql_c8,    96/1225
# relaxation_1cql_c9,    97/1225
# relaxation_1d0u_c1,    98/1225
# relaxation_1d0u_c2,    99/1225
# relaxation_1d0u_c3,    100/1225
# relaxation_1d0u_c4,    101/1225
# relaxation_1d0u_c5,    102/1225
# relaxation_1d0u_c6,    103/1225
# relaxation_1d0u_c7,    104/1225
# relaxation_1e95_c10,    105/1225
# relaxation_1e95_c11,    106/1225
# relaxation_1e95_c12,    107/1225
# relaxation_1e95_c1,    108/1225
# relaxation_1e95_c2,    109/1225
# relaxation_1e95_c3,    110/1225
# relaxation_1e95_c4,    111/1225
# relaxation_1e95_c5,    112/1225
# relaxation_1e95_c6,    113/1225
# relaxation_1e95_c7,    114/1225
# relaxation_1e95_c8,    115/1225
# relaxation_1e95_c9,    116/1225
# relaxation_1ebq_c1,    117/1225
# relaxation_1ebq_c2,    118/1225
# relaxation_1ebq_c3,    119/1225
# relaxation_1ebq_c4,    120/1225
# relaxation_1ebq_c5,    121/1225
# relaxation_1ebq_c6,    122/1225
# relaxation_1ebq_c7,    123/1225
# relaxation_1ebq_c8,    124/1225
# relaxation_1ebq_c9,    125/1225
# relaxation_1ebr_c10,    126/1225
# relaxation_1ebr_c1,    127/1225
# relaxation_1ebr_c2,    128/1225
# relaxation_1ebr_c3,    129/1225
# relaxation_1ebr_c4,    130/1225
# relaxation_1ebr_c5,    131/1225
# relaxation_1ebr_c6,    132/1225
# relaxation_1ebr_c7,    133/1225
# relaxation_1ebr_c8,    134/1225
# relaxation_1ebr_c9,    135/1225
# relaxation_1ebs_c1,    136/1225
# relaxation_1ebs_c2,    137/1225
# relaxation_1ebs_c3,    138/1225
# relaxation_1ebs_c4,    139/1225
# relaxation_1ebs_c5,    140/1225
# relaxation_1ebs_c6,    141/1225
# relaxation_1ebs_c7,    142/1225
# relaxation_1ebs_c8,    143/1225
# relaxation_1ebs_c9,    144/1225
# relaxation_1ei2_c1,    145/1225
# relaxation_1ei2_c2,    146/1225
# relaxation_1ei2_c3,    147/1225
# relaxation_1ei2_c4,    148/1225
# relaxation_1ei2_c5,    149/1225
# relaxation_1ei2_c6,    150/1225
# relaxation_1ei2_c7,    151/1225
# relaxation_1ei2_c8,    152/1225
# relaxation_1esh_c1,    153/1225
# relaxation_1esh_c2,    154/1225
# relaxation_1esh_c3,    155/1225
# relaxation_1esh_c4,    156/1225
# relaxation_1f6x_c1,    157/1225
# relaxation_1f6x_c2,    158/1225
# relaxation_1f6x_c3,    159/1225
# relaxation_1f6x_c4,    160/1225
# relaxation_1f6x_c5,    161/1225
# relaxation_1f6x_c6,    162/1225
# relaxation_1f6x_c7,    163/1225
# relaxation_1f6x_c8,    164/1225
# relaxation_1f6x_c9,    165/1225
# relaxation_1f6z_c1,    166/1225
# relaxation_1f6z_c2,    167/1225
# relaxation_1f6z_c3,    168/1225
# relaxation_1f6z_c4,    169/1225
# relaxation_1f6z_c5,    170/1225
# relaxation_1f6z_c6,    171/1225
# relaxation_1f6z_c7,    172/1225
# relaxation_1f6z_c8,    173/1225
# relaxation_1f6z_c9,    174/1225
# relaxation_1f78_c1,    175/1225
# relaxation_1f78_c2,    176/1225
# relaxation_1f78_c3,    177/1225
# relaxation_1f78_c4,    178/1225
# relaxation_1f78_c5,    179/1225
# relaxation_1f78_c6,    180/1225
# relaxation_1f78_c7,    181/1225
# relaxation_1f78_c8,    182/1225
# relaxation_1f78_c9,    183/1225
# relaxation_1f79_c1,    184/1225
# relaxation_1f79_c2,    185/1225
# relaxation_1f79_c3,    186/1225
# relaxation_1f79_c4,    187/1225
# relaxation_1f79_c5,    188/1225
# relaxation_1f79_c6,    189/1225
# relaxation_1f79_c7,    190/1225
# relaxation_1f79_c8,    191/1225
# relaxation_1f79_c9,    192/1225
# relaxation_1f7f_c1,    193/1225
# relaxation_1f7f_c2,    194/1225
# relaxation_1f7f_c3,    195/1225
# relaxation_1f7f_c4,    196/1225
# relaxation_1f7f_c5,    197/1225
# relaxation_1f7f_c6,    198/1225
# relaxation_1f7f_c7,    199/1225
# relaxation_1f7f_c8,    200/1225
# relaxation_1f7f_c9,    201/1225
# relaxation_1f7g_c1,    202/1225
# relaxation_1f7g_c2,    203/1225
# relaxation_1f7g_c3,    204/1225
# relaxation_1f7g_c4,    205/1225
# relaxation_1f7g_c5,    206/1225
# relaxation_1f7g_c6,    207/1225
# relaxation_1f7g_c7,    208/1225
# relaxation_1f7g_c8,    209/1225
# relaxation_1f7g_c9,    210/1225
# relaxation_1f7h_c1,    211/1225
# relaxation_1f7h_c2,    212/1225
# relaxation_1f7h_c3,    213/1225
# relaxation_1f7h_c4,    214/1225
# relaxation_1f7h_c5,    215/1225
# relaxation_1f7h_c6,    216/1225
# relaxation_1f7h_c7,    217/1225
# relaxation_1f7h_c8,    218/1225
# relaxation_1f7h_c9,    219/1225
# relaxation_1f7i_c1,    220/1225
# relaxation_1f7i_c2,    221/1225
# relaxation_1f7i_c3,    222/1225
# relaxation_1f7i_c4,    223/1225
# relaxation_1f7i_c5,    224/1225
# relaxation_1f7i_c6,    225/1225
# relaxation_1f7i_c7,    226/1225
# relaxation_1f7i_c8,    227/1225
# relaxation_1f7i_c9,    228/1225
# relaxation_1f85_c1,    229/1225
# relaxation_1f85_c2,    230/1225
# relaxation_1f85_c3,    231/1225
# relaxation_1f85_c4,    232/1225
# relaxation_1f9l_c1,    233/1225
# relaxation_1f9l_c2,    234/1225
# relaxation_1f9l_c3,    235/1225
# relaxation_1f9l_c4,    236/1225
# relaxation_1f9l_c5,    237/1225
# relaxation_1f9l_c6,    238/1225
# relaxation_1f9l_c7,    239/1225
# relaxation_1feq_c1,    240/1225
# relaxation_1feq_c2,    241/1225
# relaxation_1feq_c3,    242/1225
# relaxation_1feq_c4,    243/1225
# relaxation_1feq_c5,    244/1225
# relaxation_1fhk_c1,    245/1225
# relaxation_1fhk_c2,    246/1225
# relaxation_1fhk_c3,    247/1225
# relaxation_1fhk_c4,    248/1225
# relaxation_1fqz_c1,    249/1225
# relaxation_1fqz_c2,    250/1225
# relaxation_1fqz_c3,    251/1225
# relaxation_1fqz_c4,    252/1225
# relaxation_1fqz_c5,    253/1225
# relaxation_1fqz_c6,    254/1225
# relaxation_1fqz_c7,    255/1225
# relaxation_1fqz_c8,    256/1225
# relaxation_1fqz_c9,    257/1225
# relaxation_1fyo_c1,    258/1225
# relaxation_1fyo_c2,    259/1225
# relaxation_1fyo_c3,    260/1225
# relaxation_1fyo_c4,    261/1225
# relaxation_1fyo_c5,    262/1225
# relaxation_1fyo_c6,    263/1225
# relaxation_1fyo_c7,    264/1225
# relaxation_1fyo_c8,    265/1225
# relaxation_1fyo_c9,    266/1225
# relaxation_1fyp_c1,    267/1225
# relaxation_1fyp_c2,    268/1225
# relaxation_1fyp_c3,    269/1225
# relaxation_1fyp_c4,    270/1225
# relaxation_1fyp_c5,    271/1225
# relaxation_1fyp_c6,    272/1225
# relaxation_1fyp_c7,    273/1225
# relaxation_1fyp_c8,    274/1225
# relaxation_1fyp_c9,    275/1225
# relaxation_1hlx_c1,    276/1225
# relaxation_1hlx_c2,    277/1225
# relaxation_1hlx_c3,    278/1225
# relaxation_1hlx_c4,    279/1225
# relaxation_1hlx_c5,    280/1225
# relaxation_1hlx_c6,    281/1225
# relaxation_1hs1_c1,    282/1225
# relaxation_1hs1_c2,    283/1225
# relaxation_1hs1_c3,    284/1225
# relaxation_1hs1_c4,    285/1225
# relaxation_1hs2_c1,    286/1225
# relaxation_1hs2_c2,    287/1225
# relaxation_1hs2_c3,    288/1225
# relaxation_1hs2_c4,    289/1225
# relaxation_1hs3_c1,    290/1225
# relaxation_1hs3_c2,    291/1225
# relaxation_1hs3_c3,    292/1225
# relaxation_1hs3_c4,    293/1225
# relaxation_1hs4_c1,    294/1225
# relaxation_1hs4_c2,    295/1225
# relaxation_1hs4_c3,    296/1225
# relaxation_1hs4_c4,    297/1225
# relaxation_1hs8_c1,    298/1225
# relaxation_1hs8_c2,    299/1225
# relaxation_1hs8_c3,    300/1225
# relaxation_1hs8_c4,    301/1225
# relaxation_1hwq_c10,    302/1225
# relaxation_1hwq_c1,    303/1225
# relaxation_1hwq_c2,    304/1225
# relaxation_1hwq_c3,    305/1225
# relaxation_1hwq_c4,    306/1225
# relaxation_1hwq_c5,    307/1225
# relaxation_1hwq_c6,    308/1225
# relaxation_1hwq_c7,    309/1225
# relaxation_1hwq_c8,    310/1225
# relaxation_1hwq_c9,    311/1225
# relaxation_1i3x_c1,    312/1225
# relaxation_1i3x_c2,    313/1225
# relaxation_1i3x_c3,    314/1225
# relaxation_1i3x_c4,    315/1225
# relaxation_1i3x_c5,    316/1225
# relaxation_1i3x_c6,    317/1225
# relaxation_1i46_c1,    318/1225
# relaxation_1i46_c2,    319/1225
# relaxation_1i46_c3,    320/1225
# relaxation_1i46_c4,    321/1225
# relaxation_1i4b_c1,    322/1225
# relaxation_1i4b_c2,    323/1225
# relaxation_1i4b_c3,    324/1225
# relaxation_1i4b_c4,    325/1225
# relaxation_1i4c_c1,    326/1225
# relaxation_1i4c_c2,    327/1225
# relaxation_1i4c_c3,    328/1225
# relaxation_1i4c_c4,    329/1225
# relaxation_1idv_c1,    330/1225
# relaxation_1idv_c2,    331/1225
# relaxation_1idv_c3,    332/1225
# relaxation_1ie1_c1,    333/1225
# relaxation_1ie1_c2,    334/1225
# relaxation_1ie1_c3,    335/1225
# relaxation_1ie1_c4,    336/1225
# relaxation_1ie1_c5,    337/1225
# relaxation_1ie1_c6,    338/1225
# relaxation_1ie1_c7,    339/1225
# relaxation_1ie2_c1,    340/1225
# relaxation_1ie2_c2,    341/1225
# relaxation_1ie2_c3,    342/1225
# relaxation_1ie2_c4,    343/1225
# relaxation_1ie2_c5,    344/1225
# relaxation_1ie2_c6,    345/1225
# relaxation_1ie2_c7,    346/1225
# relaxation_1ik1_c1,    347/1225
# relaxation_1ik1_c2,    348/1225
# relaxation_1ik1_c3,    349/1225
# relaxation_1ik1_c4,    350/1225
# relaxation_1j4y_c1,    351/1225
# relaxation_1j4y_c2,    352/1225
# relaxation_1j4y_c3,    353/1225
# relaxation_1j4y_c4,    354/1225
# relaxation_1j4y_c5,    355/1225
# relaxation_1jo7_c10,    356/1225
# relaxation_1jo7_c1,    357/1225
# relaxation_1jo7_c2,    358/1225
# relaxation_1jo7_c3,    359/1225
# relaxation_1jo7_c4,    360/1225
# relaxation_1jo7_c5,    361/1225
# relaxation_1jo7_c6,    362/1225
# relaxation_1jo7_c7,    363/1225
# relaxation_1jo7_c8,    364/1225
# relaxation_1jo7_c9,    365/1225
# relaxation_1jox_c1,    366/1225
# relaxation_1jox_c2,    367/1225
# relaxation_1jox_c3,    368/1225
# relaxation_1jox_c4,    369/1225
# relaxation_1jox_c5,    370/1225
# relaxation_1jox_c6,    371/1225
# relaxation_1jox_c7,    372/1225
# relaxation_1jp0_c1,    373/1225
# relaxation_1jp0_c2,    374/1225
# relaxation_1jp0_c3,    375/1225
# relaxation_1jp0_c4,    376/1225
# relaxation_1jp0_c5,    377/1225
# relaxation_1jp0_c6,    378/1225
# relaxation_1jp0_c7,    379/1225
# relaxation_1jtj_c1,    380/1225
# relaxation_1jtj_c2,    381/1225
# relaxation_1jtj_c3,    382/1225
# relaxation_1jtj_c4,    383/1225
# relaxation_1jtj_c5,    384/1225
# relaxation_1jtj_c6,    385/1225
# relaxation_1jtj_c7,    386/1225
# relaxation_1jtw_c1,    387/1225
# relaxation_1jtw_c2,    388/1225
# relaxation_1jtw_c3,    389/1225
# relaxation_1jtw_c4,    390/1225
# relaxation_1jtw_c5,    391/1225
# relaxation_1ju7_c1,    392/1225
# relaxation_1ju7_c2,    393/1225
# relaxation_1ju7_c3,    394/1225
# relaxation_1ju7_c4,    395/1225
# relaxation_1ju7_c5,    396/1225
# relaxation_1jur_c1,    397/1225
# relaxation_1jur_c2,    398/1225
# relaxation_1jur_c3,    399/1225
# relaxation_1jur_c4,    400/1225
# relaxation_1jur_c5,    401/1225
# relaxation_1jur_c6,    402/1225
# relaxation_1jur_c7,    403/1225
# relaxation_1jwc_c1,    404/1225
# relaxation_1jwc_c2,    405/1225
# relaxation_1jwc_c3,    406/1225
# relaxation_1jwc_c4,    407/1225
# relaxation_1jwc_c5,    408/1225
# relaxation_1jzc_c1,    409/1225
# relaxation_1jzc_c2,    410/1225
# relaxation_1jzc_c3,    411/1225
# relaxation_1jzc_c4,    412/1225
# relaxation_1k2g_c1,    413/1225
# relaxation_1k2g_c2,    414/1225
# relaxation_1k2g_c3,    415/1225
# relaxation_1k2g_c4,    416/1225
# relaxation_1k2g_c5,    417/1225
# relaxation_1k2g_c6,    418/1225
# relaxation_1k2g_c7,    419/1225
# relaxation_1k4a_c1,    420/1225
# relaxation_1k4a_c2,    421/1225
# relaxation_1k4a_c3,    422/1225
# relaxation_1k4a_c4,    423/1225
# relaxation_1k4b_c1,    424/1225
# relaxation_1k4b_c2,    425/1225
# relaxation_1k4b_c3,    426/1225
# relaxation_1k4b_c4,    427/1225
# relaxation_1k5i_c1,    428/1225
# relaxation_1k5i_c2,    429/1225
# relaxation_1k5i_c3,    430/1225
# relaxation_1k5i_c4,    431/1225
# relaxation_1k5i_c5,    432/1225
# relaxation_1k5i_c6,    433/1225
# relaxation_1k5i_c7,    434/1225
# relaxation_1k6g_c1,    435/1225
# relaxation_1k6g_c2,    436/1225
# relaxation_1k6g_c3,    437/1225
# relaxation_1k6g_c4,    438/1225
# relaxation_1k6g_c5,    439/1225
# relaxation_1k6g_c6,    440/1225
# relaxation_1k6g_c7,    441/1225
# relaxation_1k6h_c1,    442/1225
# relaxation_1k6h_c2,    443/1225
# relaxation_1k6h_c3,    444/1225
# relaxation_1k6h_c4,    445/1225
# relaxation_1k6h_c5,    446/1225
# relaxation_1k6h_c6,    447/1225
# relaxation_1k6h_c7,    448/1225
# relaxation_1kaj_c10,    449/1225
# relaxation_1kaj_c1,    450/1225
# relaxation_1kaj_c2,    451/1225
# relaxation_1kaj_c3,    452/1225
# relaxation_1kaj_c4,    453/1225
# relaxation_1kaj_c5,    454/1225
# relaxation_1kaj_c6,    455/1225
# relaxation_1kaj_c7,    456/1225
# relaxation_1kaj_c8,    457/1225
# relaxation_1kaj_c9,    458/1225
# relaxation_1kka_c1,    459/1225
# relaxation_1kka_c2,    460/1225
# relaxation_1kka_c3,    461/1225
# relaxation_1kka_c4,    462/1225
# relaxation_1kka_c5,    463/1225
# relaxation_1kks_c1,    464/1225
# relaxation_1kks_c2,    465/1225
# relaxation_1kks_c3,    466/1225
# relaxation_1kks_c4,    467/1225
# relaxation_1kks_c5,    468/1225
# relaxation_1kks_c6,    469/1225
# relaxation_1kks_c7,    470/1225
# relaxation_1kks_c8,    471/1225
# relaxation_1kp7_c10,    472/1225
# relaxation_1kp7_c1,    473/1225
# relaxation_1kp7_c2,    474/1225
# relaxation_1kp7_c3,    475/1225
# relaxation_1kp7_c4,    476/1225
# relaxation_1kp7_c5,    477/1225
# relaxation_1kp7_c6,    478/1225
# relaxation_1kp7_c7,    479/1225
# relaxation_1kp7_c8,    480/1225
# relaxation_1kp7_c9,    481/1225
# relaxation_1l1w_c1,    482/1225
# relaxation_1l1w_c2,    483/1225
# relaxation_1l1w_c3,    484/1225
# relaxation_1l1w_c4,    485/1225
# relaxation_1l1w_c5,    486/1225
# relaxation_1l1w_c6,    487/1225
# relaxation_1l1w_c7,    488/1225
# relaxation_1l1w_c8,    489/1225
# relaxation_1l1w_c9,    490/1225
# relaxation_1l2x_c1,    491/1225
# relaxation_1l2x_c2,    492/1225
# relaxation_1l2x_c3,    493/1225
# relaxation_1l2x_c4,    494/1225
# relaxation_1l2x_c5,    495/1225
# relaxation_1l2x_c6,    496/1225
# relaxation_1l2x_c7,    497/1225
# relaxation_1l2x_c8,    498/1225
# relaxation_1l2x_c9,    499/1225
# relaxation_1lc6_c1,    500/1225
# relaxation_1lc6_c2,    501/1225
# relaxation_1lc6_c3,    502/1225
# relaxation_1lc6_c4,    503/1225
# relaxation_1lc6_c5,    504/1225
# relaxation_1lc6_c6,    505/1225
# relaxation_1lc6_c7,    506/1225
# relaxation_1lc6_c8,    507/1225
# relaxation_1luu_c1,    508/1225
# relaxation_1luu_c2,    509/1225
# relaxation_1luu_c3,    510/1225
# relaxation_1luu_c4,    511/1225
# relaxation_1lux_c1,    512/1225
# relaxation_1lux_c2,    513/1225
# relaxation_1lux_c3,    514/1225
# relaxation_1lux_c4,    515/1225
# relaxation_1lvj_c10,    516/1225
# relaxation_1lvj_c1,    517/1225
# relaxation_1lvj_c2,    518/1225
# relaxation_1lvj_c3,    519/1225
# relaxation_1lvj_c4,    520/1225
# relaxation_1lvj_c5,    521/1225
# relaxation_1lvj_c6,    522/1225
# relaxation_1lvj_c7,    523/1225
# relaxation_1lvj_c8,    524/1225
# relaxation_1lvj_c9,    525/1225
# relaxation_1m5l_c10,    526/1225
# relaxation_1m5l_c11,    527/1225
# relaxation_1m5l_c12,    528/1225
# relaxation_1m5l_c1,    529/1225
# relaxation_1m5l_c2,    530/1225
# relaxation_1m5l_c3,    531/1225
# relaxation_1m5l_c4,    532/1225
# relaxation_1m5l_c5,    533/1225
# relaxation_1m5l_c6,    534/1225
# relaxation_1m5l_c7,    535/1225
# relaxation_1m5l_c8,    536/1225
# relaxation_1m5l_c9,    537/1225
# relaxation_1m82_c1,    538/1225
# relaxation_1m82_c2,    539/1225
# relaxation_1m82_c3,    540/1225
# relaxation_1m82_c4,    541/1225
# relaxation_1m82_c5,    542/1225
# relaxation_1m82_c6,    543/1225
# relaxation_1m82_c7,    544/1225
# relaxation_1m82_c8,    545/1225
# relaxation_1mfj_c1,    546/1225
# relaxation_1mfj_c2,    547/1225
# relaxation_1mfj_c3,    548/1225
# relaxation_1mfj_c4,    549/1225
# relaxation_1mfj_c5,    550/1225
# relaxation_1mfj_c6,    551/1225
# relaxation_1mfk_c1,    552/1225
# relaxation_1mfk_c2,    553/1225
# relaxation_1mfk_c3,    554/1225
# relaxation_1mfk_c4,    555/1225
# relaxation_1mfk_c5,    556/1225
# relaxation_1mfk_c6,    557/1225
# relaxation_1mfk_c7,    558/1225
# relaxation_1mfy_c10,    559/1225
# relaxation_1mfy_c1,    560/1225
# relaxation_1mfy_c2,    561/1225
# relaxation_1mfy_c3,    562/1225
# relaxation_1mfy_c4,    563/1225
# relaxation_1mfy_c5,    564/1225
# relaxation_1mfy_c6,    565/1225
# relaxation_1mfy_c7,    566/1225
# relaxation_1mfy_c8,    567/1225
# relaxation_1mfy_c9,    568/1225
# relaxation_1mt4_c1,    569/1225
# relaxation_1mt4_c2,    570/1225
# relaxation_1mt4_c3,    571/1225
# relaxation_1mt4_c4,    572/1225
# relaxation_1mt4_c5,    573/1225
# relaxation_1mt4_c6,    574/1225
# relaxation_1mt4_c7,    575/1225
# relaxation_1mt4_c8,    576/1225
# relaxation_1n8x_c10,    577/1225
# relaxation_1n8x_c11,    578/1225
# relaxation_1n8x_c12,    579/1225
# relaxation_1n8x_c1,    580/1225
# relaxation_1n8x_c2,    581/1225
# relaxation_1n8x_c3,    582/1225
# relaxation_1n8x_c4,    583/1225
# relaxation_1n8x_c5,    584/1225
# relaxation_1n8x_c6,    585/1225
# relaxation_1n8x_c7,    586/1225
# relaxation_1n8x_c8,    587/1225
# relaxation_1n8x_c9,    588/1225
# relaxation_1na2_c10,    589/1225
# relaxation_1na2_c1,    590/1225
# relaxation_1na2_c2,    591/1225
# relaxation_1na2_c3,    592/1225
# relaxation_1na2_c4,    593/1225
# relaxation_1na2_c5,    594/1225
# relaxation_1na2_c6,    595/1225
# relaxation_1na2_c7,    596/1225
# relaxation_1na2_c8,    597/1225
# relaxation_1na2_c9,    598/1225
# relaxation_1nbr_c1,    599/1225
# relaxation_1nbr_c2,    600/1225
# relaxation_1nbr_c3,    601/1225
# relaxation_1nbr_c4,    602/1225
# relaxation_1nbr_c5,    603/1225
# relaxation_1nbr_c6,    604/1225
# relaxation_1nbr_c7,    605/1225
# relaxation_1nbr_c8,    606/1225
# relaxation_1nbr_c9,    607/1225
# relaxation_1nc0_c1,    608/1225
# relaxation_1nc0_c2,    609/1225
# relaxation_1nc0_c3,    610/1225
# relaxation_1nc0_c4,    611/1225
# relaxation_1nc0_c5,    612/1225
# relaxation_1nc0_c6,    613/1225
# relaxation_1nc0_c7,    614/1225
# relaxation_1nc0_c8,    615/1225
# relaxation_1nem_c1,    616/1225
# relaxation_1nem_c2,    617/1225
# relaxation_1nem_c3,    618/1225
# relaxation_1nem_c4,    619/1225
# relaxation_1nem_c5,    620/1225
# relaxation_1nem_c6,    621/1225
# relaxation_1nem_c7,    622/1225
# relaxation_1nz1_c1,    623/1225
# relaxation_1nz1_c2,    624/1225
# relaxation_1nz1_c3,    625/1225
# relaxation_1nz1_c4,    626/1225
# relaxation_1nz1_c5,    627/1225
# relaxation_1nz1_c6,    628/1225
# relaxation_1nz1_c7,    629/1225
# relaxation_1o15_c10,    630/1225
# relaxation_1o15_c11,    631/1225
# relaxation_1o15_c1,    632/1225
# relaxation_1o15_c2,    633/1225
# relaxation_1o15_c3,    634/1225
# relaxation_1o15_c4,    635/1225
# relaxation_1o15_c5,    636/1225
# relaxation_1o15_c6,    637/1225
# relaxation_1o15_c7,    638/1225
# relaxation_1o15_c8,    639/1225
# relaxation_1o15_c9,    640/1225
# relaxation_1oq0_c1,    641/1225
# relaxation_1oq0_c2,    642/1225
# relaxation_1oq0_c3,    643/1225
# relaxation_1oq0_c4,    644/1225
# relaxation_1oq0_c5,    645/1225
# relaxation_1ow9_c1,    646/1225
# relaxation_1ow9_c2,    647/1225
# relaxation_1ow9_c3,    648/1225
# relaxation_1ow9_c4,    649/1225
# relaxation_1ow9_c5,    650/1225
# relaxation_1ow9_c6,    651/1225
# relaxation_1ow9_c7,    652/1225
# relaxation_1p5m_c10,    653/1225
# relaxation_1p5m_c11,    654/1225
# relaxation_1p5m_c12,    655/1225
# relaxation_1p5m_c13,    656/1225
# relaxation_1p5m_c14,    657/1225
# relaxation_1p5m_c15,    658/1225
# relaxation_1p5m_c16,    659/1225
# relaxation_1p5m_c17,    660/1225
# relaxation_1p5m_c18,    661/1225
# relaxation_1p5m_c1,    662/1225
# relaxation_1p5m_c2,    663/1225
# relaxation_1p5m_c3,    664/1225
# relaxation_1p5m_c4,    665/1225
# relaxation_1p5m_c5,    666/1225
# relaxation_1p5m_c6,    667/1225
# relaxation_1p5m_c7,    668/1225
# relaxation_1p5m_c8,    669/1225
# relaxation_1p5m_c9,    670/1225
# relaxation_1p5n_c10,    671/1225
# relaxation_1p5n_c11,    672/1225
# relaxation_1p5n_c1,    673/1225
# relaxation_1p5n_c2,    674/1225
# relaxation_1p5n_c3,    675/1225
# relaxation_1p5n_c4,    676/1225
# relaxation_1p5n_c5,    677/1225
# relaxation_1p5n_c6,    678/1225
# relaxation_1p5n_c7,    679/1225
# relaxation_1p5n_c8,    680/1225
# relaxation_1p5n_c9,    681/1225
# relaxation_1p5o_c10,    682/1225
# relaxation_1p5o_c11,    683/1225
# relaxation_1p5o_c12,    684/1225
# relaxation_1p5o_c13,    685/1225
# relaxation_1p5o_c14,    686/1225
# relaxation_1p5o_c15,    687/1225
# relaxation_1p5o_c16,    688/1225
# relaxation_1p5o_c17,    689/1225
# relaxation_1p5o_c18,    690/1225
# relaxation_1p5o_c19,    691/1225
# relaxation_1p5o_c1,    692/1225
# relaxation_1p5o_c20,    693/1225
# relaxation_1p5o_c21,    694/1225
# relaxation_1p5o_c22,    695/1225
# relaxation_1p5o_c23,    696/1225
# relaxation_1p5o_c24,    697/1225
# relaxation_1p5o_c25,    698/1225
# relaxation_1p5o_c2,    699/1225
# relaxation_1p5o_c3,    700/1225
# relaxation_1p5o_c4,    701/1225
# relaxation_1p5o_c5,    702/1225
# relaxation_1p5o_c6,    703/1225
# relaxation_1p5o_c7,    704/1225
# relaxation_1p5o_c8,    705/1225
# relaxation_1p5o_c9,    706/1225
# relaxation_1p5p_c10,    707/1225
# relaxation_1p5p_c11,    708/1225
# relaxation_1p5p_c12,    709/1225
# relaxation_1p5p_c13,    710/1225
# relaxation_1p5p_c14,    711/1225
# relaxation_1p5p_c15,    712/1225
# relaxation_1p5p_c16,    713/1225
# relaxation_1p5p_c17,    714/1225
# relaxation_1p5p_c18,    715/1225
# relaxation_1p5p_c19,    716/1225
# relaxation_1p5p_c1,    717/1225
# relaxation_1p5p_c20,    718/1225
# relaxation_1p5p_c21,    719/1225
# relaxation_1p5p_c22,    720/1225
# relaxation_1p5p_c23,    721/1225
# relaxation_1p5p_c24,    722/1225
# relaxation_1p5p_c25,    723/1225
# relaxation_1p5p_c2,    724/1225
# relaxation_1p5p_c3,    725/1225
# relaxation_1p5p_c4,    726/1225
# relaxation_1p5p_c5,    727/1225
# relaxation_1p5p_c6,    728/1225
# relaxation_1p5p_c7,    729/1225
# relaxation_1p5p_c8,    730/1225
# relaxation_1p5p_c9,    731/1225
# relaxation_1p79,    732/1225
# relaxation_1pjy_c1,    733/1225
# relaxation_1pjy_c2,    734/1225
# relaxation_1pjy_c3,    735/1225
# relaxation_1pjy_c4,    736/1225
# relaxation_1pjy_c5,    737/1225
# relaxation_1pjy_c6,    738/1225
# relaxation_1pjy_c7,    739/1225
# relaxation_1q75_c1,    740/1225
# relaxation_1q75_c2,    741/1225
# relaxation_1q75_c3,    742/1225
# relaxation_1q75_c4,    743/1225
# relaxation_1q75_c5,    744/1225
# relaxation_1q8n_c10,    745/1225
# relaxation_1q8n_c11,    746/1225
# relaxation_1q8n_c12,    747/1225
# relaxation_1q8n_c1,    748/1225
# relaxation_1q8n_c2,    749/1225
# relaxation_1q8n_c3,    750/1225
# relaxation_1q8n_c4,    751/1225
# relaxation_1q8n_c5,    752/1225
# relaxation_1q8n_c6,    753/1225
# relaxation_1q8n_c7,    754/1225
# relaxation_1q8n_c8,    755/1225
# relaxation_1q8n_c9,    756/1225
# relaxation_1qd3_c1,    757/1225
# relaxation_1qd3_c2,    758/1225
# relaxation_1qd3_c3,    759/1225
# relaxation_1qd3_c4,    760/1225
# relaxation_1qd3_c5,    761/1225
# relaxation_1qd3_c6,    762/1225
# relaxation_1qd3_c7,    763/1225
# relaxation_1qd3_c8,    764/1225
# relaxation_1qd3_c9,    765/1225
# relaxation_1qwa_c1,    766/1225
# relaxation_1qwa_c2,    767/1225
# relaxation_1qwa_c3,    768/1225
# relaxation_1qwa_c4,    769/1225
# relaxation_1qwa_c5,    770/1225
# relaxation_1qwa_c6,    771/1225
# relaxation_1qwa_c7,    772/1225
# relaxation_1qwb_c1,    773/1225
# relaxation_1qwb_c2,    774/1225
# relaxation_1qwb_c3,    775/1225
# relaxation_1qwb_c4,    776/1225
# relaxation_1qwb_c5,    777/1225
# relaxation_1qwb_c6,    778/1225
# relaxation_1qwb_c7,    779/1225
# relaxation_1qwb_c8,    780/1225
# relaxation_1r2p_c10,    781/1225
# relaxation_1r2p_c11,    782/1225
# relaxation_1r2p_c1,    783/1225
# relaxation_1r2p_c2,    784/1225
# relaxation_1r2p_c3,    785/1225
# relaxation_1r2p_c4,    786/1225
# relaxation_1r2p_c5,    787/1225
# relaxation_1r2p_c6,    788/1225
# relaxation_1r2p_c7,    789/1225
# relaxation_1r2p_c8,    790/1225
# relaxation_1r2p_c9,    791/1225
# relaxation_1r4h_c1,    792/1225
# relaxation_1r4h_c2,    793/1225
# relaxation_1r4h_c3,    794/1225
# relaxation_1r7w_c10,    795/1225
# relaxation_1r7w_c11,    796/1225
# relaxation_1r7w_c1,    797/1225
# relaxation_1r7w_c2,    798/1225
# relaxation_1r7w_c3,    799/1225
# relaxation_1r7w_c4,    800/1225
# relaxation_1r7w_c5,    801/1225
# relaxation_1r7w_c6,    802/1225
# relaxation_1r7w_c7,    803/1225
# relaxation_1r7w_c8,    804/1225
# relaxation_1r7w_c9,    805/1225
# relaxation_1r7z_c10,    806/1225
# relaxation_1r7z_c11,    807/1225
# relaxation_1r7z_c1,    808/1225
# relaxation_1r7z_c2,    809/1225
# relaxation_1r7z_c3,    810/1225
# relaxation_1r7z_c4,    811/1225
# relaxation_1r7z_c5,    812/1225
# relaxation_1r7z_c6,    813/1225
# relaxation_1r7z_c7,    814/1225
# relaxation_1r7z_c8,    815/1225
# relaxation_1r7z_c9,    816/1225
# relaxation_1rfr_c10,    817/1225
# relaxation_1rfr_c1,    818/1225
# relaxation_1rfr_c2,    819/1225
# relaxation_1rfr_c3,    820/1225
# relaxation_1rfr_c4,    821/1225
# relaxation_1rfr_c5,    822/1225
# relaxation_1rfr_c6,    823/1225
# relaxation_1rfr_c7,    824/1225
# relaxation_1rfr_c8,    825/1225
# relaxation_1rfr_c9,    826/1225
# relaxation_1rht_c1,    827/1225
# relaxation_1rht_c2,    828/1225
# relaxation_1rht_c3,    829/1225
# relaxation_1rht_c4,    830/1225
# relaxation_1rht_c5,    831/1225
# relaxation_1rht_c6,    832/1225
# relaxation_1rht_c7,    833/1225
# relaxation_1rht_c8,    834/1225
# relaxation_1rng_c1,    835/1225
# relaxation_1rng_c2,    836/1225
# relaxation_1rng_c3,    837/1225
# relaxation_1rng_c4,    838/1225
# relaxation_1rnk_c10,    839/1225
# relaxation_1rnk_c11,    840/1225
# relaxation_1rnk_c1,    841/1225
# relaxation_1rnk_c2,    842/1225
# relaxation_1rnk_c3,    843/1225
# relaxation_1rnk_c4,    844/1225
# relaxation_1rnk_c5,    845/1225
# relaxation_1rnk_c6,    846/1225
# relaxation_1rnk_c7,    847/1225
# relaxation_1rnk_c8,    848/1225
# relaxation_1rnk_c9,    849/1225
# relaxation_1roq_c1,    850/1225
# relaxation_1roq_c2,    851/1225
# relaxation_1roq_c3,    852/1225
# relaxation_1roq_c4,    853/1225
# relaxation_1s2f_c1,    854/1225
# relaxation_1s2f_c2,    855/1225
# relaxation_1s2f_c3,    856/1225
# relaxation_1s2f_c4,    857/1225
# relaxation_1s2f_c5,    858/1225
# relaxation_1s2f_c6,    859/1225
# relaxation_1s2f_c7,    860/1225
# relaxation_1s34_c1,    861/1225
# relaxation_1s34_c2,    862/1225
# relaxation_1s34_c3,    863/1225
# relaxation_1s34_c4,    864/1225
# relaxation_1s34_c5,    865/1225
# relaxation_1s34_c6,    866/1225
# relaxation_1s34_c7,    867/1225
# relaxation_1s9s_c10,    868/1225
# relaxation_1s9s_c11,    869/1225
# relaxation_1s9s_c12,    870/1225
# relaxation_1s9s_c13,    871/1225
# relaxation_1s9s_c14,    872/1225
# relaxation_1s9s_c15,    873/1225
# relaxation_1s9s_c16,    874/1225
# relaxation_1s9s_c17,    875/1225
# relaxation_1s9s_c18,    876/1225
# relaxation_1s9s_c19,    877/1225
# relaxation_1s9s_c1,    878/1225
# relaxation_1s9s_c20,    879/1225
# relaxation_1s9s_c21,    880/1225
# relaxation_1s9s_c22,    881/1225
# relaxation_1s9s_c23,    882/1225
# relaxation_1s9s_c24,    883/1225
# relaxation_1s9s_c25,    884/1225
# relaxation_1s9s_c26,    885/1225
# relaxation_1s9s_c27,    886/1225
# relaxation_1s9s_c28,    887/1225
# relaxation_1s9s_c29,    888/1225
# relaxation_1s9s_c2,    889/1225
# relaxation_1s9s_c30,    890/1225
# relaxation_1s9s_c31,    891/1225
# relaxation_1s9s_c32,    892/1225
# relaxation_1s9s_c33,    893/1225
# relaxation_1s9s_c3,    894/1225
# relaxation_1s9s_c4,    895/1225
# relaxation_1s9s_c5,    896/1225
# relaxation_1s9s_c6,    897/1225
# relaxation_1s9s_c7,    898/1225
# relaxation_1s9s_c8,    899/1225
# relaxation_1s9s_c9,    900/1225
# relaxation_1scl_c1,    901/1225
# relaxation_1scl_c2,    902/1225
# relaxation_1scl_c3,    903/1225
# relaxation_1scl_c4,    904/1225
# relaxation_1scl_c5,    905/1225
# relaxation_1scl_c6,    906/1225
# relaxation_1scl_c7,    907/1225
# relaxation_1scl_c8,    908/1225
# relaxation_1scl_c9,    909/1225
# relaxation_1slo_c1,    910/1225
# relaxation_1slo_c2,    911/1225
# relaxation_1slo_c3,    912/1225
# relaxation_1slo_c4,    913/1225
# relaxation_1slo_c5,    914/1225
# relaxation_1slo_c6,    915/1225
# relaxation_1slp_c1,    916/1225
# relaxation_1slp_c2,    917/1225
# relaxation_1slp_c3,    918/1225
# relaxation_1slp_c4,    919/1225
# relaxation_1slp_c5,    920/1225
# relaxation_1slp_c6,    921/1225
# relaxation_1sy4_c1,    922/1225
# relaxation_1sy4_c2,    923/1225
# relaxation_1sy4_c3,    924/1225
# relaxation_1sy4_c4,    925/1225
# relaxation_1sy4_c5,    926/1225
# relaxation_1sy4_c6,    927/1225
# relaxation_1sy4_c7,    928/1225
# relaxation_1sy4_c8,    929/1225
# relaxation_1syz_c1,    930/1225
# relaxation_1syz_c2,    931/1225
# relaxation_1syz_c3,    932/1225
# relaxation_1syz_c4,    933/1225
# relaxation_1syz_c5,    934/1225
# relaxation_1syz_c6,    935/1225
# relaxation_1syz_c7,    936/1225
# relaxation_1syz_c8,    937/1225
# relaxation_1szy_c1,    938/1225
# relaxation_1szy_c2,    939/1225
# relaxation_1szy_c3,    940/1225
# relaxation_1szy_c4,    941/1225
# relaxation_1szy_c5,    942/1225
# relaxation_1szy_c6,    943/1225
# relaxation_1szy_c7,    944/1225
# relaxation_1t28_c10,    945/1225
# relaxation_1t28_c11,    946/1225
# relaxation_1t28_c1,    947/1225
# relaxation_1t28_c2,    948/1225
# relaxation_1t28_c3,    949/1225
# relaxation_1t28_c4,    950/1225
# relaxation_1t28_c5,    951/1225
# relaxation_1t28_c6,    952/1225
# relaxation_1t28_c7,    953/1225
# relaxation_1t28_c8,    954/1225
# relaxation_1t28_c9,    955/1225
# relaxation_1tbk_c1,    956/1225
# relaxation_1tbk_c2,    957/1225
# relaxation_1tbk_c3,    958/1225
# relaxation_1tbk_c4,    959/1225
# relaxation_1tbk_c5,    960/1225
# relaxation_1tfn_c1,    961/1225
# relaxation_1tfn_c2,    962/1225
# relaxation_1tfn_c3,    963/1225
# relaxation_1tfn_c4,    964/1225
# relaxation_1tfn_c5,    965/1225
# relaxation_1tfn_c6,    966/1225
# relaxation_1tfn_c7,    967/1225
# relaxation_1tfn_c8,    968/1225
# relaxation_1tjz_c1,    969/1225
# relaxation_1tjz_c2,    970/1225
# relaxation_1tjz_c3,    971/1225
# relaxation_1tjz_c4,    972/1225
# relaxation_1tjz_c5,    973/1225
# relaxation_1tjz_c6,    974/1225
# relaxation_1tjz_c7,    975/1225
# relaxation_1tlr_c1,    976/1225
# relaxation_1tlr_c2,    977/1225
# relaxation_1tlr_c3,    978/1225
# relaxation_1tlr_c4,    979/1225
# relaxation_1tlr_c5,    980/1225
# relaxation_1tlr_c6,    981/1225
# relaxation_1tlr_c7,    982/1225
# relaxation_1txs_c10,    983/1225
# relaxation_1txs_c11,    984/1225
# relaxation_1txs_c12,    985/1225
# relaxation_1txs_c1,    986/1225
# relaxation_1txs_c2,    987/1225
# relaxation_1txs_c3,    988/1225
# relaxation_1txs_c4,    989/1225
# relaxation_1txs_c5,    990/1225
# relaxation_1txs_c6,    991/1225
# relaxation_1txs_c7,    992/1225
# relaxation_1txs_c8,    993/1225
# relaxation_1txs_c9,    994/1225
# relaxation_1u2a_c1,    995/1225
# relaxation_1u2a_c2,    996/1225
# relaxation_1u2a_c3,    997/1225
# relaxation_1u2a_c4,    998/1225
# relaxation_1u2a_c5,    999/1225
# relaxation_1u2a_c6,    1000/1225
# relaxation_1u3k_c10,    1001/1225
# relaxation_1u3k_c11,    1002/1225
# relaxation_1u3k_c12,    1003/1225
# relaxation_1u3k_c1,    1004/1225
# relaxation_1u3k_c2,    1005/1225
# relaxation_1u3k_c3,    1006/1225
# relaxation_1u3k_c4,    1007/1225
# relaxation_1u3k_c5,    1008/1225
# relaxation_1u3k_c6,    1009/1225
# relaxation_1u3k_c7,    1010/1225
# relaxation_1u3k_c8,    1011/1225
# relaxation_1u3k_c9,    1012/1225
# relaxation_1uts_c1,    1013/1225
# relaxation_1uts_c2,    1014/1225
# relaxation_1uts_c3,    1015/1225
# relaxation_1uts_c4,    1016/1225
# relaxation_1uts_c5,    1017/1225
# relaxation_1uts_c6,    1018/1225
# relaxation_1uts_c7,    1019/1225
# relaxation_1uts_c8,    1020/1225
# relaxation_1uts_c9,    1021/1225
# relaxation_1uui_c1,    1022/1225
# relaxation_1uui_c2,    1023/1225
# relaxation_1uui_c3,    1024/1225
# relaxation_1uui_c4,    1025/1225
# relaxation_1uui_c5,    1026/1225
# relaxation_1uui_c6,    1027/1225
# relaxation_1uui_c7,    1028/1225
# relaxation_1uui_c8,    1029/1225
# relaxation_1uui_c9,    1030/1225
# relaxation_1uuu_c1,    1031/1225
# relaxation_1uuu_c2,    1032/1225
# relaxation_1uuu_c3,    1033/1225
# relaxation_1uuu_c4,    1034/1225
# relaxation_1uuu_c5,    1035/1225
# relaxation_1uuu_c6,    1036/1225
# relaxation_1vop_c1,    1037/1225
# relaxation_1vop_c2,    1038/1225
# relaxation_1vop_c3,    1039/1225
# relaxation_1vop_c4,    1040/1225
# relaxation_1wks_c1,    1041/1225
# relaxation_1wks_c2,    1042/1225
# relaxation_1wks_c3,    1043/1225
# relaxation_1wks_c4,    1044/1225
# relaxation_1wks_c5,    1045/1225
# relaxation_1xhp_c10,    1046/1225
# relaxation_1xhp_c1,    1047/1225
# relaxation_1xhp_c2,    1048/1225
# relaxation_1xhp_c3,    1049/1225
# relaxation_1xhp_c4,    1050/1225
# relaxation_1xhp_c5,    1051/1225
# relaxation_1xhp_c6,    1052/1225
# relaxation_1xhp_c7,    1053/1225
# relaxation_1xhp_c8,    1054/1225
# relaxation_1xhp_c9,    1055/1225
# relaxation_1xsg_c1,    1056/1225
# relaxation_1xsg_c2,    1057/1225
# relaxation_1xsg_c3,    1058/1225
# relaxation_1xsg_c4,    1059/1225
# relaxation_1xsg_c5,    1060/1225
# relaxation_1xsg_c6,    1061/1225
# relaxation_1xsg_c7,    1062/1225
# relaxation_1xsg_c8,    1063/1225
# relaxation_1xsg_c9,    1064/1225
# relaxation_1xsh_c1,    1065/1225
# relaxation_1xsh_c2,    1066/1225
# relaxation_1xsh_c3,    1067/1225
# relaxation_1xsh_c4,    1068/1225
# relaxation_1xsh_c5,    1069/1225
# relaxation_1xsh_c6,    1070/1225
# relaxation_1xsh_c7,    1071/1225
# relaxation_1xsh_c8,    1072/1225
# relaxation_1xsh_c9,    1073/1225
# relaxation_1xst_c1,    1074/1225
# relaxation_1xst_c2,    1075/1225
# relaxation_1xst_c3,    1076/1225
# relaxation_1xst_c4,    1077/1225
# relaxation_1xst_c5,    1078/1225
# relaxation_1xst_c6,    1079/1225
# relaxation_1xst_c7,    1080/1225
# relaxation_1xst_c8,    1081/1225
# relaxation_1xst_c9,    1082/1225
# relaxation_1xsu_c1,    1083/1225
# relaxation_1xsu_c2,    1084/1225
# relaxation_1xsu_c3,    1085/1225
# relaxation_1xsu_c4,    1086/1225
# relaxation_1xsu_c5,    1087/1225
# relaxation_1xsu_c6,    1088/1225
# relaxation_1xsu_c7,    1089/1225
# relaxation_1xsu_c8,    1090/1225
# relaxation_1xsu_c9,    1091/1225
# relaxation_1xwp_c1,    1092/1225
# relaxation_1xwp_c2,    1093/1225
# relaxation_1xwp_c3,    1094/1225
# relaxation_1xwp_c4,    1095/1225
# relaxation_1xwp_c5,    1096/1225
# relaxation_1xwu_c1,    1097/1225
# relaxation_1xwu_c2,    1098/1225
# relaxation_1xwu_c3,    1099/1225
# relaxation_1xwu_c4,    1100/1225
# relaxation_1xwu_c5,    1101/1225
# relaxation_1y26_c10,    1102/1225
# relaxation_1y26_c11,    1103/1225
# relaxation_1y26_c12,    1104/1225
# relaxation_1y26_c13,    1105/1225
# relaxation_1y26_c14,    1106/1225
# relaxation_1y26_c15,    1107/1225
# relaxation_1y26_c16,    1108/1225
# relaxation_1y26_c17,    1109/1225
# relaxation_1y26_c18,    1110/1225
# relaxation_1y26_c19,    1111/1225
# relaxation_1y26_c1,    1112/1225
# relaxation_1y26_c20,    1113/1225
# relaxation_1y26_c21,    1114/1225
# relaxation_1y26_c22,    1115/1225
# relaxation_1y26_c23,    1116/1225
# relaxation_1y26_c2,    1117/1225
# relaxation_1y26_c3,    1118/1225
# relaxation_1y26_c4,    1119/1225
# relaxation_1y26_c5,    1120/1225
# relaxation_1y26_c6,    1121/1225
# relaxation_1y26_c7,    1122/1225
# relaxation_1y26_c8,    1123/1225
# relaxation_1y26_c9,    1124/1225
# relaxation_1ylg_c10,    1125/1225
# relaxation_1ylg_c1,    1126/1225
# relaxation_1ylg_c2,    1127/1225
# relaxation_1ylg_c3,    1128/1225
# relaxation_1ylg_c4,    1129/1225
# relaxation_1ylg_c5,    1130/1225
# relaxation_1ylg_c6,    1131/1225
# relaxation_1ylg_c7,    1132/1225
# relaxation_1ylg_c8,    1133/1225
# relaxation_1ylg_c9,    1134/1225
# relaxation_1ymo_c10,    1135/1225
# relaxation_1ymo_c11,    1136/1225
# relaxation_1ymo_c12,    1137/1225
# relaxation_1ymo_c13,    1138/1225
# relaxation_1ymo_c14,    1139/1225
# relaxation_1ymo_c15,    1140/1225
# relaxation_1ymo_c1,    1141/1225
# relaxation_1ymo_c2,    1142/1225
# relaxation_1ymo_c3,    1143/1225
# relaxation_1ymo_c4,    1144/1225
# relaxation_1ymo_c5,    1145/1225
# relaxation_1ymo_c6,    1146/1225
# relaxation_1ymo_c7,    1147/1225
# relaxation_1ymo_c8,    1148/1225
# relaxation_1ymo_c9,    1149/1225
# relaxation_1yn1_c1,    1150/1225
# relaxation_1yn1_c2,    1151/1225
# relaxation_1yn1_c3,    1152/1225
# relaxation_1yn1_c4,    1153/1225
# relaxation_1yn1_c5,    1154/1225
# relaxation_1yn2_c1,    1155/1225
# relaxation_1yn2_c2,    1156/1225
# relaxation_1yn2_c3,    1157/1225
# relaxation_1yn2_c4,    1158/1225
# relaxation_1yn2_c5,    1159/1225
# relaxation_1ync_c10,    1160/1225
# relaxation_1ync_c1,    1161/1225
# relaxation_1ync_c2,    1162/1225
# relaxation_1ync_c3,    1163/1225
# relaxation_1ync_c4,    1164/1225
# relaxation_1ync_c5,    1165/1225
# relaxation_1ync_c6,    1166/1225
# relaxation_1ync_c7,    1167/1225
# relaxation_1ync_c8,    1168/1225
# relaxation_1ync_c9,    1169/1225
# relaxation_1yne_c10,    1170/1225
# relaxation_1yne_c1,    1171/1225
# relaxation_1yne_c2,    1172/1225
# relaxation_1yne_c3,    1173/1225
# relaxation_1yne_c4,    1174/1225
# relaxation_1yne_c5,    1175/1225
# relaxation_1yne_c6,    1176/1225
# relaxation_1yne_c7,    1177/1225
# relaxation_1yne_c8,    1178/1225
# relaxation_1yne_c9,    1179/1225
# relaxation_1yng_c10,    1180/1225
# relaxation_1yng_c1,    1181/1225
# relaxation_1yng_c2,    1182/1225
# relaxation_1yng_c3,    1183/1225
# relaxation_1yng_c4,    1184/1225
# relaxation_1yng_c5,    1185/1225
# relaxation_1yng_c6,    1186/1225
# relaxation_1yng_c7,    1187/1225
# relaxation_1yng_c8,    1188/1225
# relaxation_1yng_c9,    1189/1225
# relaxation_1ysv_c1,    1190/1225
# relaxation_1ysv_c2,    1191/1225
# relaxation_1ysv_c3,    1192/1225
# relaxation_1ysv_c4,    1193/1225
# relaxation_1ysv_c5,    1194/1225
# relaxation_1ysv_c6,    1195/1225
# relaxation_1ysv_c7,    1196/1225
# relaxation_1ysv_c8,    1197/1225
# relaxation_1ysv_c9,    1198/1225
# relaxation_1z2j_c10,    1199/1225
# relaxation_1z2j_c11,    1200/1225
# relaxation_1z2j_c12,    1201/1225
# relaxation_1z2j_c13,    1202/1225
# relaxation_1z2j_c14,    1203/1225
# relaxation_1z2j_c15,    1204/1225
# relaxation_1z2j_c1,    1205/1225
# relaxation_1z2j_c2,    1206/1225
# relaxation_1z2j_c3,    1207/1225
# relaxation_1z2j_c4,    1208/1225
# relaxation_1z2j_c5,    1209/1225
# relaxation_1z2j_c6,    1210/1225
# relaxation_1z2j_c7,    1211/1225
# relaxation_1z2j_c8,    1212/1225
# relaxation_1z2j_c9,    1213/1225
# relaxation_1z30_c1,    1214/1225
# relaxation_1z30_c2,    1215/1225
# relaxation_1z30_c3,    1216/1225
# relaxation_1z30_c4,    1217/1225
# relaxation_1z30_c5,    1218/1225
# relaxation_1z30_c6,    1219/1225
# relaxation_1z31_c10,    1220/1225
# relaxation_1z31_c1,    1221/1225
# relaxation_1z31_c2,    1222/1225
# relaxation_1z31_c3,    1223/1225
# relaxation_1z31_c4,    1224/1225
# relaxation_1z31_c6,    1225/1225
# ({'R4-P': [0.38609883189201355,
#    0.38809868693351746,
#    0.3719944655895233,
#    0.3815794587135315,
#    0.38735103607177734,
#    0.3907195031642914,
#    0.38682135939598083,
#    0.3891684114933014,
#    0.3872720003128052,
#    0.3904520571231842,
#    0.37703368067741394,
#    0.38233843445777893,
#    0.3848872780799866,
#    0.38457179069519043,
#    0.3861944079399109,
#    0.38282114267349243,
#    0.3889663517475128,
#    0.3771197497844696,
#    0.3848872780799866,
#    0.38457179069519043,
#    0.3861944079399109,
#    0.38282114267349243,
#    0.3889663517475128,
#    0.3771197497844696,
#    0.38404205441474915,
#    0.38548544049263,
#    0.38844746351242065,
#    0.37930142879486084,
#    0.3833175301551819,
#    0.381661057472229,
#    0.3870902359485626,
#    0.3775410056114197,
#    0.3810563087463379,
#    0.3838818669319153,
#    0.3854227364063263,
#    0.3860766589641571,
#    0.38046881556510925,
#    0.3865734040737152,
#    0.3818809688091278,
#    0.3791470229625702,
#    0.38714590668678284,
#    0.38709384202957153,
#    0.3837641477584839,
#    0.38200828433036804,
#    0.37856361269950867,
#    0.38707205653190613,
#    0.3845382332801819,
#    0.38033387064933777,
#    0.39258989691734314,
#    0.3843618333339691,
#    0.38585129380226135,
#    0.38695308566093445,
#    0.3918420672416687,
#    0.38370653986930847,
#    0.38277769088745117,
# %%
# functions to generate subplots with the correct dimensions

def choose_subplot_dimensions(k):
    if k < 5:
        return k, 1
    elif k < 11:
        return math.ceil(k/3), 4
    else:
        # I've chosen to have a maximum of 3 columns
        return math.ceil(k/4), 4


def generate_subplots(k, row_wise=False):
    nrow, ncol = choose_subplot_dimensions(k)
    # Choose your share X and share Y parameters as you wish:
    figure, axes = plt.subplots(nrow, ncol,
                                sharex=False,
                                sharey=False,
                                figsize=(17,10))  # (17,17) for dihedrals, (17,10) for angles and bonds

    # Check if it's an array. If there's only one plot, it's just an Axes obj
    if not isinstance(axes, np.ndarray):
        return figure, [axes]
    else:
        # Choose the traversal you'd like: 'F' is col-wise, 'C' is row-wise
        axes = axes.flatten(order=('C' if row_wise else 'F'))

        # Delete any unused axes from the figure, so that they don't show
        # blank x- and y-axis lines
        for idx, ax in enumerate(axes[k:]):
            figure.delaxes(ax)

            # Turn ticks on for the last ax in each column, wherever it lands
            idx_to_turn_on_ticks = idx + k - ncol if row_wise else idx + k - 1
            for tk in axes[idx_to_turn_on_ticks].get_xticklabels():
                tk.set_visible(True)

        axes = axes[:k]
        return figure, axes

# %%
## Bonds plot

bonds_true = pickle.load(open('Amber/bonds.pkl','rb'))
bonds_free = pickle.load(open('FreeMin/bonds.pkl','rb'))
bonds_old = pickle.load(open('HiRE_old/bonds.pkl','rb'))
bonds_psgd = pickle.load(open('PSGD/bonds.pkl','rb'))
bonds_nogeom = pickle.load(open('NoGeom/bonds.pkl','rb'))

# %%
for i,k in enumerate(bonds_true):
    print(i,k)
# Out:
# 0 P-O
# 1 O-C
# 2 C-R4
# 3 R4-P
# 4 R4-R1
# 5 R1-C1
# 6 R1-U1
# 7 R1-A1
# 8 R1-G1
# 9 A1-A2
# 10 G1-G2

# %%
kde_kws = {'shade': True, 'alpha':0.3, 'linewidth': 1, 'bw':0.1}

figure, axes = generate_subplots(len(bonds_true), row_wise=True)
for i, key in enumerate(bonds_true):
    sns.distplot(ax = axes[i], x=np.array(bonds_true[key])*10, hist = False, kde = True,
        kde_kws = {'shade': True, 'alpha':0.1, 'linewidth': 2, 'bw':0.1, 'linestyle':'--'},
                 label='Amber', color='firebrick')
    # sns.distplot(ax = axes[i], x=bonds_old[key], hist = False, kde = True,
    #    kde_kws = kde_kws, label='HiRE old', color='y')
    sns.distplot(ax = axes[i], x=np.array(bonds_free[key])*10, hist = False, kde = True,
        kde_kws = kde_kws, label='Free min', color='b')
    sns.distplot(ax = axes[i], x=np.array(bonds_psgd[key])*10, hist = False, kde = True,
        kde_kws = kde_kws, label='PSGD') #, color='olivedrab')
    sns.distplot(ax = axes[i], x=np.array(bonds_nogeom[key])*10, hist = False, kde = True,
        kde_kws = kde_kws, label='NG' , color='darkmagenta')
    axes[i].set_title(key+' bond', fontsize=13)
    axes[i].set_ylabel('')
    axes[i].grid(linewidth=0.3)
    # axes[i].yaxis.set_major_formatter(FormatStrFormatter('%.3f'))
    axes[i].xaxis.set_major_formatter(FormatStrFormatter('%.3f'))
    # axes[i].yaxis.set_major_formatter(NullFormatter())
    axes[i].tick_params(axis='both', which='major', labelsize=11)
    # axes[i].tick_params(axis='y', which='major', left=False, right=False)
    axes[i].xaxis.set_major_formatter(FormatStrFormatter('%.2f'))
axes[10].legend(bbox_to_anchor=(1.9,0.9),fontsize=15)

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.3, 
                    hspace=0.3)
axes[8].set_xlabel(r'Bond length ($\AA$)',fontsize=15)
axes[9].set_xlabel(r'Bond length ($\AA$)',fontsize=15)
axes[10].set_xlabel(r'Bond length ($\AA$)',fontsize=15)

axes[0].set_ylabel('Density',fontsize=15)
axes[4].set_ylabel('Density',fontsize=15)
axes[8].set_ylabel('Density',fontsize=15)

plt.savefig('bond_distribution.png',bbox_inches='tight',dpi=100)

# %%
# Variation in mean values

true_mean = [np.array(bonds_true[key]).mean() for key in bonds_true]
free_mean = [np.array(bonds_free[key]).mean() for key in bonds_free]
old_mean = [np.array(bonds_old[key]).mean() for key in bonds_old]
psgd_mean = [np.array(bonds_psgd[key]).mean() for key in bonds_psgd]
nogeom_mean = [np.array(bonds_nogeom[key]).mean() for key in bonds_nogeom]

bond_mean = np.array([true_mean,old_mean,free_mean,psgd_mean,nogeom_mean])
print(bond_mean.shape)

x = np.arange(1,12)
plt.scatter(x,bond_mean[0],marker = 'o')
plt.scatter(x,bond_mean[1],marker = '*')
plt.scatter(x,bond_mean[2], marker = 'v')
plt.scatter(x,bond_mean[3], marker = '^')
plt.scatter(x,bond_mean[4])
plt.grid(axis='x',linewidth=0.2)
# Out:
# (5, 11)

# %%
## Angles

angles_true = pickle.load(open('Amber/angles.pkl','rb'))
angles_free = pickle.load(open('FreeMin/angles.pkl','rb'))
angles_old = pickle.load(open('HiRE_old/angles.pkl','rb'))
angles_psgd = pickle.load(open('PSGD/angles.pkl','rb'))
angles_nogeom = pickle.load(open('NoGeom/angles.pkl','rb'))

# %%
kde_kws = {'shade': True, 'alpha':0.3, 'linewidth': 1, 'bw':0.1}

figure, axes = generate_subplots(len(angles_true), row_wise=True)
for i, key in enumerate(angles_true):
    sns.distplot(ax = axes[i], x=angles_true[key], hist = False, kde = True,
        kde_kws = {'shade': True, 'alpha':0.1, 'linewidth': 2, 'bw':0.1, 'linestyle':'--'},
                 label='Amber', color='firebrick')
    # sns.distplot(ax = axes[i], x=angles_old[key], hist = False, kde = True,
    #     kde_kws = {'shade': True, 'linewidth': 1, 'bw':0.1}, label='HiRE old')
    sns.distplot(ax = axes[i], x=angles_free[key], hist = False, kde = True,
        kde_kws = kde_kws, label='Free min', color='b')
    sns.distplot(ax = axes[i], x=angles_psgd[key], hist = False, kde = True,
        kde_kws = kde_kws, label='PSGD')
    sns.distplot(ax = axes[i], x=angles_nogeom[key], hist = False, kde = True,
        kde_kws = kde_kws, label='NG', color='darkmagenta')
    axes[i].set_title(key+' angle', fontsize=13)
    axes[i].set_ylabel('')
    axes[i].grid(linewidth=0.3)
    # axes[i].yaxis.set_major_formatter(FormatStrFormatter('%.3f'))
    axes[i].xaxis.set_major_formatter(FormatStrFormatter('%.2f'))
axes[11].legend(bbox_to_anchor=(1.1,0.9),fontsize=15)
axes[2].set_xlim([1,3.5])
axes[4].set_xlim([1.9,2.2])
axes[5].set_xlim([1.9,2])
axes[6].set_xlim([2,2.3])

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.3, 
                    hspace=0.3)

axes[8].set_xlabel('Angle amplitude (rad)',fontsize=15)
axes[9].set_xlabel('Angle amplitude (rad)',fontsize=15)
axes[10].set_xlabel('Angle amplitude (rad)',fontsize=15)
axes[11].set_xlabel('Angle amplitude (rad)',fontsize=15)

axes[0].set_ylabel('Density',fontsize=15)
axes[4].set_ylabel('Density',fontsize=15)
axes[8].set_ylabel('Density',fontsize=15)

plt.savefig('angles_distribution.png',bbox_inches='tight',dpi=100)

# %%
## Torsions

dihedrals_true = pickle.load(open('Amber/dihedrals.pkl','rb'))
dihedrals_free = pickle.load(open('FreeMin/dihedrals.pkl','rb'))
dihedrals_old = pickle.load(open('HiRE_old/dihedrals.pkl','rb'))
dihedrals_psgd = pickle.load(open('PSGD/dihedrals.pkl','rb'))
dihedrals_nogeom = pickle.load(open('NoGeom/dihedrals.pkl','rb'))

# %%
kde_kws = {'shade': True, 'alpha':0.3, 'linewidth': 1, 'clip': (-math.pi, math.pi), 'bw':0.05}

figure, axes = generate_subplots(len(dihedrals_true), row_wise=True)
for i, key in enumerate(dihedrals_true):
    sns.distplot(ax = axes[i], x=dihedrals_true[key], hist=False, kde=True,
        kde_kws = {'shade': True, 'alpha':0.1, 'linewidth': 2, 'clip': (-math.pi, math.pi),
                   'bw':0.05, 'linestyle':'--'}, label='Amber', color='firebrick')
    # sns.distplot(ax = axes[i], x=dihedrals_old[key], hist = False, kde = True,
    #     kde_kws = {'shade': True, 'linewidth': 1, 'clip': (-math.pi, math.pi), 'bw':0.05}, label='HiRE old')
    sns.distplot(ax = axes[i], x=dihedrals_free[key], hist = False, kde = True,
        kde_kws = kde_kws, label='Free min', color='b')
    sns.distplot(ax = axes[i], x=dihedrals_psgd[key], hist = False, kde = True,
        kde_kws = kde_kws, label='PSGD')
    sns.distplot(ax = axes[i], x=dihedrals_nogeom[key], hist = False, kde = True,
        kde_kws = kde_kws, label='NG', color='darkmagenta')
    axes[i].set_title(key+' dihedral', fontsize=13)
    axes[i].set_ylabel('')
    axes[i].grid(linewidth=0.3)
    # axes[i].yaxis.set_major_formatter(FormatStrFormatter('%.3f'))
    axes[i].xaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    
    xlim_old = axes[i].get_xlim()
    if xlim_old[0] < -math.pi or xlim_old[1] > math.pi:
        axes[i].set_xlim([-math.pi,math.pi])
axes[17].legend(bbox_to_anchor=(1.9,0.9),fontsize=15)

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.3, 
                    hspace=0.3)

axes[16].set_xlabel('Dihedral amplitude (rad)',fontsize=15)
axes[17].set_xlabel('Dihedral amplitude (rad)',fontsize=15)

axes[0].set_ylabel('Density',fontsize=15)
axes[4].set_ylabel('Density',fontsize=15)
axes[8].set_ylabel('Density',fontsize=15)
axes[12].set_ylabel('Density',fontsize=15)
axes[16].set_ylabel('Density',fontsize=15)

plt.savefig('dihedrals_distribution.png',bbox_inches='tight',dpi=100)
