# %%
from __future__ import print_function, division
import time
import torch
import pickle
from tqdm.notebook import tqdm
from IPython.utils import io
import torch.nn as nn
from torch.nn import Parameter
import LocalEnergyVct as le
import numpy as np
from torch.utils.data import DataLoader, random_split
from data_classes import RNASeqDataset # , LocalEnergyOpt
from sklearn.metrics import r2_score
# from my_script import get_target, loss_fn, train, test
import matplotlib.pyplot as plt
plt.style.use('bmh')

# %%
class LocalEnergyOpt(nn.Module):

    def __init__(self,fixed_pars,opt_pars,device,set_to_one=False):
        super(LocalEnergyOpt, self).__init__()
        if set_to_one:
            fixed_pars['bond_type'][:,0] = 1.
            fixed_pars['angle_type'][:,0] = 1.
            fixed_pars['torsion_type'][:,0] = 1.
        self.device = device
        self.opt_pars = Parameter(torch.tensor(opt_pars, dtype=torch.float, device=self.device, requires_grad=True))
        self.bond_type = Parameter(torch.tensor(fixed_pars['bond_type'], dtype=torch.float, device=self.device, requires_grad=True))
        self.angle_type = Parameter(torch.tensor(fixed_pars['angle_type'], dtype=torch.float, device=self.device, requires_grad=True))
        self.tor_type = Parameter(torch.tensor(fixed_pars['torsion_type'][:,(0,2)], dtype=torch.float, device=self.device, requires_grad=True))
        self.multiplicity = torch.tensor(fixed_pars['torsion_type'][:,1], dtype=torch.int64, device=self.device, requires_grad=False)


    def forward(self,X):

        X_lengths = X['lengths']
        X_features = X['features']

        if len(X_lengths.shape) == 1:
            X_lengths = X_lengths.unsqueeze(0)
            X_features = X_features.unsqueeze(0)
        
        batch_size = X_lengths.shape[0]
        energy = torch.zeros(batch_size,3,device=self.device)

        for i in range(X_lengths.shape[0]):
            lengths = X_lengths[i]
            features = X_features[i]
            atoms = features[:lengths[0],0].long()
            # res_labels
            # res_pointer
            # mass
            # charge
            coords = features[:lengths[5],5].view(-1,3)
            bonds = features[:lengths[6],6].long().view(-1,3)
            angles = features[:lengths[7],7].long().view(-1,4)
            tors = features[:lengths[8],8].long().view(-1,5)
            energy[i,0] = le.bonds_energy(coords,bonds,self.bond_type,self.opt_pars)
            energy[i,1] = le.angles_energy(atoms,coords,angles,self.angle_type,self.opt_pars)
            energy[i,2] = le.torsions_energy(atoms,coords,tors,self.tor_type,self.multiplicity,self.opt_pars)
            
        energy = energy.sum(dim=0).squeeze() / batch_size
        return energy

# %%
def get_target(X):
    if len(X['features'].shape) == 2:
        X['features'] = X['features'].unsqueeze(0)
    target = (X['features'][:,0:3,9]).sum(dim=0).squeeze() / X['features'].shape[0]
    return target


# Functions without gradients in the loss

def loss_fn(energy,target):
    # batch_size = energy.shape[0]
    loss = (energy - target).pow(2).sum()  # / batch_size
    return loss


def train(dataloader, model, loss_fn, optimizer):
    num_batches = len(dataloader)
    model.train()
    train_loss = 0
    y_true = torch.zeros((num_batches,3))
    y_pred = torch.zeros((num_batches,3))
    for i,X in enumerate(dataloader):
        pred = model(X)
        target = get_target(X)
        y_true[i] = target.reshape(-1,)  # requires drop_last = True
        y_pred[i] = pred.reshape(-1,)
        loss = loss_fn(pred, target)
        train_loss += loss.item()
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    y_true = y_true.detach().numpy()
    y_pred = y_pred.detach().numpy()
    acc = r2_score(y_true,y_pred)
    train_loss /= num_batches
    print(f'Avg loss = {train_loss:>0.4f}, batches = {num_batches}')
    return train_loss, acc


def test(dataloader, model, loss_fn):
    num_batches = len(dataloader)
    model.eval()
    test_loss = 0
    y_true = torch.zeros((num_batches,3))
    y_pred = torch.zeros((num_batches,3))
    with torch.no_grad():
        for i,X in enumerate(dataloader):
            pred = model(X)
            target = get_target(X)
            y_true[i] = target.reshape(-1,) # requires drop_last = True
            y_pred[i] = pred.reshape(-1,)
            loss = loss_fn(pred, target)
            test_loss += loss.item()
    y_true = y_true.detach().numpy()
    y_pred = y_pred.detach().numpy()
    acc = r2_score(y_true,y_pred)
    test_loss /= num_batches
    print(f'Avg test_loss = {test_loss:>0.4f}, batches = {num_batches}')
    return test_loss, acc


def KL_divergence(hist1,hist2):
    # div(p,q) = sum_x p(x) * log(p(x)/q(x))
    # hist[1]: bin limits
    # hist[0]: y value
    p_x = hist1[0] * np.diff(hist1[1])
    q_x = hist2[0] * np.diff(hist2[1])
    cond = (q_x>0) & (p_x>0)
    div = np.sum( -p_x[cond] * np.log(q_x[cond]/p_x[cond]))
    return div


def plot_hist(idx_dict,energies):
    fig,ax = plt.subplots(1,3,figsize=(18,5))
    for i in idx_dict.keys():
        hist1 = ax[i].hist(energies['amber'][i], bins=30, density=True, label='Amber')
        ax[i].hist(energies['hire'][i], bins=hist1[1], alpha=0.6, density=True, label='HiRE')
        ax[i].set_xlabel(idx_dict[i]+' energy', fontsize=15)
        ax[i].set_ylabel('Prob. distribution', fontsize=15)
        ax[i].set_title(idx_dict[i]+' energy distribution', fontsize=18)
        ax[i].legend(fontsize=15)
    return 0


def compare_energies(dataset,model,plot=False):
    
    idx_dict = {
        0: 'Bonds',
        1: 'Angles',
        2: 'Torsions'
    }
    energies = {'amber': [], 'hire': []}
    stats = {'amber': [], 'hire': []}
    for i in idx_dict.keys():
        amber_en = np.array([dataset[j]['features'][i,9].item() for j in range(len(dataset))])
        hire_en = np.array([model(dataset[j]).squeeze()[i].item() for j in range(len(dataset))])
        energies['amber'].append(amber_en)
        energies['hire'].append(hire_en)
        stats['amber'].append([amber_en.mean(), amber_en.var()])
        stats['hire'].append([hire_en.mean(), hire_en.var()])
        print(idx_dict[i]+' energy computed')
    stats['amber'] = np.array(stats['amber'])
    stats['hire'] = np.array(stats['hire'])
    
    if plot:
        plot_hist(idx_dict,energies)
        
    return energies,stats

# %%
def KL_tensor_divergence(hist1,hist2):
    # div(p,q) = sum_x p(x) * log(p(x)/q(x))
    # hist[1]: bin limits
    # hist[0]: y value
    p_x = hist1[0] * torch.diff(hist1[1])
    q_x = hist2[0] * torch.diff(hist2[1])
    cond = (q_x>0) & (p_x>0)
    div = torch.sum( -p_x[cond] * torch.log(q_x[cond]/p_x[cond]))
    return div


def TotVarDist(hist1,hist2):
    return torch.sum(torch.abs(hist1[0]-hist2[0]) * torch.diff(hist1[1])).item()


def get_amber_hist(dataset):
    n_bins = 30
    amber_hist_bins = torch.zeros((3,n_bins+1))
    amber_hist_values = torch.zeros((3,n_bins))
    for i in range(3):
        amber_en = torch.tensor([dataset[j]['features'][i,9].item() for j in range(len(dataset))])
        amber_hist_values[i], amber_hist_bins[i] = torch.histogram(amber_en, bins=n_bins, density=True)
    return (amber_hist_values, amber_hist_bins)


def KL_train(dataloader, model, loss_fn, optimizer, amber_hist):
    num_batches = len(dataloader)
    train_loss = 0
    y_pred = torch.zeros((len(dataloader.dataset),3))
    KL_score = 0
    model.train()    
    for i,X in enumerate(dataloader):
        pred = model(X)
        target = get_target(X)
        y_pred[i: i+dataloader.batch_size] = pred
        loss = loss_fn(pred, target)
        train_loss += loss.item()
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    train_loss /= num_batches
    
    for i in range(3):
        hist1 = (amber_hist[0][i],amber_hist[1][i])
        hist2 = torch.histogram(y_pred[:,i], bins=hist1[1], density=True)
        KL_score += TotVarDist(hist1,hist2)  # KL_tensor_divergence(hist1,hist2)
        
    print(f'Avg loss = {train_loss:>0.4f}, batches = {num_batches}')
    return train_loss, KL_score


def KL_test(dataloader, model, loss_fn, amber_hist):
    num_batches = len(dataloader)
    test_loss = 0
    y_pred = torch.zeros((len(dataloader.dataset),3))
    KL_score = 0
    model.eval()
    with torch.no_grad():
        for i,X in enumerate(dataloader):
            pred = model(X)
            target = get_target(X)
            y_pred[i: i+dataloader.batch_size] = pred
            loss = loss_fn(pred, target)
            test_loss += loss.item()
    
    for i in range(3):
        hist1 = (amber_hist[0][i],amber_hist[1][i])
        hist2 = torch.histogram(y_pred[:,i], bins=hist1[1], density=True)
        KL_score += TotVarDist(hist1,hist2)  # KL_tensor_divergence(hist1,hist2)
    
    test_loss /= num_batches
    print(f'Avg test_loss = {test_loss:>0.4f}, batches = {num_batches}')
    return test_loss, KL_score

# %%
# CUDA for Pytorch
print(torch.cuda.is_available())
# device = torch.device("cuda" if torch.cuda.is_available() else 'cpu')
device ='cpu'
# Out:
# False

# %%
# Parameters
params = {'batch_size': 1,
          'shuffle': True,
          'drop_last': True,
          'num_workers': 0,
          'pin_memory': False}

# Datasets and Dataloaders
seq_data = RNASeqDataset(device=device)
print(f'dataset allocated on {device}')
tot_length = len(seq_data)
test_length = int(0.2 * tot_length)
train_set, test_set = random_split(seq_data, [tot_length - test_length, test_length])  #, generator=torch.Generator().manual_seed(42))
print(f'Training set: {len(train_set)} elements')
print(f'Test set: {len(test_set)} elements')
train_dataloader = DataLoader(train_set,**params)
test_dataloader = DataLoader(test_set,**params)

fixed_pars = pickle.load(open('data/SeqCSV/fixed_pars.p', 'rb'))
opt_pars = pickle.load(open('data/SeqCSV/pars.p', 'rb'))

# set parameters to the same order of magnitude
fixed_pars['bond_type'][:,0] /= 100
fixed_pars['angle_type'][:,0] /= 100

model = LocalEnergyOpt(fixed_pars,opt_pars,device).to(device)
torch.save(model.state_dict(), 'data/Results/initial_values_sameorder.pth')

my_loss = loss_fn  # _with_grad
my_train = train  # _with_grad
my_test = test  # _with_grad

for p in model.parameters():
    print(p)
# Out:
# dataset allocated on cpu
# Training set: 1311 elements
# Test set: 327 elements
# Parameter containing:
# tensor([  2.6080,   2.0730,   1.5190,   2.3550,   4.1900,   4.6980,   4.8240,
#           5.6360,   2.1300,   1.3070,  15.2230,   1.0000,   2.8000,   2.5050,
#           1.8260,   3.9320,   4.3090,   4.7750,   4.5460,   2.8210,   3.8130,
#           3.0100,   0.9080,   3.0000,   4.0000,   2.2570,   0.4800,   0.5000,
#           4.2470,  10.8160,  11.1210,   5.8190,   0.5010,   0.7300,   0.3310,
#           0.2570,   0.2240,   0.2070,   1.2000,   1.5000,   0.4000,   1.8000,
#           0.8000, 142.3060,   1.0000,   0.0000,   1.4830], requires_grad=True)
# Parameter containing:
# tensor([[ 0.3000,  3.8000],
#         [ 2.0000,  2.3440],
#         [ 2.0000,  2.6220],
#         [ 2.0000,  2.6330],
#         [ 2.0000,  3.0620],
#         [ 2.0000,  3.0040],
#         [ 2.0000,  2.4500],
#         [ 2.0000,  2.1800],
#         [ 2.0000,  1.5200],
#         [ 2.0000,  1.5930],
#         [ 2.0000,  1.4300],
#         [ 0.4000, 12.0000],
#         [ 0.1000, 12.0000],
#         [ 0.1000, 12.0000],
#         [ 0.1000, 12.0000]], requires_grad=True)
# Parameter containing:
# tensor([[0.7000, 2.1572],
#         [0.7000, 2.3126],
#         [0.7000, 2.1555],
#         [0.7000, 2.2881],
#         [1.2000, 2.0368],
#         [1.2000, 1.9408],
#         [0.7000, 2.1450],
#         [0.7000, 1.9303],
#         [0.7000, 1.7104],
#         [0.5000, 1.9199],
#         [0.7000, 2.3649],
#         [1.0000, 1.7104],
#         [0.8000, 3.1416]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.0000, -0.3491],
#         [ 0.2000, -2.7925],
#         [ 1.0000, -0.3491],
#         [ 0.2000, -2.7925],
#         [ 1.0000, -2.8798],
#         [ 1.0000, -2.8798],
#         [ 1.0000, -2.6180],
#         [ 0.2000,  2.6180],
#         [ 1.0000, -2.6180],
#         [ 1.0000, -2.6180],
#         [ 0.2000,  2.6180],
#         [ 1.0000, -2.6180],
#         [ 0.2000,  2.6180],
#         [ 1.0000,  1.7453],
#         [ 1.0000,  1.7453],
#         [ 1.0000,  1.7453],
#         [ 1.0000,  1.7453],
#         [ 1.2000,  0.3491],
#         [ 1.2000,  2.7925],
#         [ 1.0000,  1.5708],
#         [ 1.0000,  2.6180],
#         [ 0.3300,  0.0000],
#         [ 0.1250,  3.1416],
#         [ 0.8300,  0.0000],
#         [ 1.0000,  0.0000]], requires_grad=True)

# %%
lr = 1e-4
adam_optimizer = torch.optim.Adam(model.parameters(), lr=lr)
train_loss_adam = []
test_loss_adam = []
train_acc_adam = []
test_acc_adam = []

epochs = 150
for index_epoch in range(epochs):
    print(f'epoch {index_epoch+1}/{epochs} \n-------------------------')
    t0 = time.time()
    with io.capture_output() as captured:
        train_tmp, train_acc_tmp = my_train(train_dataloader, model, my_loss, adam_optimizer)
        test_tmp, test_acc_tmp = my_test(test_dataloader, model, my_loss)
    tf = time.time()
    print(f'Avg train loss = {train_tmp:.4f}, train accuracy = {train_acc_tmp:.4f}')
    print(f'Avg test loss = {test_tmp:.4f}, test accuracy = {test_acc_tmp:.4f}' )
    print(f'time for epoch: {tf-t0:.2f} \n')
    train_loss_adam.append(train_tmp)
    test_loss_adam.append(test_tmp)
    train_acc_adam.append(train_acc_tmp)
    test_acc_adam.append(test_acc_tmp)
    
torch.save(model.state_dict(), 'data/Results/150_b1_e4_Aso.pth')  # epochs_batchsize_lr_A/SGD + all1/so/~

for p in model.parameters():
    print(p.data)
# Out:
# epoch 1/150
# -------------------------
# Avg train loss = 18014.7152, train accuracy = -75.8037
# Avg test loss = 14294.4660, test accuracy = -52.3320
# time for epoch: 2.53
#
# epoch 2/150
# -------------------------
# Avg train loss = 10830.8118, train accuracy = -34.3981
# Avg test loss = 7049.6913, test accuracy = -19.8431
# time for epoch: 2.45
#
# epoch 3/150
# -------------------------
# Avg train loss = 4892.0933, train accuracy = -13.2020
# Avg test loss = 2831.8291, test accuracy = -8.1167
# time for epoch: 2.43
#
# epoch 4/150
# -------------------------
# Avg train loss = 2249.1690, train accuracy = -6.2456
# Avg test loss = 1670.4626, test accuracy = -4.9428
# time for epoch: 2.40
#
# epoch 5/150
# -------------------------
# Avg train loss = 1581.1540, train accuracy = -4.4109
# Avg test loss = 1372.2971, test accuracy = -4.0386
# time for epoch: 2.41
#
# epoch 6/150
# -------------------------
# Avg train loss = 1305.1113, train accuracy = -3.5889
# Avg test loss = 1165.4798, test accuracy = -3.3874
# time for epoch: 2.59
#
# epoch 7/150
# -------------------------
# Avg train loss = 1096.0817, train accuracy = -2.9507
# Avg test loss = 989.3172, test accuracy = -2.8235
# time for epoch: 2.41
#
# epoch 8/150
# -------------------------
# Avg train loss = 921.0400, train accuracy = -2.4103
# Avg test loss = 837.9958, test accuracy = -2.3413
# time for epoch: 2.41
#
# epoch 9/150
# -------------------------
# Avg train loss = 773.9110, train accuracy = -1.9556
# Avg test loss = 710.5788, test accuracy = -1.9281
# time for epoch: 2.49
#
# epoch 10/150
# -------------------------
# Avg train loss = 650.9313, train accuracy = -1.5724
# Avg test loss = 603.2323, test accuracy = -1.5782
# time for epoch: 2.42
#
# epoch 11/150
# -------------------------
# Avg train loss = 547.8041, train accuracy = -1.2452
# Avg test loss = 511.1124, test accuracy = -1.2767
# time for epoch: 2.48
#
# epoch 12/150
# -------------------------
# Avg train loss = 462.9983, train accuracy = -0.9743
# Avg test loss = 435.5323, test accuracy = -1.0252
# time for epoch: 2.40
#
# epoch 13/150
# -------------------------
# Avg train loss = 393.0268, train accuracy = -0.7480
# Avg test loss = 373.5840, test accuracy = -0.8151
# time for epoch: 2.42
#
# epoch 14/150
# -------------------------
# Avg train loss = 335.8630, train accuracy = -0.5609
# Avg test loss = 320.3163, test accuracy = -0.6357
# time for epoch: 2.41
#
# epoch 15/150
# -------------------------
# Avg train loss = 289.0461, train accuracy = -0.4064
# Avg test loss = 278.2812, test accuracy = -0.4898
# time for epoch: 2.41
#
# epoch 16/150
# -------------------------
# Avg train loss = 251.5772, train accuracy = -0.2790
# Avg test loss = 243.8598, test accuracy = -0.3714
# time for epoch: 2.41
#
# epoch 17/150
# -------------------------
# Avg train loss = 220.6185, train accuracy = -0.1766
# Avg test loss = 214.5689, test accuracy = -0.2673
# time for epoch: 2.41
#
# epoch 18/150
# -------------------------
# Avg train loss = 196.9999, train accuracy = -0.0932
# Avg test loss = 191.8093, test accuracy = -0.1861
# time for epoch: 2.40
#
# epoch 19/150
# -------------------------
# Avg train loss = 177.4245, train accuracy = -0.0240
# Avg test loss = 174.1055, test accuracy = -0.1198
# time for epoch: 2.41
#
# epoch 20/150
# -------------------------
# Avg train loss = 162.0284, train accuracy = 0.0310
# Avg test loss = 158.7813, test accuracy = -0.0630
# time for epoch: 2.41
#
# epoch 21/150
# -------------------------
# Avg train loss = 149.4592, train accuracy = 0.0788
# Avg test loss = 146.7459, test accuracy = -0.0163
# time for epoch: 2.40
#
# epoch 22/150
# -------------------------
# Avg train loss = 139.2541, train accuracy = 0.1166
# Avg test loss = 137.1379, test accuracy = 0.0217
# time for epoch: 2.41
#
# epoch 23/150
# -------------------------
# Avg train loss = 130.3069, train accuracy = 0.1509
# Avg test loss = 128.7430, test accuracy = 0.0516
# time for epoch: 2.40
#
# epoch 24/150
# -------------------------
# Avg train loss = 122.9881, train accuracy = 0.1794
# Avg test loss = 121.8291, test accuracy = 0.0815
# time for epoch: 2.40
#
# epoch 25/150
# -------------------------
# Avg train loss = 116.6537, train accuracy = 0.2036
# Avg test loss = 116.1531, test accuracy = 0.1066
# time for epoch: 2.40
#
# epoch 26/150
# -------------------------
# Avg train loss = 111.0829, train accuracy = 0.2264
# Avg test loss = 109.9120, test accuracy = 0.1317
# time for epoch: 2.40
#
# epoch 27/150
# -------------------------
# Avg train loss = 106.0606, train accuracy = 0.2460
# Avg test loss = 105.0654, test accuracy = 0.1524
# time for epoch: 2.40
#
# epoch 28/150
# -------------------------
# Avg train loss = 101.5207, train accuracy = 0.2622
# Avg test loss = 101.0420, test accuracy = 0.1695
# time for epoch: 2.40
#
# epoch 29/150
# -------------------------
# Avg train loss = 97.7657, train accuracy = 0.2766
# Avg test loss = 98.0388, test accuracy = 0.1805
# time for epoch: 2.40
#
# epoch 30/150
# -------------------------
# Avg train loss = 94.2378, train accuracy = 0.2900
# Avg test loss = 94.0058, test accuracy = 0.1975
# time for epoch: 2.40
#
# epoch 31/150
# -------------------------
# Avg train loss = 90.9585, train accuracy = 0.3028
# Avg test loss = 91.5187, test accuracy = 0.2081
# time for epoch: 2.40
#
# epoch 32/150
# -------------------------
# Avg train loss = 88.1549, train accuracy = 0.3126
# Avg test loss = 88.1810, test accuracy = 0.2212
# time for epoch: 2.40
#
# epoch 33/150
# -------------------------
# Avg train loss = 85.3786, train accuracy = 0.3240
# Avg test loss = 86.0870, test accuracy = 0.2285
# time for epoch: 2.42
#
# epoch 34/150
# -------------------------
# Avg train loss = 82.9020, train accuracy = 0.3331
# Avg test loss = 83.2595, test accuracy = 0.2400
# time for epoch: 2.41
#
# epoch 35/150
# -------------------------
# Avg train loss = 80.6098, train accuracy = 0.3416
# Avg test loss = 81.0526, test accuracy = 0.2500
# time for epoch: 2.46
#
# epoch 36/150
# -------------------------
# Avg train loss = 78.5624, train accuracy = 0.3496
# Avg test loss = 79.4485, test accuracy = 0.2566
# time for epoch: 2.43
#
# epoch 37/150
# -------------------------
# Avg train loss = 76.6005, train accuracy = 0.3566
# Avg test loss = 78.5400, test accuracy = 0.2616
# time for epoch: 2.42
#
# epoch 38/150
# -------------------------
# Avg train loss = 74.7402, train accuracy = 0.3639
# Avg test loss = 76.7636, test accuracy = 0.2680
# time for epoch: 2.42
#
# epoch 39/150
# -------------------------
# Avg train loss = 73.0743, train accuracy = 0.3700
# Avg test loss = 74.2901, test accuracy = 0.2757
# time for epoch: 2.41
#
# epoch 40/150
# -------------------------
# Avg train loss = 71.8243, train accuracy = 0.3748
# Avg test loss = 73.1214, test accuracy = 0.2829
# time for epoch: 2.42
#
# epoch 41/150
# -------------------------
# Avg train loss = 70.4039, train accuracy = 0.3799
# Avg test loss = 71.2825, test accuracy = 0.2908
# time for epoch: 2.41
#
# epoch 42/150
# -------------------------
# Avg train loss = 68.8663, train accuracy = 0.3866
# Avg test loss = 70.1604, test accuracy = 0.2952
# time for epoch: 2.42
#
# epoch 43/150
# -------------------------
# Avg train loss = 67.7918, train accuracy = 0.3902
# Avg test loss = 69.2848, test accuracy = 0.2978
# time for epoch: 2.41
#
# epoch 44/150
# -------------------------
# Avg train loss = 66.6801, train accuracy = 0.3942
# Avg test loss = 67.7498, test accuracy = 0.3039
# time for epoch: 2.41
#
# epoch 45/150
# -------------------------
# Avg train loss = 65.6586, train accuracy = 0.3979
# Avg test loss = 67.2814, test accuracy = 0.3052
# time for epoch: 2.42
#
# epoch 46/150
# -------------------------
# Avg train loss = 64.5917, train accuracy = 0.4027
# Avg test loss = 66.0285, test accuracy = 0.3121
# time for epoch: 2.42
#
# epoch 47/150
# -------------------------
# Avg train loss = 63.6444, train accuracy = 0.4052
# Avg test loss = 65.0309, test accuracy = 0.3171
# time for epoch: 2.41
#
# epoch 48/150
# -------------------------
# Avg train loss = 62.5531, train accuracy = 0.4106
# Avg test loss = 64.8103, test accuracy = 0.3103
# time for epoch: 2.42
#
# epoch 49/150
# -------------------------
# Avg train loss = 61.6543, train accuracy = 0.4136
# Avg test loss = 63.0388, test accuracy = 0.3245
# time for epoch: 2.42
#
# epoch 50/150
# -------------------------
# Avg train loss = 61.1240, train accuracy = 0.4145
# Avg test loss = 62.3258, test accuracy = 0.3285
# time for epoch: 2.41
#
# epoch 51/150
# -------------------------
# Avg train loss = 60.2470, train accuracy = 0.4187
# Avg test loss = 62.3281, test accuracy = 0.3284
# time for epoch: 2.41
#
# epoch 52/150
# -------------------------
# Avg train loss = 59.5220, train accuracy = 0.4208
# Avg test loss = 61.7527, test accuracy = 0.3295
# time for epoch: 2.44
#
# epoch 53/150
# -------------------------
# Avg train loss = 58.7679, train accuracy = 0.4251
# Avg test loss = 60.2536, test accuracy = 0.3340
# time for epoch: 2.43
#
# epoch 54/150
# -------------------------
# Avg train loss = 57.9174, train accuracy = 0.4268
# Avg test loss = 59.8009, test accuracy = 0.3376
# time for epoch: 2.43
#
# epoch 55/150
# -------------------------
# Avg train loss = 57.4650, train accuracy = 0.4287
# Avg test loss = 58.7614, test accuracy = 0.3428
# time for epoch: 2.58
#
# epoch 56/150
# -------------------------
# Avg train loss = 56.8119, train accuracy = 0.4305
# Avg test loss = 59.3137, test accuracy = 0.3423
# time for epoch: 2.50
#
# epoch 57/150
# -------------------------
# Avg train loss = 56.1473, train accuracy = 0.4333
# Avg test loss = 57.7040, test accuracy = 0.3446
# time for epoch: 2.54
#
# epoch 58/150
# -------------------------
# Avg train loss = 55.6113, train accuracy = 0.4347
# Avg test loss = 57.5244, test accuracy = 0.3454
# time for epoch: 2.93
#
# epoch 59/150
# -------------------------
# Avg train loss = 54.9673, train accuracy = 0.4381
# Avg test loss = 56.9328, test accuracy = 0.3478
# time for epoch: 2.80
#
# epoch 60/150
# -------------------------
# Avg train loss = 54.5509, train accuracy = 0.4383
# Avg test loss = 56.4071, test accuracy = 0.3509
# time for epoch: 3.11
#
# epoch 61/150
# -------------------------
# Avg train loss = 53.9333, train accuracy = 0.4407
# Avg test loss = 55.8074, test accuracy = 0.3544
# time for epoch: 2.85
#
# epoch 62/150
# -------------------------
# Avg train loss = 53.4486, train accuracy = 0.4422
# Avg test loss = 56.2302, test accuracy = 0.3533
# time for epoch: 2.92
#
# epoch 63/150
# -------------------------
# Avg train loss = 53.0410, train accuracy = 0.4441
# Avg test loss = 54.5633, test accuracy = 0.3597
# time for epoch: 2.51
#
# epoch 64/150
# -------------------------
# Avg train loss = 52.4778, train accuracy = 0.4468
# Avg test loss = 53.9630, test accuracy = 0.3615
# time for epoch: 2.60
#
# epoch 65/150
# -------------------------
# Avg train loss = 52.1211, train accuracy = 0.4474
# Avg test loss = 53.3038, test accuracy = 0.3624
# time for epoch: 2.66
#
# epoch 66/150
# -------------------------
# Avg train loss = 51.6437, train accuracy = 0.4486
# Avg test loss = 53.5411, test accuracy = 0.3638
# time for epoch: 2.51
#
# epoch 67/150
# -------------------------
# Avg train loss = 51.1723, train accuracy = 0.4516
# Avg test loss = 52.7013, test accuracy = 0.3650
# time for epoch: 2.44
#
# epoch 68/150
# -------------------------
# Avg train loss = 50.8721, train accuracy = 0.4517
# Avg test loss = 52.3809, test accuracy = 0.3665
# time for epoch: 2.45
#
# epoch 69/150
# -------------------------
# Avg train loss = 50.4083, train accuracy = 0.4538
# Avg test loss = 51.6745, test accuracy = 0.3700
# time for epoch: 2.55
#
# epoch 70/150
# -------------------------
# Avg train loss = 49.9984, train accuracy = 0.4550
# Avg test loss = 51.2628, test accuracy = 0.3680
# time for epoch: 2.55
#
# epoch 71/150
# -------------------------
# Avg train loss = 49.6738, train accuracy = 0.4563
# Avg test loss = 50.7351, test accuracy = 0.3715
# time for epoch: 2.50
#
# epoch 72/150
# -------------------------
# Avg train loss = 49.2780, train accuracy = 0.4569
# Avg test loss = 50.8883, test accuracy = 0.3726
# time for epoch: 2.50
#
# epoch 73/150
# -------------------------
# Avg train loss = 48.9404, train accuracy = 0.4590
# Avg test loss = 50.1169, test accuracy = 0.3761
# time for epoch: 2.45
#
# epoch 74/150
# -------------------------
# Avg train loss = 48.4800, train accuracy = 0.4606
# Avg test loss = 49.8736, test accuracy = 0.3754
# time for epoch: 2.53
#
# epoch 75/150
# -------------------------
# Avg train loss = 48.1875, train accuracy = 0.4612
# Avg test loss = 49.4887, test accuracy = 0.3776
# time for epoch: 2.50
#
# epoch 76/150
# -------------------------
# Avg train loss = 47.8206, train accuracy = 0.4625
# Avg test loss = 49.4101, test accuracy = 0.3760
# time for epoch: 2.64
#
# epoch 77/150
# -------------------------
# Avg train loss = 47.6411, train accuracy = 0.4631
# Avg test loss = 49.4434, test accuracy = 0.3784
# time for epoch: 2.89
#
# epoch 78/150
# -------------------------
# Avg train loss = 47.0913, train accuracy = 0.4651
# Avg test loss = 48.3199, test accuracy = 0.3825
# time for epoch: 2.61
#
# epoch 79/150
# -------------------------
# Avg train loss = 46.9804, train accuracy = 0.4654
# Avg test loss = 48.8212, test accuracy = 0.3806
# time for epoch: 2.48
#
# epoch 80/150
# -------------------------
# Avg train loss = 46.6235, train accuracy = 0.4670
# Avg test loss = 48.0035, test accuracy = 0.3828
# time for epoch: 2.51
#
# epoch 81/150
# -------------------------
# Avg train loss = 46.3611, train accuracy = 0.4684
# Avg test loss = 47.6872, test accuracy = 0.3860
# time for epoch: 2.48
#
# epoch 82/150
# -------------------------
# Avg train loss = 46.1590, train accuracy = 0.4684
# Avg test loss = 47.9078, test accuracy = 0.3836
# time for epoch: 2.50
#
# epoch 83/150
# -------------------------
# Avg train loss = 45.6936, train accuracy = 0.4708
# Avg test loss = 46.9693, test accuracy = 0.3867
# time for epoch: 2.71
#
# epoch 84/150
# -------------------------
# Avg train loss = 45.5588, train accuracy = 0.4712
# Avg test loss = 47.2989, test accuracy = 0.3825
# time for epoch: 2.60
#
# epoch 85/150
# -------------------------
# Avg train loss = 45.2567, train accuracy = 0.4719
# Avg test loss = 47.0283, test accuracy = 0.3860
# time for epoch: 2.62
#
# epoch 86/150
# -------------------------
# Avg train loss = 45.0583, train accuracy = 0.4722
# Avg test loss = 46.4048, test accuracy = 0.3898
# time for epoch: 2.48
#
# epoch 87/150
# -------------------------
# Avg train loss = 44.7189, train accuracy = 0.4752
# Avg test loss = 46.8538, test accuracy = 0.3821
# time for epoch: 2.48
#
# epoch 88/150
# -------------------------
# Avg train loss = 44.4969, train accuracy = 0.4747
# Avg test loss = 46.1424, test accuracy = 0.3923
# time for epoch: 2.45
#
# epoch 89/150
# -------------------------
# Avg train loss = 44.2671, train accuracy = 0.4760
# Avg test loss = 45.4136, test accuracy = 0.3937
# time for epoch: 2.49
#
# epoch 90/150
# -------------------------
# Avg train loss = 43.8942, train accuracy = 0.4779
# Avg test loss = 46.6435, test accuracy = 0.3912
# time for epoch: 2.59
#
# epoch 91/150
# -------------------------
# Avg train loss = 43.8257, train accuracy = 0.4784
# Avg test loss = 45.3184, test accuracy = 0.3914
# time for epoch: 2.51
#
# epoch 92/150
# -------------------------
# Avg train loss = 43.5789, train accuracy = 0.4788
# Avg test loss = 44.7134, test accuracy = 0.3961
# time for epoch: 2.49
#
# epoch 93/150
# -------------------------
# Avg train loss = 43.3831, train accuracy = 0.4794
# Avg test loss = 44.5117, test accuracy = 0.3982
# time for epoch: 2.55
#
# epoch 94/150
# -------------------------
# Avg train loss = 43.0966, train accuracy = 0.4806
# Avg test loss = 44.4499, test accuracy = 0.3952
# time for epoch: 2.60
#
# epoch 95/150
# -------------------------
# Avg train loss = 42.9208, train accuracy = 0.4810
# Avg test loss = 44.1059, test accuracy = 0.4005
# time for epoch: 2.52
#
# epoch 96/150
# -------------------------
# Avg train loss = 42.6700, train accuracy = 0.4828
# Avg test loss = 44.3833, test accuracy = 0.3999
# time for epoch: 2.53
#
# epoch 97/150
# -------------------------
# Avg train loss = 42.4362, train accuracy = 0.4835
# Avg test loss = 45.1322, test accuracy = 0.3935
# time for epoch: 2.62
#
# epoch 98/150
# -------------------------
# Avg train loss = 42.2763, train accuracy = 0.4853
# Avg test loss = 43.5749, test accuracy = 0.4030
# time for epoch: 2.65
#
# epoch 99/150
# -------------------------
# Avg train loss = 42.1624, train accuracy = 0.4854
# Avg test loss = 43.4237, test accuracy = 0.4024
# time for epoch: 2.56
#
# epoch 100/150
# -------------------------
# Avg train loss = 41.9076, train accuracy = 0.4859
# Avg test loss = 43.2092, test accuracy = 0.4025
# time for epoch: 2.61
#
# epoch 101/150
# -------------------------
# Avg train loss = 41.7373, train accuracy = 0.4873
# Avg test loss = 43.9478, test accuracy = 0.3984
# time for epoch: 2.70
#
# epoch 102/150
# -------------------------
# Avg train loss = 41.5505, train accuracy = 0.4876
# Avg test loss = 42.8298, test accuracy = 0.4067
# time for epoch: 2.68
#
# epoch 103/150
# -------------------------
# Avg train loss = 41.4127, train accuracy = 0.4876
# Avg test loss = 42.8367, test accuracy = 0.4062
# time for epoch: 2.67
#
# epoch 104/150
# -------------------------
# Avg train loss = 41.2473, train accuracy = 0.4887
# Avg test loss = 42.4466, test accuracy = 0.4072
# time for epoch: 2.57
#
# epoch 105/150
# -------------------------
# Avg train loss = 41.0195, train accuracy = 0.4898
# Avg test loss = 42.8411, test accuracy = 0.4053
# time for epoch: 2.55
#
# epoch 106/150
# -------------------------
# Avg train loss = 40.7904, train accuracy = 0.4915
# Avg test loss = 42.3991, test accuracy = 0.4071
# time for epoch: 2.54
#
# epoch 107/150
# -------------------------
# Avg train loss = 40.6238, train accuracy = 0.4927
# Avg test loss = 42.8641, test accuracy = 0.3981
# time for epoch: 2.49
#
# epoch 108/150
# -------------------------
# Avg train loss = 40.4349, train accuracy = 0.4916
# Avg test loss = 44.3881, test accuracy = 0.3992
# time for epoch: 2.65
#
# epoch 109/150
# -------------------------
# Avg train loss = 40.3972, train accuracy = 0.4918
# Avg test loss = 42.2217, test accuracy = 0.4081
# time for epoch: 3.50
#
# epoch 110/150
# -------------------------
# Avg train loss = 40.2667, train accuracy = 0.4926
# Avg test loss = 41.7321, test accuracy = 0.4095
# time for epoch: 2.53
#
# epoch 111/150
# -------------------------
# Avg train loss = 40.0219, train accuracy = 0.4945
# Avg test loss = 41.8128, test accuracy = 0.4085
# time for epoch: 2.42
#
# epoch 112/150
# -------------------------
# Avg train loss = 39.8342, train accuracy = 0.4953
# Avg test loss = 41.8795, test accuracy = 0.4116
# time for epoch: 2.43
#
# epoch 113/150
# -------------------------
# Avg train loss = 39.7836, train accuracy = 0.4951
# Avg test loss = 41.6588, test accuracy = 0.4128
# time for epoch: 2.42
#
# epoch 114/150
# -------------------------
# Avg train loss = 39.5831, train accuracy = 0.4965
# Avg test loss = 40.6869, test accuracy = 0.4159
# time for epoch: 2.41
#
# epoch 115/150
# -------------------------
# Avg train loss = 39.4648, train accuracy = 0.4963
# Avg test loss = 40.7761, test accuracy = 0.4158
# time for epoch: 2.42
#
# epoch 116/150
# -------------------------
# Avg train loss = 39.3309, train accuracy = 0.4975
# Avg test loss = 41.0532, test accuracy = 0.4152
# time for epoch: 2.42
#
# epoch 117/150
# -------------------------
# Avg train loss = 39.1766, train accuracy = 0.4982
# Avg test loss = 40.4882, test accuracy = 0.4169
# time for epoch: 2.41
#
# epoch 118/150
# -------------------------
# Avg train loss = 39.1283, train accuracy = 0.4984
# Avg test loss = 40.3485, test accuracy = 0.4163
# time for epoch: 2.41
#
# epoch 119/150
# -------------------------
# Avg train loss = 38.9390, train accuracy = 0.4997
# Avg test loss = 40.6614, test accuracy = 0.4170
# time for epoch: 2.41
#
# epoch 120/150
# -------------------------
# Avg train loss = 38.8110, train accuracy = 0.5003
# Avg test loss = 40.4002, test accuracy = 0.4184
# time for epoch: 2.41
#
# epoch 121/150
# -------------------------
# Avg train loss = 38.7255, train accuracy = 0.5003
# Avg test loss = 40.2062, test accuracy = 0.4180
# time for epoch: 2.42
#
# epoch 122/150
# -------------------------
# Avg train loss = 38.4937, train accuracy = 0.5022
# Avg test loss = 40.2293, test accuracy = 0.4130
# time for epoch: 2.42
#
# epoch 123/150
# -------------------------
# Avg train loss = 38.5017, train accuracy = 0.5017
# Avg test loss = 40.0420, test accuracy = 0.4184
# time for epoch: 2.42
#
# epoch 124/150
# -------------------------
# Avg train loss = 38.3272, train accuracy = 0.5024
# Avg test loss = 40.6327, test accuracy = 0.4161
# time for epoch: 2.44
#
# epoch 125/150
# -------------------------
# Avg train loss = 38.1620, train accuracy = 0.5030
# Avg test loss = 39.8779, test accuracy = 0.4213
# time for epoch: 2.56
#
# epoch 126/150
# -------------------------
# Avg train loss = 38.0378, train accuracy = 0.5033
# Avg test loss = 39.6268, test accuracy = 0.4203
# time for epoch: 2.63
#
# epoch 127/150
# -------------------------
# Avg train loss = 37.9483, train accuracy = 0.5042
# Avg test loss = 39.4987, test accuracy = 0.4226
# time for epoch: 2.60
#
# epoch 128/150
# -------------------------
# Avg train loss = 37.7798, train accuracy = 0.5042
# Avg test loss = 39.2332, test accuracy = 0.4200
# time for epoch: 2.74
#
# epoch 129/150
# -------------------------
# Avg train loss = 37.7060, train accuracy = 0.5050
# Avg test loss = 39.8547, test accuracy = 0.4189
# time for epoch: 2.81
#
# epoch 130/150
# -------------------------
# Avg train loss = 37.6629, train accuracy = 0.5058
# Avg test loss = 39.1530, test accuracy = 0.4212
# time for epoch: 2.59
#
# epoch 131/150
# -------------------------
# Avg train loss = 37.4928, train accuracy = 0.5064
# Avg test loss = 39.0255, test accuracy = 0.4236
# time for epoch: 2.41
#
# epoch 132/150
# -------------------------
# Avg train loss = 37.4425, train accuracy = 0.5077
# Avg test loss = 39.1434, test accuracy = 0.4252
# time for epoch: 2.67
#
# epoch 133/150
# -------------------------
# Avg train loss = 37.3439, train accuracy = 0.5076
# Avg test loss = 38.9921, test accuracy = 0.4223
# time for epoch: 2.41
#
# epoch 134/150
# -------------------------
# Avg train loss = 37.1756, train accuracy = 0.5075
# Avg test loss = 38.7480, test accuracy = 0.4257
# time for epoch: 2.40
#
# epoch 135/150
# -------------------------
# Avg train loss = 37.0486, train accuracy = 0.5086
# Avg test loss = 38.5997, test accuracy = 0.4223
# time for epoch: 2.40
#
# epoch 136/150
# -------------------------
# Avg train loss = 37.0704, train accuracy = 0.5080
# Avg test loss = 38.5864, test accuracy = 0.4253
# time for epoch: 2.40
#
# epoch 137/150
# -------------------------
# Avg train loss = 36.8351, train accuracy = 0.5100
# Avg test loss = 38.8555, test accuracy = 0.4220
# time for epoch: 2.40
#
# epoch 138/150
# -------------------------
# Avg train loss = 36.7689, train accuracy = 0.5090
# Avg test loss = 40.0140, test accuracy = 0.4218
# time for epoch: 2.40
#
# epoch 139/150
# -------------------------
# Avg train loss = 36.6993, train accuracy = 0.5097
# Avg test loss = 39.8280, test accuracy = 0.4237
# time for epoch: 2.41
#
# epoch 140/150
# -------------------------
# Avg train loss = 36.7090, train accuracy = 0.5101
# Avg test loss = 37.9790, test accuracy = 0.4273
# time for epoch: 2.40
#
# epoch 141/150
# -------------------------
# Avg train loss = 36.6094, train accuracy = 0.5100
# Avg test loss = 37.8018, test accuracy = 0.4300
# time for epoch: 2.41
#
# epoch 142/150
# -------------------------
# Avg train loss = 36.4571, train accuracy = 0.5107
# Avg test loss = 38.2001, test accuracy = 0.4279
# time for epoch: 2.41
#
# epoch 143/150
# -------------------------
# Avg train loss = 36.3614, train accuracy = 0.5114
# Avg test loss = 38.0362, test accuracy = 0.4261
# time for epoch: 2.41
#
# epoch 144/150
# -------------------------
# Avg train loss = 36.3559, train accuracy = 0.5111
# Avg test loss = 37.6905, test accuracy = 0.4290
# time for epoch: 2.40
#
# epoch 145/150
# -------------------------
# Avg train loss = 36.2669, train accuracy = 0.5116
# Avg test loss = 38.2990, test accuracy = 0.4250
# time for epoch: 2.40
#
# epoch 146/150
# -------------------------
# Avg train loss = 36.1138, train accuracy = 0.5123
# Avg test loss = 37.6624, test accuracy = 0.4308
# time for epoch: 2.40
#
# epoch 147/150
# -------------------------
# Avg train loss = 36.0612, train accuracy = 0.5126
# Avg test loss = 37.5586, test accuracy = 0.4287
# time for epoch: 2.40
#
# epoch 148/150
# -------------------------
# Avg train loss = 36.0093, train accuracy = 0.5130
# Avg test loss = 37.3828, test accuracy = 0.4292
# time for epoch: 2.40
#
# epoch 149/150
# -------------------------
# Avg train loss = 35.8957, train accuracy = 0.5134
# Avg test loss = 38.0934, test accuracy = 0.4309
# time for epoch: 2.40
#
# epoch 150/150
# -------------------------
# Avg train loss = 35.8015, train accuracy = 0.5138
# Avg test loss = 37.5342, test accuracy = 0.4307
# time for epoch: 2.40
#
# tensor([  2.8132,   2.4848,   2.0591,   2.7568,   4.5016,   4.5643,   4.6240,
#           5.6483,   2.0871,   1.4940,  15.2230,   1.0000,   2.8000,   2.5050,
#           1.8260,   3.9320,   4.3090,   4.7750,   4.5460,   2.8210,   3.8130,
#           3.0100,   0.9080,   3.0000,   4.0000,   2.2570,   0.4800,   0.5000,
#           4.8787,  10.6493,  11.4201,   4.7424,   0.3365,   0.4944,   0.2439,
#           0.7315,   0.6634,   0.3085,   1.2000,   1.5000,   0.4000,   1.8000,
#           0.8000, 142.3060,   1.0000,   0.0000,   1.5485])
# tensor([[ 0.2914,  3.8238],
#         [ 1.9636,  2.2061],
#         [ 1.7166,  2.7592],
#         [ 2.0364,  2.7226],
#         [ 2.1881,  3.2281],
#         [ 2.4462,  3.3861],
#         [ 2.1578,  2.1133],
#         [ 2.0680,  2.2904],
#         [ 2.0765,  1.3484],
#         [ 2.1729,  1.3777],
#         [ 2.3436,  1.7372],
#         [ 0.4000, 12.0000],
#         [ 0.1000, 12.0000],
#         [ 0.1000, 12.0000],
#         [ 0.1000, 12.0000]])
# tensor([[1.4417, 2.4327],
#         [0.8476, 2.6479],
#         [1.5499, 2.3670],
#         [0.7949, 1.6325],
#         [1.7240, 2.5621],
#         [1.6453, 2.2915],
#         [1.0923, 2.6477],
#         [1.0003, 1.4598],
#         [0.5529, 1.5813],
#         [0.2801, 1.6885],
#         [0.6944, 1.9765],
#         [0.9529, 1.8353],
#         [0.8000, 3.1416]])
# tensor([[ 6.2375e-01,  8.3988e-02],
#         [ 1.1121e+00, -3.7136e+00],
#         [ 3.3724e-01, -3.2003e-01],
#         [ 6.9896e-01, -3.4745e+00],
#         [ 6.3610e-01, -2.6014e+00],
#         [ 9.2665e-01, -2.3368e+00],
#         [ 5.5808e-01, -2.0862e+00],
#         [ 5.5511e-01,  1.9149e+00],
#         [ 1.3345e-01, -2.2196e+00],
#         [ 9.9583e-01, -1.8149e+00],
#         [ 7.4269e-01,  1.7022e+00],
#         [ 8.9286e-01, -1.9224e+00],
#         [ 7.6936e-01,  1.6670e+00],
#         [ 1.2489e-01,  2.1698e+00],
#         [ 9.2555e-02,  2.3975e+00],
#         [ 2.8564e-01,  2.4125e+00],
#         [ 2.6200e-01,  2.4613e+00],
#         [ 1.0479e+00, -9.8330e-01],
#         [ 9.7073e-01,  1.5388e+00],
#         [ 9.3426e-01,  2.1134e+00],
#         [ 1.4979e+00,  2.1864e+00],
#         [ 7.2443e-01, -1.8971e-01],
#         [ 6.3149e-01,  2.7134e+00],
#         [ 1.2590e+00, -3.6782e-03],
#         [ 1.1348e+00,  8.9765e-02]])

# %%
model2 = LocalEnergyOpt(fixed_pars,opt_pars,device,set_to_one=True).to(device)
lr = 5e-7
SGD_optimizer = torch.optim.SGD(model2.parameters(), lr=lr, momentum=0.9)  # consider adding momentum
scheduler = scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(SGD_optimizer, 'min', factor=0.5, patience=0, cooldown=1000, threshold=1e-10, verbose=True)
train_loss_SGD = []
test_loss_SGD = []
train_acc_SGD = []
test_acc_SGD = []

epochs = 150
for index_epoch in range(epochs):
    print(f'epoch {index_epoch+1}/{epochs} \n-------------------------')
    t0 = time.time()
    with io.capture_output() as captured:
        train_tmp, train_acc_tmp = my_train(train_dataloader, model2, my_loss, SGD_optimizer)
        test_tmp, test_acc_tmp = my_test(test_dataloader, model2, my_loss)
    tf = time.time()
    print(f'Avg train loss = {train_tmp:.4f}, train accuracy = {train_acc_tmp:.4f}')
    print(f'Avg test loss = {test_tmp:.4f}, test accuracy = {test_acc_tmp:.4f}' )
    print(f'time for epoch: {tf-t0:.2f} \n')
    train_loss_SGD.append(train_tmp)
    test_loss_SGD.append(test_tmp)
    train_acc_SGD.append(train_acc_tmp)
    test_acc_SGD.append(test_acc_tmp)
    
torch.save(model.state_dict(), 'data/Results/150_b1_5e7_SGDso.pth')  # epochs_batchsize_lr_A/SGD + all1/so/~

for p in model.parameters():
    print(p.data)
# Out:
# epoch 1/150
# -------------------------
# Avg train loss = 530.9486, train accuracy = -13.9969
# Avg test loss = 186.0345, test accuracy = -1.2397
# time for epoch: 2.34
#
# epoch 2/150
# -------------------------
# Avg train loss = 150.5328, train accuracy = -0.7661
# Avg test loss = 140.5598, test accuracy = -0.5995
# time for epoch: 2.30
#
# epoch 3/150
# -------------------------
# Avg train loss = 115.4856, train accuracy = -0.3939
# Avg test loss = 116.3150, test accuracy = -0.3703
# time for epoch: 2.30
#
# epoch 4/150
# -------------------------
# Avg train loss = 98.8493, train accuracy = -0.2109
# Avg test loss = 105.6832, test accuracy = -0.2298
# time for epoch: 2.29
#
# epoch 5/150
# -------------------------
# Avg train loss = 87.0953, train accuracy = -0.1071
# Avg test loss = 86.2401, test accuracy = -0.1134
# time for epoch: 2.29
#
# epoch 6/150
# -------------------------
# Avg train loss = 78.6775, train accuracy = -0.0348
# Avg test loss = 82.3678, test accuracy = -0.0566
# time for epoch: 2.30
#
# epoch 7/150
# -------------------------
# Avg train loss = 73.6644, train accuracy = 0.0144
# Avg test loss = 76.0743, test accuracy = -0.0214
# time for epoch: 2.38
#
# epoch 8/150
# -------------------------
# Avg train loss = 68.7096, train accuracy = 0.0520
# Avg test loss = 114.3294, test accuracy = -0.0954
# time for epoch: 2.46
#
# epoch 9/150
# -------------------------
# Avg train loss = 64.9648, train accuracy = 0.0856
# Avg test loss = 66.8876, test accuracy = 0.0616
# time for epoch: 2.52
#
# epoch 10/150
# -------------------------
# Avg train loss = 62.7868, train accuracy = 0.1091
# Avg test loss = 66.7355, test accuracy = 0.0750
# time for epoch: 2.72
#
# epoch 11/150
# -------------------------
# Avg train loss = 61.4504, train accuracy = 0.1298
# Avg test loss = 79.6239, test accuracy = 0.0619
# time for epoch: 2.36
#
# epoch 12/150
# -------------------------
# Avg train loss = 58.5161, train accuracy = 0.1482
# Avg test loss = 68.5839, test accuracy = 0.1050
# time for epoch: 2.38
#
# epoch 13/150
# -------------------------
# Avg train loss = 56.8925, train accuracy = 0.1600
# Avg test loss = 58.6003, test accuracy = 0.1133
# time for epoch: 2.44
#
# epoch 14/150
# -------------------------
# Avg train loss = 54.6992, train accuracy = 0.1781
# Avg test loss = 54.7075, test accuracy = 0.1625
# time for epoch: 2.41
#
# epoch 15/150
# -------------------------
# Avg train loss = 52.7780, train accuracy = 0.1869
# Avg test loss = 56.5764, test accuracy = 0.1571
# time for epoch: 2.29
#
# epoch 16/150
# -------------------------
# Avg train loss = 51.4776, train accuracy = 0.2008
# Avg test loss = 57.4252, test accuracy = 0.1689
# time for epoch: 2.29
#
# epoch 17/150
# -------------------------
# Avg train loss = 51.7173, train accuracy = 0.2082
# Avg test loss = 66.2219, test accuracy = 0.1144
# time for epoch: 2.29
#
# epoch 18/150
# -------------------------
# Avg train loss = 49.7580, train accuracy = 0.2175
# Avg test loss = 49.8240, test accuracy = 0.2019
# time for epoch: 2.30
#
# epoch 19/150
# -------------------------
# Avg train loss = 48.7404, train accuracy = 0.2263
# Avg test loss = 69.5384, test accuracy = 0.1504
# time for epoch: 2.29
#
# epoch 20/150
# -------------------------
# Avg train loss = 48.9232, train accuracy = 0.2311
# Avg test loss = 57.4172, test accuracy = 0.1958
# time for epoch: 2.29
#
# epoch 21/150
# -------------------------
# Avg train loss = 49.4203, train accuracy = 0.2319
# Avg test loss = 47.3024, test accuracy = 0.2180
# time for epoch: 2.29
#
# epoch 22/150
# -------------------------
# Avg train loss = 45.9521, train accuracy = 0.2481
# Avg test loss = 48.2989, test accuracy = 0.1937
# time for epoch: 2.29
#
# epoch 23/150
# -------------------------
# Avg train loss = 46.4753, train accuracy = 0.2484
# Avg test loss = 45.0766, test accuracy = 0.2365
# time for epoch: 2.29
#
# epoch 24/150
# -------------------------
# Avg train loss = 46.0388, train accuracy = 0.2493
# Avg test loss = 44.5314, test accuracy = 0.2479
# time for epoch: 2.29
#
# epoch 25/150
# -------------------------
# Avg train loss = 45.7921, train accuracy = 0.2580
# Avg test loss = 47.3256, test accuracy = 0.2412
# time for epoch: 2.30
#
# epoch 26/150
# -------------------------
# Avg train loss = 45.1594, train accuracy = 0.2578
# Avg test loss = 46.4574, test accuracy = 0.2484
# time for epoch: 2.40
#
# epoch 27/150
# -------------------------
# Avg train loss = 44.9788, train accuracy = 0.2639
# Avg test loss = 57.7477, test accuracy = 0.2230
# time for epoch: 2.55
#
# epoch 28/150
# -------------------------
# Avg train loss = 44.8293, train accuracy = 0.2671
# Avg test loss = 44.5687, test accuracy = 0.2500
# time for epoch: 2.46
#
# epoch 29/150
# -------------------------
# Avg train loss = 43.7319, train accuracy = 0.2747
# Avg test loss = 46.7767, test accuracy = 0.2500
# time for epoch: 2.48
#
# epoch 30/150
# -------------------------
# Avg train loss = 43.4502, train accuracy = 0.2804
# Avg test loss = 58.9750, test accuracy = 0.2063
# time for epoch: 2.87
#
# epoch 31/150
# -------------------------
# Avg train loss = 42.8357, train accuracy = 0.2825
# Avg test loss = 42.0984, test accuracy = 0.2707
# time for epoch: 2.45
#
# epoch 32/150
# -------------------------
# Avg train loss = 43.2449, train accuracy = 0.2869
# Avg test loss = 47.5975, test accuracy = 0.2629
# time for epoch: 2.75
#
# epoch 33/150
# -------------------------
# Avg train loss = 42.3324, train accuracy = 0.2911
# Avg test loss = 41.4096, test accuracy = 0.2850
# time for epoch: 2.47
#
# epoch 34/150
# -------------------------
# Avg train loss = 42.9319, train accuracy = 0.2918
# Avg test loss = 41.9022, test accuracy = 0.2615
# time for epoch: 2.90
#
# epoch 35/150
# -------------------------
# Avg train loss = 41.7951, train accuracy = 0.3008
# Avg test loss = 52.6823, test accuracy = 0.2245
# time for epoch: 2.60
#
# epoch 36/150
# -------------------------
# Avg train loss = 41.2548, train accuracy = 0.3037
# Avg test loss = 45.2706, test accuracy = 0.2647
# time for epoch: 2.39
#
# epoch 37/150
# -------------------------
# Avg train loss = 41.1348, train accuracy = 0.3099
# Avg test loss = 45.6115, test accuracy = 0.2471
# time for epoch: 2.37
#
# epoch 38/150
# -------------------------
# Avg train loss = 41.1523, train accuracy = 0.3123
# Avg test loss = 40.4013, test accuracy = 0.2985
# time for epoch: 2.75
#
# epoch 39/150
# -------------------------
# Avg train loss = 40.7075, train accuracy = 0.3159
# Avg test loss = 40.6065, test accuracy = 0.2969
# time for epoch: 2.58
#
# epoch 40/150
# -------------------------
# Avg train loss = 40.7472, train accuracy = 0.3143
# Avg test loss = 54.3926, test accuracy = 0.2556
# time for epoch: 2.66
#
# epoch 41/150
# -------------------------
# Avg train loss = 41.3241, train accuracy = 0.3207
# Avg test loss = 38.6671, test accuracy = 0.3097
# time for epoch: 2.29
#
# epoch 42/150
# -------------------------
# Avg train loss = 40.5252, train accuracy = 0.3279
# Avg test loss = 42.2580, test accuracy = 0.2754
# time for epoch: 2.32
#
# epoch 43/150
# -------------------------
# Avg train loss = 41.0595, train accuracy = 0.3278
# Avg test loss = 38.2168, test accuracy = 0.3179
# time for epoch: 2.29
#
# epoch 44/150
# -------------------------
# Avg train loss = 39.9056, train accuracy = 0.3388
# Avg test loss = 40.9270, test accuracy = 0.2942
# time for epoch: 2.28
#
# epoch 45/150
# -------------------------
# Avg train loss = 39.6623, train accuracy = 0.3428
# Avg test loss = 44.8164, test accuracy = 0.2837
# time for epoch: 2.28
#
# epoch 46/150
# -------------------------
# Avg train loss = 40.8980, train accuracy = 0.3423
# Avg test loss = 41.8200, test accuracy = 0.3122
# time for epoch: 2.27
#
# epoch 47/150
# -------------------------
# Avg train loss = 39.6784, train accuracy = 0.3489
# Avg test loss = 38.1447, test accuracy = 0.3298
# time for epoch: 2.27
#
# epoch 48/150
# -------------------------
# Avg train loss = 39.4641, train accuracy = 0.3537
# Avg test loss = 39.3599, test accuracy = 0.3002
# time for epoch: 2.28
#
# epoch 49/150
# -------------------------
# Avg train loss = 39.5096, train accuracy = 0.3556
# Avg test loss = 51.6218, test accuracy = 0.2708
# time for epoch: 2.30
#
# epoch 50/150
# -------------------------
# Avg train loss = 38.6632, train accuracy = 0.3637
# Avg test loss = 38.2376, test accuracy = 0.3349
# time for epoch: 2.47
#
# epoch 51/150
# -------------------------
# Avg train loss = 39.5589, train accuracy = 0.3646
# Avg test loss = 37.4004, test accuracy = 0.3330
# time for epoch: 2.31
#
# epoch 52/150
# -------------------------
# Avg train loss = 39.2990, train accuracy = 0.3721
# Avg test loss = 38.8165, test accuracy = 0.3422
# time for epoch: 2.29
#
# epoch 53/150
# -------------------------
# Avg train loss = 39.1728, train accuracy = 0.3743
# Avg test loss = 41.3964, test accuracy = 0.3342
# time for epoch: 2.42
#
# epoch 54/150
# -------------------------
# Avg train loss = 38.6797, train accuracy = 0.3821
# Avg test loss = 36.6403, test accuracy = 0.3459
# time for epoch: 2.39
#
# epoch 55/150
# -------------------------
# Avg train loss = 38.3825, train accuracy = 0.3872
# Avg test loss = 41.4730, test accuracy = 0.3262
# time for epoch: 2.39
#
# epoch 56/150
# -------------------------
# Avg train loss = 38.0953, train accuracy = 0.3938
# Avg test loss = 37.4209, test accuracy = 0.3396
# time for epoch: 2.43
#
# epoch 57/150
# -------------------------
# Avg train loss = 38.4665, train accuracy = 0.3931
# Avg test loss = 36.1697, test accuracy = 0.3627
# time for epoch: 3.35
#
# epoch 58/150
# -------------------------
# Avg train loss = 37.9567, train accuracy = 0.4029
# Avg test loss = 36.3533, test accuracy = 0.3604
# time for epoch: 2.51
#
# epoch 59/150
# -------------------------
# Avg train loss = 37.8279, train accuracy = 0.4082
# Avg test loss = 36.8277, test accuracy = 0.3648
# time for epoch: 2.76
#
# epoch 60/150
# -------------------------
# Avg train loss = 37.8159, train accuracy = 0.4094
# Avg test loss = 41.6772, test accuracy = 0.3165
# time for epoch: 2.50
#
# epoch 61/150
# -------------------------
# Avg train loss = 36.9277, train accuracy = 0.4158
# Avg test loss = 40.8373, test accuracy = 0.3601
# time for epoch: 2.32
#
# epoch 62/150
# -------------------------
# Avg train loss = 37.4275, train accuracy = 0.4150
# Avg test loss = 78.0416, test accuracy = 0.2645
# time for epoch: 2.75
#
# epoch 63/150
# -------------------------
# Avg train loss = 37.7108, train accuracy = 0.4224
# Avg test loss = 47.4339, test accuracy = 0.3430
# time for epoch: 2.51
#
# epoch 64/150
# -------------------------
# Avg train loss = 38.6779, train accuracy = 0.4215
# Avg test loss = 40.4147, test accuracy = 0.3438
# time for epoch: 2.40
#
# epoch 65/150
# -------------------------
# Avg train loss = 36.8024, train accuracy = 0.4262
# Avg test loss = 42.7443, test accuracy = 0.3604
# time for epoch: 2.73
#
# epoch 66/150
# -------------------------
# Avg train loss = 36.9491, train accuracy = 0.4312
# Avg test loss = 43.4973, test accuracy = 0.3596
# time for epoch: 2.65
#
# epoch 67/150
# -------------------------
# Avg train loss = 37.4421, train accuracy = 0.4344
# Avg test loss = 34.7030, test accuracy = 0.3865
# time for epoch: 2.50
#
# epoch 68/150
# -------------------------
# Avg train loss = 37.2420, train accuracy = 0.4353
# Avg test loss = 35.3068, test accuracy = 0.3786
# time for epoch: 2.29
#
# epoch 69/150
# -------------------------
# Avg train loss = 36.5141, train accuracy = 0.4398
# Avg test loss = 41.1842, test accuracy = 0.3531
# time for epoch: 2.51
#
# epoch 70/150
# -------------------------
# Avg train loss = 36.3921, train accuracy = 0.4473
# Avg test loss = 34.2458, test accuracy = 0.3935
# time for epoch: 2.49
#
# epoch 71/150
# -------------------------
# Avg train loss = 37.0623, train accuracy = 0.4423
# Avg test loss = 38.6702, test accuracy = 0.3657
# time for epoch: 2.61
#
# epoch 72/150
# -------------------------
# Avg train loss = 36.7095, train accuracy = 0.4455
# Avg test loss = 35.2433, test accuracy = 0.3794
# time for epoch: 2.62
#
# epoch 73/150
# -------------------------
# Avg train loss = 35.9561, train accuracy = 0.4527
# Avg test loss = 38.1407, test accuracy = 0.3589
# time for epoch: 2.31
#
# epoch 74/150
# -------------------------
# Avg train loss = 36.0481, train accuracy = 0.4548
# Avg test loss = 34.9076, test accuracy = 0.3916
# time for epoch: 2.32
#
# epoch 75/150
# -------------------------
# Avg train loss = 35.4835, train accuracy = 0.4554
# Avg test loss = 38.0827, test accuracy = 0.3817
# time for epoch: 2.55
#
# epoch 76/150
# -------------------------
# Avg train loss = 36.8086, train accuracy = 0.4535
# Avg test loss = 34.2990, test accuracy = 0.3948
# time for epoch: 2.38
#
# epoch 77/150
# -------------------------
# Avg train loss = 35.7360, train accuracy = 0.4578
# Avg test loss = 35.3366, test accuracy = 0.3742
# time for epoch: 2.29
#
# epoch 78/150
# -------------------------
# Avg train loss = 36.3055, train accuracy = 0.4587
# Avg test loss = 34.7009, test accuracy = 0.3864
# time for epoch: 2.29
#
# epoch 79/150
# -------------------------
# Avg train loss = 36.1116, train accuracy = 0.4601
# Avg test loss = 37.5666, test accuracy = 0.3964
# time for epoch: 2.35
#
# epoch 80/150
# -------------------------
# Avg train loss = 36.5322, train accuracy = 0.4600
# Avg test loss = 33.9964, test accuracy = 0.4050
# time for epoch: 2.44
#
# epoch 81/150
# -------------------------
# Avg train loss = 35.7751, train accuracy = 0.4640
# Avg test loss = 35.8569, test accuracy = 0.3931
# time for epoch: 2.50
#
# epoch 82/150
# -------------------------
# Avg train loss = 35.4456, train accuracy = 0.4638
# Avg test loss = 39.7056, test accuracy = 0.3719
# time for epoch: 2.44
#
# epoch 83/150
# -------------------------
# Avg train loss = 35.2550, train accuracy = 0.4651
# Avg test loss = 36.1270, test accuracy = 0.3816
# time for epoch: 2.61
#
# epoch 84/150
# -------------------------
# Avg train loss = 35.3779, train accuracy = 0.4664
# Avg test loss = 40.4334, test accuracy = 0.3903
# time for epoch: 2.60
#
# epoch 85/150
# -------------------------
# Avg train loss = 35.8668, train accuracy = 0.4665
# Avg test loss = 38.0228, test accuracy = 0.3984
# time for epoch: 2.63
#
# epoch 86/150
# -------------------------
# Avg train loss = 35.0851, train accuracy = 0.4644
# Avg test loss = 33.2234, test accuracy = 0.4106
# time for epoch: 2.56
#
# epoch 87/150
# -------------------------
# Avg train loss = 35.4718, train accuracy = 0.4666
# Avg test loss = 34.4295, test accuracy = 0.4080
# time for epoch: 2.29
#
# epoch 88/150
# -------------------------
# Avg train loss = 36.0053, train accuracy = 0.4659
# Avg test loss = 35.6770, test accuracy = 0.3912
# time for epoch: 2.40
#
# epoch 89/150
# -------------------------
# Avg train loss = 36.0666, train accuracy = 0.4651
# Avg test loss = 34.4496, test accuracy = 0.3929
# time for epoch: 2.71
#
# epoch 90/150
# -------------------------
# Avg train loss = 35.2343, train accuracy = 0.4693
# Avg test loss = 33.2223, test accuracy = 0.4125
# time for epoch: 2.75
#
# epoch 91/150
# -------------------------
# Avg train loss = 34.9569, train accuracy = 0.4689
# Avg test loss = 33.5860, test accuracy = 0.4084
# time for epoch: 2.68
#
# epoch 92/150
# -------------------------
# Avg train loss = 35.6701, train accuracy = 0.4668
# Avg test loss = 34.0770, test accuracy = 0.4086
# time for epoch: 2.56
#
# epoch 93/150
# -------------------------
# Avg train loss = 34.4881, train accuracy = 0.4695
# Avg test loss = 35.8583, test accuracy = 0.4064
# time for epoch: 2.52
#
# epoch 94/150
# -------------------------
# Avg train loss = 34.8738, train accuracy = 0.4673
# Avg test loss = 38.8787, test accuracy = 0.3996
# time for epoch: 2.67
#
# epoch 95/150
# -------------------------
# Avg train loss = 35.4257, train accuracy = 0.4687
# Avg test loss = 33.1119, test accuracy = 0.4147
# time for epoch: 2.63
#
# epoch 96/150
# -------------------------
# Avg train loss = 35.5052, train accuracy = 0.4673
# Avg test loss = 35.1084, test accuracy = 0.4071
# time for epoch: 2.33
#
# epoch 97/150
# -------------------------
# Avg train loss = 35.6972, train accuracy = 0.4696
# Avg test loss = 41.7623, test accuracy = 0.3803
# time for epoch: 2.46
#
# epoch 98/150
# -------------------------
# Avg train loss = 35.0265, train accuracy = 0.4684
# Avg test loss = 37.2886, test accuracy = 0.3879
# time for epoch: 2.39
#
# epoch 99/150
# -------------------------
# Avg train loss = 34.3029, train accuracy = 0.4740
# Avg test loss = 34.1803, test accuracy = 0.3993
# time for epoch: 2.41
#
# epoch 100/150
# -------------------------
# Avg train loss = 34.6927, train accuracy = 0.4722
# Avg test loss = 32.9548, test accuracy = 0.4119
# time for epoch: 2.37
#
# epoch 101/150
# -------------------------
# Avg train loss = 34.8351, train accuracy = 0.4749
# Avg test loss = 51.2791, test accuracy = 0.3661
# time for epoch: 2.31
#
# epoch 102/150
# -------------------------
# Avg train loss = 35.2144, train accuracy = 0.4746
# Avg test loss = 33.1046, test accuracy = 0.4170
# time for epoch: 2.45
#
# epoch 103/150
# -------------------------
# Avg train loss = 35.2293, train accuracy = 0.4739
# Avg test loss = 37.8155, test accuracy = 0.4058
# time for epoch: 2.60
#
# epoch 104/150
# -------------------------
# Avg train loss = 34.8812, train accuracy = 0.4747
# Avg test loss = 34.2111, test accuracy = 0.4045
# time for epoch: 2.39
#
# epoch 105/150
# -------------------------
# Avg train loss = 35.1501, train accuracy = 0.4742
# Avg test loss = 33.1810, test accuracy = 0.4165
# time for epoch: 2.42
#
# epoch 106/150
# -------------------------
# Avg train loss = 34.6954, train accuracy = 0.4713
# Avg test loss = 32.8857, test accuracy = 0.4148
# time for epoch: 2.58
#
# epoch 107/150
# -------------------------
# Avg train loss = 34.5281, train accuracy = 0.4740
# Avg test loss = 38.4619, test accuracy = 0.4013
# time for epoch: 2.41
#
# epoch 108/150
# -------------------------
# Avg train loss = 34.6039, train accuracy = 0.4763
# Avg test loss = 34.3820, test accuracy = 0.4144
# time for epoch: 2.44
#
# epoch 109/150
# -------------------------
# Avg train loss = 35.4240, train accuracy = 0.4715
# Avg test loss = 56.4519, test accuracy = 0.3528
# time for epoch: 2.52
#
# epoch 110/150
# -------------------------
# Avg train loss = 34.6535, train accuracy = 0.4755
# Avg test loss = 35.6676, test accuracy = 0.4116
# time for epoch: 2.51
#
# epoch 111/150
# -------------------------
# Avg train loss = 34.9140, train accuracy = 0.4737
# Avg test loss = 36.3258, test accuracy = 0.4053
# time for epoch: 2.49
#
# epoch 112/150
# -------------------------
# Avg train loss = 34.1585, train accuracy = 0.4784
# Avg test loss = 33.5069, test accuracy = 0.4015
# time for epoch: 2.46
#
# epoch 113/150
# -------------------------
# Avg train loss = 34.6279, train accuracy = 0.4779
# Avg test loss = 36.5008, test accuracy = 0.4117
# time for epoch: 2.36
#
# epoch 114/150
# -------------------------
# Avg train loss = 34.7297, train accuracy = 0.4776
# Avg test loss = 36.1090, test accuracy = 0.4098
# time for epoch: 2.36
#
# epoch 115/150
# -------------------------
# Avg train loss = 34.8179, train accuracy = 0.4765
# Avg test loss = 33.8398, test accuracy = 0.4183
# time for epoch: 2.36
#
# epoch 116/150
# -------------------------
# Avg train loss = 34.3446, train accuracy = 0.4789
# Avg test loss = 38.5998, test accuracy = 0.3726
# time for epoch: 2.36
#
# epoch 117/150
# -------------------------
# Avg train loss = 34.5187, train accuracy = 0.4777
# Avg test loss = 35.1984, test accuracy = 0.4049
# time for epoch: 2.36
#
# epoch 118/150
# -------------------------
# Avg train loss = 34.0743, train accuracy = 0.4797
# Avg test loss = 33.1034, test accuracy = 0.4126
# time for epoch: 2.35
#
# epoch 119/150
# -------------------------
# Avg train loss = 34.1077, train accuracy = 0.4818
# Avg test loss = 33.8398, test accuracy = 0.4199
# time for epoch: 2.35
#
# epoch 120/150
# -------------------------
# Avg train loss = 34.2119, train accuracy = 0.4811
# Avg test loss = 40.8237, test accuracy = 0.4048
# time for epoch: 2.35
#
# epoch 121/150
# -------------------------
# Avg train loss = 34.1972, train accuracy = 0.4816
# Avg test loss = 32.6831, test accuracy = 0.4218
# time for epoch: 2.35
#
# epoch 122/150
# -------------------------
# Avg train loss = 34.5946, train accuracy = 0.4829
# Avg test loss = 36.6980, test accuracy = 0.4146
# time for epoch: 2.36
#
# epoch 123/150
# -------------------------
# Avg train loss = 33.9336, train accuracy = 0.4842
# Avg test loss = 36.8005, test accuracy = 0.3560
# time for epoch: 2.35
#
# epoch 124/150
# -------------------------
# Avg train loss = 33.8247, train accuracy = 0.4842
# Avg test loss = 39.1031, test accuracy = 0.4121
# time for epoch: 2.35
#
# epoch 125/150
# -------------------------
# Avg train loss = 33.6824, train accuracy = 0.4865
# Avg test loss = 33.2607, test accuracy = 0.4272
# time for epoch: 2.48
#
# epoch 126/150
# -------------------------
# Avg train loss = 33.9599, train accuracy = 0.4878
# Avg test loss = 33.5500, test accuracy = 0.4275
# time for epoch: 2.38
#
# epoch 127/150
# -------------------------
# Avg train loss = 34.2255, train accuracy = 0.4852
# Avg test loss = 33.4551, test accuracy = 0.4277
# time for epoch: 2.36
#
# epoch 128/150
# -------------------------
# Avg train loss = 33.8869, train accuracy = 0.4891
# Avg test loss = 32.3448, test accuracy = 0.4159
# time for epoch: 2.38
#
# epoch 129/150
# -------------------------
# Avg train loss = 33.2113, train accuracy = 0.4924
# Avg test loss = 38.6874, test accuracy = 0.3649
# time for epoch: 2.35
#
# epoch 130/150
# -------------------------
# Avg train loss = 33.8874, train accuracy = 0.4872
# Avg test loss = 32.5482, test accuracy = 0.4279
# time for epoch: 2.36
#
# epoch 131/150
# -------------------------
# Avg train loss = 34.1001, train accuracy = 0.4893
# Avg test loss = 32.5124, test accuracy = 0.4200
# time for epoch: 2.35
#
# epoch 132/150
# -------------------------
# Avg train loss = 33.9895, train accuracy = 0.4855
# Avg test loss = 35.0395, test accuracy = 0.4240
# time for epoch: 2.36
#
# epoch 133/150
# -------------------------
# Avg train loss = 33.3048, train accuracy = 0.4909
# Avg test loss = 31.8809, test accuracy = 0.4360
# time for epoch: 2.35
#
# epoch 134/150
# -------------------------
# Avg train loss = 33.9253, train accuracy = 0.4889
# Avg test loss = 36.7108, test accuracy = 0.3903
# time for epoch: 2.35
#
# epoch 135/150
# -------------------------
# Avg train loss = 33.2871, train accuracy = 0.4902
# Avg test loss = 32.2511, test accuracy = 0.4357
# time for epoch: 2.35
#
# epoch 136/150
# -------------------------
# Avg train loss = 33.2451, train accuracy = 0.4948
# Avg test loss = 35.6249, test accuracy = 0.4282
# time for epoch: 2.35
#
# epoch 137/150
# -------------------------
# Avg train loss = 33.5015, train accuracy = 0.4915
# Avg test loss = 31.9273, test accuracy = 0.4333
# time for epoch: 2.36
#
# epoch 138/150
# -------------------------
# Avg train loss = 33.3995, train accuracy = 0.4943
# Avg test loss = 41.8904, test accuracy = 0.4044
# time for epoch: 2.35
#
# epoch 139/150
# -------------------------
# Avg train loss = 33.3185, train accuracy = 0.4945
# Avg test loss = 34.9826, test accuracy = 0.3941
# time for epoch: 2.35
#
# epoch 140/150
# -------------------------
# Avg train loss = 33.0200, train accuracy = 0.4974
# Avg test loss = 34.9658, test accuracy = 0.4084
# time for epoch: 2.35
#
# epoch 141/150
# -------------------------
# Avg train loss = 33.8589, train accuracy = 0.4952
# Avg test loss = 37.0762, test accuracy = 0.4084
# time for epoch: 2.35
#
# epoch 142/150
# -------------------------
# Avg train loss = 33.2580, train accuracy = 0.4951
# Avg test loss = 41.0299, test accuracy = 0.3736
# time for epoch: 2.35
#
# epoch 143/150
# -------------------------
# Avg train loss = 33.9612, train accuracy = 0.4944
# Avg test loss = 42.2485, test accuracy = 0.3712
# time for epoch: 2.35
#
# epoch 144/150
# -------------------------
# Avg train loss = 32.8359, train accuracy = 0.4977
# Avg test loss = 45.1723, test accuracy = 0.4059
# time for epoch: 2.33
#
# epoch 145/150
# -------------------------
# Avg train loss = 33.3654, train accuracy = 0.4972
# Avg test loss = 39.0196, test accuracy = 0.4226
# time for epoch: 2.28
#
# epoch 146/150
# -------------------------
# Avg train loss = 32.6328, train accuracy = 0.4999
# Avg test loss = 37.5342, test accuracy = 0.3889
# time for epoch: 2.28
#
# epoch 147/150
# -------------------------
# Avg train loss = 33.3780, train accuracy = 0.4971
# Avg test loss = 31.3933, test accuracy = 0.4403
# time for epoch: 2.40
#
# epoch 148/150
# -------------------------
# Avg train loss = 33.0385, train accuracy = 0.4995
# Avg test loss = 37.6811, test accuracy = 0.4277
# time for epoch: 2.40
#
# epoch 149/150
# -------------------------
# Avg train loss = 33.0635, train accuracy = 0.4961
# Avg test loss = 33.4431, test accuracy = 0.4313
# time for epoch: 2.29
#
# epoch 150/150
# -------------------------
# Avg train loss = 32.5554, train accuracy = 0.5007
# Avg test loss = 47.5294, test accuracy = 0.3598
# time for epoch: 2.29
#
# tensor([  2.8132,   2.4848,   2.0591,   2.7568,   4.5016,   4.5643,   4.6240,
#           5.6483,   2.0871,   1.4940,  15.2230,   1.0000,   2.8000,   2.5050,
#           1.8260,   3.9320,   4.3090,   4.7750,   4.5460,   2.8210,   3.8130,
#           3.0100,   0.9080,   3.0000,   4.0000,   2.2570,   0.4800,   0.5000,
#           4.8787,  10.6493,  11.4201,   4.7424,   0.3365,   0.4944,   0.2439,
#           0.7315,   0.6634,   0.3085,   1.2000,   1.5000,   0.4000,   1.8000,
#           0.8000, 142.3060,   1.0000,   0.0000,   1.5485])
# tensor([[ 0.2914,  3.8238],
#         [ 1.9636,  2.2061],
#         [ 1.7166,  2.7592],
#         [ 2.0364,  2.7226],
#         [ 2.1881,  3.2281],
#         [ 2.4462,  3.3861],
#         [ 2.1578,  2.1133],
#         [ 2.0680,  2.2904],
#         [ 2.0765,  1.3484],
#         [ 2.1729,  1.3777],
#         [ 2.3436,  1.7372],
#         [ 0.4000, 12.0000],
#         [ 0.1000, 12.0000],
#         [ 0.1000, 12.0000],
#         [ 0.1000, 12.0000]])
# tensor([[1.4417, 2.4327],
#         [0.8476, 2.6479],
#         [1.5499, 2.3670],
#         [0.7949, 1.6325],
#         [1.7240, 2.5621],
#         [1.6453, 2.2915],
#         [1.0923, 2.6477],
#         [1.0003, 1.4598],
#         [0.5529, 1.5813],
#         [0.2801, 1.6885],
#         [0.6944, 1.9765],
#         [0.9529, 1.8353],
#         [0.8000, 3.1416]])
# tensor([[ 6.2375e-01,  8.3988e-02],
#         [ 1.1121e+00, -3.7136e+00],
#         [ 3.3724e-01, -3.2003e-01],
#         [ 6.9896e-01, -3.4745e+00],
#         [ 6.3610e-01, -2.6014e+00],
#         [ 9.2665e-01, -2.3368e+00],
#         [ 5.5808e-01, -2.0862e+00],
#         [ 5.5511e-01,  1.9149e+00],
#         [ 1.3345e-01, -2.2196e+00],
#         [ 9.9583e-01, -1.8149e+00],
#         [ 7.4269e-01,  1.7022e+00],
#         [ 8.9286e-01, -1.9224e+00],
#         [ 7.6936e-01,  1.6670e+00],
#         [ 1.2489e-01,  2.1698e+00],
#         [ 9.2555e-02,  2.3975e+00],
#         [ 2.8564e-01,  2.4125e+00],
#         [ 2.6200e-01,  2.4613e+00],
#         [ 1.0479e+00, -9.8330e-01],
#         [ 9.7073e-01,  1.5388e+00],
#         [ 9.3426e-01,  2.1134e+00],
#         [ 1.4979e+00,  2.1864e+00],
#         [ 7.2443e-01, -1.8971e-01],
#         [ 6.3149e-01,  2.7134e+00],
#         [ 1.2590e+00, -3.6782e-03],
#         [ 1.1348e+00,  8.9765e-02]])

# %%
fig, ax = plt.subplots(1,2,figsize=(14,5))
ax[0].semilogy(train_loss_adam, label='Adam')
ax[0].semilogy(train_loss_SGD, label='SGD')
ax[0].set_xlabel('Epochs', fontsize=15)
ax[0].set_ylabel('Loss', fontsize=15)
ax[0].legend(fontsize=15)
ax[0].set_title('Train loss', fontsize=18)

ax[1].semilogy(test_loss_adam, label='Adam')
ax[1].semilogy(test_loss_SGD, label='SGD')
ax[1].set_xlabel('Epochs', fontsize=15)
ax[1].set_ylabel('Loss', fontsize=15)
ax[1].legend(fontsize=15)
ax[1].set_title('Test loss', fontsize=18)
plt.show()

# %%
plt.semilogy(train_loss_SGD)

# %%
fig, ax = plt.subplots(1,2,figsize=(14,5))
ax[0].plot(train_acc_adam, label='Adam')
ax[0].plot(train_acc_SGD, label='SGD')
ax[0].axhline(y=1, color='black', linestyle='--', linewidth=0.7)
ax[0].set_xlabel('Epochs', fontsize=15)
ax[0].set_ylabel('R2 score', fontsize=15)
ax[0].set_ylim([-2.2,1.5])
ax[0].legend(fontsize=15)
ax[0].set_title('Train score, batch size = 1', fontsize=18)

ax[1].plot(test_acc_adam, label='Adam')
ax[1].plot(test_acc_SGD, label='SGD')
ax[1].axhline(y=1, color='black', linestyle='--', linewidth=0.7)
ax[1].set_xlabel('Epochs', fontsize=15)
ax[1].set_ylabel('R2 score', fontsize=15)
ax[1].set_ylim([-2.2,1.5])
ax[1].legend(fontsize=15)
ax[1].set_title('Test score, batch size = 1', fontsize=18)

# plt.savefig('Images/Score_400_b16.pdf')
plt.show()

# %% [markdown]
# ## Adam optimizer analysis: learning rate and batch size

# %%
_,stats_adam = compare_energies(seq_data,model,plot=True)
# Out:
# Bonds energy computed
# Angles energy computed
# Torsions energy computed

# %%
_,stats_SGD = compare_energies(seq_data,model2,plot=True)
# Out:
# Bonds energy computed
# Angles energy computed
# Torsions energy computed

# %% [markdown]
# Adam results seem better in terms of matching between obtained distributions and original ones. Indeed, one issue to take into consideration is that, if the learning rate is too high (indicatively above $10^{-4}$), it leads to negative couplings, which is obviously unphysical.
# Limitations to SGD are instead the learning rate, that needs to be small to avoid divergent quantities, and wrong predictions concerning the variance of distributions. Even an increase in the batch size does not modify substantially these behaviours.
#
# In particular, the larger discrepancy is observed in the angle energy distribution

# %%
print(stats_adam['amber']-stats_adam['hire'])
print(stats_SGD['amber']-stats_SGD['hire'])
# Out:
# [[ 0.10503336  2.26889679]
#  [ 0.12082913  6.75023433]
#  [-0.21086896 13.08070414]]
# [[ 0.1273872   2.13627399]
#  [ 1.38135068  9.67380343]
#  [-3.25204945  8.67444226]]

# %%
amber_hist = get_amber_hist(seq_data)
# print(amber_hist[0][0], amber_hist[1][0])

# %%
model.load_state_dict(torch.load("data/Results/initial_values_sameorder.pth"))
lr = 1e-4
adam_optimizer = torch.optim.Adam(model.parameters(), lr=lr)
my_train = KL_train
my_test = KL_test
epochs = 200

train_loss_adam = []
test_loss_adam = []
train_acc_adam = []
test_acc_adam = []

for index_epoch in range(epochs):
    print(f'epoch {index_epoch+1}/{epochs} \n-------------------------')
    t0 = time.time()
    with io.capture_output() as captured:
        train_tmp, train_acc_tmp = my_train(train_dataloader, model, my_loss, adam_optimizer, amber_hist)
        test_tmp, test_acc_tmp = my_test(test_dataloader, model, my_loss, amber_hist)
    tf = time.time()
    print(f'Avg train loss = {train_tmp:.4f}, train score = {train_acc_tmp:.4f}')
    print(f'Avg test loss = {test_tmp:.4f}, test score = {test_acc_tmp:.4f}' )
    print(f'time for epoch: {tf-t0:.2f} \n')
    train_loss_adam.append(train_tmp)
    test_loss_adam.append(test_tmp)
    train_acc_adam.append(train_acc_tmp)
    test_acc_adam.append(test_acc_tmp)
# Out:
# epoch 1/200
# -------------------------
# Avg train loss = 18003.0980, train score = nan
# Avg test loss = 14282.1815, test score = nan
# time for epoch: 2.49
#
# epoch 2/200
# -------------------------
# Avg train loss = 10824.3344, train score = 2.7571
# Avg test loss = 7049.8375, test score = 2.3171
# time for epoch: 2.47
#
# epoch 3/200
# -------------------------
# Avg train loss = 4892.8060, train score = 1.9169
# Avg test loss = 2832.2706, test score = 2.1685
# time for epoch: 2.67
#
# epoch 4/200
# -------------------------
# Avg train loss = 2247.7296, train score = 2.0595
# Avg test loss = 1672.0711, test score = 2.0687
# time for epoch: 2.64
#
# epoch 5/200
# -------------------------
# Avg train loss = 1576.0582, train score = 2.0393
# Avg test loss = 1367.9044, test score = 2.0488
# time for epoch: 2.54
#
# epoch 6/200
# -------------------------
# Avg train loss = 1299.3798, train score = 1.9775
# Avg test loss = 1162.8183, test score = 2.0364
# time for epoch: 2.50
#
# epoch 7/200
# -------------------------
# Avg train loss = 1092.2149, train score = 1.9032
# Avg test loss = 988.8337, test score = 1.9687
# time for epoch: 2.56
#
# epoch 8/200
# -------------------------
# Avg train loss = 918.2260, train score = 1.8816
# Avg test loss = 838.4615, test score = 1.9335
# time for epoch: 2.57
#
# epoch 9/200
# -------------------------
# Avg train loss = 771.2256, train score = 1.7751
# Avg test loss = 709.5628, test score = 1.8859
# time for epoch: 2.69
#
# epoch 10/200
# -------------------------
# Avg train loss = 648.5905, train score = 1.7184
# Avg test loss = 602.1481, test score = 1.8569
# time for epoch: 2.62
#
# epoch 11/200
# -------------------------
# Avg train loss = 546.8950, train score = 1.6730
# Avg test loss = 512.3712, test score = 1.6474
# time for epoch: 2.61
#
# epoch 12/200
# -------------------------
# Avg train loss = 461.5631, train score = 1.5415
# Avg test loss = 434.8802, test score = 1.5977
# time for epoch: 2.41
#
# epoch 13/200
# -------------------------
# Avg train loss = 391.4564, train score = 1.4269
# Avg test loss = 372.5258, test score = 1.5251
# time for epoch: 2.40
#
# epoch 14/200
# -------------------------
# Avg train loss = 333.8069, train score = 1.3211
# Avg test loss = 318.9344, test score = 1.3739
# time for epoch: 2.42
#
# epoch 15/200
# -------------------------
# Avg train loss = 287.7254, train score = 1.2347
# Avg test loss = 277.3911, test score = 1.1964
# time for epoch: 2.52
#
# epoch 16/200
# -------------------------
# Avg train loss = 250.5190, train score = 1.0972
# Avg test loss = 241.9091, test score = 1.1071
# time for epoch: 2.43
#
# epoch 17/200
# -------------------------
# Avg train loss = 220.4082, train score = 0.9729
# Avg test loss = 214.3193, test score = 1.0803
# time for epoch: 2.46
#
# epoch 18/200
# -------------------------
# Avg train loss = 196.0065, train score = 0.8826
# Avg test loss = 191.2657, test score = 0.9683
# time for epoch: 2.40
#
# epoch 19/200
# -------------------------
# Avg train loss = 176.9626, train score = 0.7764
# Avg test loss = 173.9696, test score = 0.9418
# time for epoch: 2.43
#
# epoch 20/200
# -------------------------
# Avg train loss = 161.8287, train score = 0.6941
# Avg test loss = 159.6373, test score = 0.7863
# time for epoch: 2.43
#
# epoch 21/200
# -------------------------
# Avg train loss = 149.1276, train score = 0.6130
# Avg test loss = 146.9657, test score = 0.7823
# time for epoch: 2.43
#
# epoch 22/200
# -------------------------
# Avg train loss = 138.5022, train score = 0.5678
# Avg test loss = 137.3239, test score = 0.7495
# time for epoch: 2.73
#
# epoch 23/200
# -------------------------
# Avg train loss = 130.1229, train score = 0.5475
# Avg test loss = 128.6440, test score = 0.7158
# time for epoch: 2.72
#
# epoch 24/200
# -------------------------
# Avg train loss = 122.8132, train score = 0.5495
# Avg test loss = 121.6115, test score = 0.6784
# time for epoch: 2.75
#
# epoch 25/200
# -------------------------
# Avg train loss = 116.5814, train score = 0.4846
# Avg test loss = 115.5928, test score = 0.7374
# time for epoch: 2.48
#
# epoch 26/200
# -------------------------
# Avg train loss = 110.6563, train score = 0.4581
# Avg test loss = 112.0125, test score = 0.6174
# time for epoch: 2.59
#
# epoch 27/200
# -------------------------
# Avg train loss = 105.9962, train score = 0.4375
# Avg test loss = 106.9368, test score = 0.6641
# time for epoch: 2.70
#
# epoch 28/200
# -------------------------
# Avg train loss = 101.7327, train score = 0.4442
# Avg test loss = 101.5006, test score = 0.6995
# time for epoch: 2.60
#
# epoch 29/200
# -------------------------
# Avg train loss = 97.6980, train score = 0.4383
# Avg test loss = 97.3476, test score = 0.6722
# time for epoch: 2.55
#
# epoch 30/200
# -------------------------
# Avg train loss = 94.2064, train score = 0.4463
# Avg test loss = 94.0318, test score = 0.7059
# time for epoch: 2.58
#
# epoch 31/200
# -------------------------
# Avg train loss = 90.9206, train score = 0.4670
# Avg test loss = 91.9048, test score = 0.6907
# time for epoch: 2.77
#
# epoch 32/200
# -------------------------
# Avg train loss = 88.0249, train score = 0.4387
# Avg test loss = 89.0816, test score = 0.6642
# time for epoch: 2.56
#
# epoch 33/200
# -------------------------
# Avg train loss = 85.3002, train score = 0.4493
# Avg test loss = 85.6289, test score = 0.7573
# time for epoch: 2.73
#
# epoch 34/200
# -------------------------
# Avg train loss = 82.7114, train score = 0.4851
# Avg test loss = 84.0446, test score = 0.7145
# time for epoch: 2.77
#
# epoch 35/200
# -------------------------
# Avg train loss = 80.6948, train score = 0.4612
# Avg test loss = 82.0299, test score = 0.6175
# time for epoch: 2.65
#
# epoch 36/200
# -------------------------
# Avg train loss = 78.6497, train score = 0.5060
# Avg test loss = 80.3942, test score = 0.6357
# time for epoch: 2.60
#
# epoch 37/200
# -------------------------
# Avg train loss = 76.6142, train score = 0.5286
# Avg test loss = 77.7988, test score = 0.5810
# time for epoch: 2.52
#
# epoch 38/200
# -------------------------
# Avg train loss = 75.0010, train score = 0.5000
# Avg test loss = 76.1183, test score = 0.6750
# time for epoch: 2.46
#
# epoch 39/200
# -------------------------
# Avg train loss = 73.3016, train score = 0.5181
# Avg test loss = 74.9893, test score = 0.6674
# time for epoch: 2.42
#
# epoch 40/200
# -------------------------
# Avg train loss = 71.7664, train score = 0.5173
# Avg test loss = 72.9636, test score = 0.6859
# time for epoch: 2.42
#
# epoch 41/200
# -------------------------
# Avg train loss = 70.4003, train score = 0.5040
# Avg test loss = 71.5165, test score = 0.7988
# time for epoch: 2.41
#
# epoch 42/200
# -------------------------
# Avg train loss = 69.0417, train score = 0.5070
# Avg test loss = 70.2094, test score = 0.7775
# time for epoch: 2.43
#
# epoch 43/200
# -------------------------
# Avg train loss = 67.9242, train score = 0.5247
# Avg test loss = 69.1689, test score = 0.6980
# time for epoch: 2.53
#
# epoch 44/200
# -------------------------
# Avg train loss = 66.6393, train score = 0.5272
# Avg test loss = 68.9540, test score = 0.6995
# time for epoch: 2.52
#
# epoch 45/200
# -------------------------
# Avg train loss = 65.6796, train score = 0.4982
# Avg test loss = 67.1521, test score = 0.7326
# time for epoch: 2.42
#
# epoch 46/200
# -------------------------
# Avg train loss = 64.6086, train score = 0.5205
# Avg test loss = 65.9426, test score = 0.6886
# time for epoch: 2.41
#
# epoch 47/200
# -------------------------
# Avg train loss = 63.6821, train score = 0.5517
# Avg test loss = 65.3231, test score = 0.6382
# time for epoch: 2.42
#
# epoch 48/200
# -------------------------
# Avg train loss = 62.5419, train score = 0.5070
# Avg test loss = 64.0077, test score = 0.7643
# time for epoch: 2.42
#
# epoch 49/200
# -------------------------
# Avg train loss = 61.9436, train score = 0.5390
# Avg test loss = 63.1672, test score = 0.7242
# time for epoch: 2.41
#
# epoch 50/200
# -------------------------
# Avg train loss = 61.1167, train score = 0.5465
# Avg test loss = 62.5243, test score = 0.6431
# time for epoch: 2.42
#
# epoch 51/200
# -------------------------
# Avg train loss = 60.3076, train score = 0.5066
# Avg test loss = 62.4306, test score = 0.6715
# time for epoch: 2.42
#
# epoch 52/200
# -------------------------
# Avg train loss = 59.2449, train score = 0.5107
# Avg test loss = 62.3822, test score = 0.5801
# time for epoch: 2.42
#
# epoch 53/200
# -------------------------
# Avg train loss = 58.7517, train score = 0.5352
# Avg test loss = 60.3041, test score = 0.6070
# time for epoch: 2.41
#
# epoch 54/200
# -------------------------
# Avg train loss = 58.1242, train score = 0.4930
# Avg test loss = 59.4061, test score = 0.6764
# time for epoch: 2.41
#
# epoch 55/200
# -------------------------
# Avg train loss = 57.4781, train score = 0.5179
# Avg test loss = 59.0387, test score = 0.5904
# time for epoch: 2.41
#
# epoch 56/200
# -------------------------
# Avg train loss = 56.7615, train score = 0.5151
# Avg test loss = 58.0683, test score = 0.7452
# time for epoch: 2.41
#
# epoch 57/200
# -------------------------
# Avg train loss = 56.1840, train score = 0.5413
# Avg test loss = 57.8689, test score = 0.6186
# time for epoch: 2.42
#
# epoch 58/200
# -------------------------
# Avg train loss = 55.6303, train score = 0.5163
# Avg test loss = 57.0639, test score = 0.6460
# time for epoch: 2.41
#
# epoch 59/200
# -------------------------
# Avg train loss = 55.0455, train score = 0.5474
# Avg test loss = 56.6746, test score = 0.6162
# time for epoch: 2.41
#
# epoch 60/200
# -------------------------
# Avg train loss = 54.4878, train score = 0.5272
# Avg test loss = 56.7651, test score = 0.5704
# time for epoch: 2.41
#
# epoch 61/200
# -------------------------
# Avg train loss = 53.7966, train score = 0.5284
# Avg test loss = 55.5718, test score = 0.5910
# time for epoch: 2.41
#
# epoch 62/200
# -------------------------
# Avg train loss = 53.4797, train score = 0.4771
# Avg test loss = 54.8756, test score = 0.6091
# time for epoch: 2.41
#
# epoch 63/200
# -------------------------
# Avg train loss = 53.0098, train score = 0.5223
# Avg test loss = 55.2868, test score = 0.5539
# time for epoch: 2.41
#
# epoch 64/200
# -------------------------
# Avg train loss = 52.4949, train score = 0.4778
# Avg test loss = 53.6978, test score = 0.6827
# time for epoch: 2.41
#
# epoch 65/200
# -------------------------
# Avg train loss = 52.1409, train score = 0.5255
# Avg test loss = 53.7959, test score = 0.5773
# time for epoch: 2.42
#
# epoch 66/200
# -------------------------
# Avg train loss = 51.5694, train score = 0.5164
# Avg test loss = 53.7697, test score = 0.4984
# time for epoch: 2.41
#
# epoch 67/200
# -------------------------
# Avg train loss = 51.0363, train score = 0.4921
# Avg test loss = 54.3155, test score = 0.5418
# time for epoch: 2.41
#
# epoch 68/200
# -------------------------
# Avg train loss = 50.8027, train score = 0.5252
# Avg test loss = 53.9164, test score = 0.5839
# time for epoch: 2.41
#
# epoch 69/200
# -------------------------
# Avg train loss = 50.4544, train score = 0.4831
# Avg test loss = 51.6176, test score = 0.6964
# time for epoch: 2.42
#
# epoch 70/200
# -------------------------
# Avg train loss = 49.9766, train score = 0.5202
# Avg test loss = 52.6484, test score = 0.5389
# time for epoch: 2.42
#
# epoch 71/200
# -------------------------
# Avg train loss = 49.7096, train score = 0.5095
# Avg test loss = 51.3369, test score = 0.5767
# time for epoch: 2.43
#
# epoch 72/200
# -------------------------
# Avg train loss = 49.2976, train score = 0.5025
# Avg test loss = 50.9144, test score = 0.5290
# time for epoch: 2.42
#
# epoch 73/200
# -------------------------
# Avg train loss = 48.8504, train score = 0.4982
# Avg test loss = 51.5637, test score = 0.5677
# time for epoch: 2.42
#
# epoch 74/200
# -------------------------
# Avg train loss = 48.5523, train score = 0.5010
# Avg test loss = 50.6318, test score = 0.5096
# time for epoch: 2.41
#
# epoch 75/200
# -------------------------
# Avg train loss = 48.1377, train score = 0.4989
# Avg test loss = 49.5480, test score = 0.5534
# time for epoch: 2.42
#
# epoch 76/200
# -------------------------
# Avg train loss = 47.8489, train score = 0.5059
# Avg test loss = 49.6586, test score = 0.4627
# time for epoch: 2.41
#
# epoch 77/200
# -------------------------
# Avg train loss = 47.4678, train score = 0.5343
# Avg test loss = 48.9990, test score = 0.6389
# time for epoch: 2.41
#
# epoch 78/200
# -------------------------
# Avg train loss = 47.2910, train score = 0.5469
# Avg test loss = 48.7142, test score = 0.5613
# time for epoch: 2.41
#
# epoch 79/200
# -------------------------
# Avg train loss = 46.8480, train score = 0.5175
# Avg test loss = 49.7165, test score = 0.5172
# time for epoch: 2.42
#
# epoch 80/200
# -------------------------
# Avg train loss = 46.5664, train score = 0.5337
# Avg test loss = 49.0117, test score = 0.5057
# time for epoch: 2.41
#
# epoch 81/200
# -------------------------
# Avg train loss = 46.3740, train score = 0.4994
# Avg test loss = 48.2697, test score = 0.6184
# time for epoch: 2.41
#
# epoch 82/200
# -------------------------
# Avg train loss = 46.0586, train score = 0.5089
# Avg test loss = 47.4720, test score = 0.5676
# time for epoch: 2.42
#
# epoch 83/200
# -------------------------
# Avg train loss = 45.7522, train score = 0.5401
# Avg test loss = 47.2146, test score = 0.5551
# time for epoch: 2.41
#
# epoch 84/200
# -------------------------
# Avg train loss = 45.4469, train score = 0.5336
# Avg test loss = 46.5779, test score = 0.7196
# time for epoch: 2.42
#
# epoch 85/200
# -------------------------
# Avg train loss = 45.1952, train score = 0.5225
# Avg test loss = 46.6430, test score = 0.6724
# time for epoch: 2.41
#
# epoch 86/200
# -------------------------
# Avg train loss = 44.8920, train score = 0.5231
# Avg test loss = 46.1817, test score = 0.5670
# time for epoch: 2.43
#
# epoch 87/200
# -------------------------
# Avg train loss = 44.5919, train score = 0.4970
# Avg test loss = 46.0543, test score = 0.7651
# time for epoch: 2.46
#
# epoch 88/200
# -------------------------
# Avg train loss = 44.6174, train score = 0.5504
# Avg test loss = 45.8105, test score = 0.7100
# time for epoch: 2.42
#
# epoch 89/200
# -------------------------
# Avg train loss = 44.0881, train score = 0.5022
# Avg test loss = 45.5381, test score = 0.6292
# time for epoch: 2.42
#
# epoch 90/200
# -------------------------
# Avg train loss = 43.8921, train score = 0.5348
# Avg test loss = 45.2476, test score = 0.5261
# time for epoch: 2.41
#
# epoch 91/200
# -------------------------
# Avg train loss = 43.6875, train score = 0.4966
# Avg test loss = 45.4888, test score = 0.5965
# time for epoch: 2.41
#
# epoch 92/200
# -------------------------
# Avg train loss = 43.4283, train score = 0.5101
# Avg test loss = 45.3216, test score = 0.5449
# time for epoch: 2.42
#
# epoch 93/200
# -------------------------
# Avg train loss = 43.3758, train score = 0.4847
# Avg test loss = 45.0259, test score = 0.6473
# time for epoch: 2.42
#
# epoch 94/200
# -------------------------
# Avg train loss = 43.0589, train score = 0.5102
# Avg test loss = 44.5618, test score = 0.5047
# time for epoch: 2.43
#
# epoch 95/200
# -------------------------
# Avg train loss = 42.7928, train score = 0.5236
# Avg test loss = 45.9005, test score = 0.5668
# time for epoch: 2.50
#
# epoch 96/200
# -------------------------
# Avg train loss = 42.7669, train score = 0.5304
# Avg test loss = 44.0839, test score = 0.5212
# time for epoch: 2.42
#
# epoch 97/200
# -------------------------
# Avg train loss = 42.4848, train score = 0.5235
# Avg test loss = 44.7195, test score = 0.5817
# time for epoch: 2.42
#
# epoch 98/200
# -------------------------
# Avg train loss = 42.2285, train score = 0.4854
# Avg test loss = 43.5600, test score = 0.5457
# time for epoch: 2.41
#
# epoch 99/200
# -------------------------
# Avg train loss = 42.0115, train score = 0.5092
# Avg test loss = 44.0636, test score = 0.6094
# time for epoch: 2.41
#
# epoch 100/200
# -------------------------
# Avg train loss = 41.8814, train score = 0.5129
# Avg test loss = 43.2580, test score = 0.7037
# time for epoch: 2.42
#
# epoch 101/200
# -------------------------
# Avg train loss = 41.6822, train score = 0.5066
# Avg test loss = 43.0679, test score = 0.5537
# time for epoch: 2.41
#
# epoch 102/200
# -------------------------
# Avg train loss = 41.5794, train score = 0.5232
# Avg test loss = 42.9830, test score = 0.6178
# time for epoch: 2.42
#
# epoch 103/200
# -------------------------
# Avg train loss = 41.3372, train score = 0.5123
# Avg test loss = 42.8788, test score = 0.6932
# time for epoch: 2.42
#
# epoch 104/200
# -------------------------
# Avg train loss = 41.1691, train score = 0.5032
# Avg test loss = 42.3807, test score = 0.5944
# time for epoch: 2.41
#
# epoch 105/200
# -------------------------
# Avg train loss = 40.8766, train score = 0.5009
# Avg test loss = 42.3625, test score = 0.6424
# time for epoch: 2.41
#
# epoch 106/200
# -------------------------
# Avg train loss = 40.8602, train score = 0.4976
# Avg test loss = 42.2123, test score = 0.5759
# time for epoch: 2.43
#
# epoch 107/200
# -------------------------
# Avg train loss = 40.7263, train score = 0.4804
# Avg test loss = 42.6041, test score = 0.6447
# time for epoch: 2.41
#
# epoch 108/200
# -------------------------
# Avg train loss = 40.4542, train score = 0.5123
# Avg test loss = 41.7829, test score = 0.6511
# time for epoch: 2.41
#
# epoch 109/200
# -------------------------
# Avg train loss = 40.3436, train score = 0.4893
# Avg test loss = 42.0676, test score = 0.6199
# time for epoch: 2.42
#
# epoch 110/200
# -------------------------
# Avg train loss = 40.1240, train score = 0.5344
# Avg test loss = 41.3533, test score = 0.6142
# time for epoch: 2.42
#
# epoch 111/200
# -------------------------
# Avg train loss = 40.0335, train score = 0.5247
# Avg test loss = 41.5330, test score = 0.6543
# time for epoch: 2.41
#
# epoch 112/200
# -------------------------
# Avg train loss = 39.7349, train score = 0.5089
# Avg test loss = 42.3154, test score = 0.6625
# time for epoch: 2.41
#
# epoch 113/200
# -------------------------
# Avg train loss = 39.7578, train score = 0.5077
# Avg test loss = 42.1666, test score = 0.6905
# time for epoch: 2.41
#
# epoch 114/200
# -------------------------
# Avg train loss = 39.6182, train score = 0.5220
# Avg test loss = 40.7417, test score = 0.6759
# time for epoch: 2.41
#
# epoch 115/200
# -------------------------
# Avg train loss = 39.4227, train score = 0.5228
# Avg test loss = 41.0405, test score = 0.6367
# time for epoch: 2.41
#
# epoch 116/200
# -------------------------
# Avg train loss = 39.3104, train score = 0.5112
# Avg test loss = 41.6738, test score = 0.5718
# time for epoch: 2.42
#
# epoch 117/200
# -------------------------
# Avg train loss = 39.1643, train score = 0.5232
# Avg test loss = 40.7076, test score = 0.6601
# time for epoch: 2.53
#
# epoch 118/200
# -------------------------
# Avg train loss = 38.8904, train score = 0.5171
# Avg test loss = 40.1832, test score = 0.6741
# time for epoch: 2.60
#
# epoch 119/200
# -------------------------
# Avg train loss = 38.8858, train score = 0.4865
# Avg test loss = 40.3010, test score = 0.6628
# time for epoch: 2.55
#
# epoch 120/200
# -------------------------
# Avg train loss = 38.7944, train score = 0.4991
# Avg test loss = 40.0687, test score = 0.6801
# time for epoch: 2.56
#
# epoch 121/200
# -------------------------
# Avg train loss = 38.6396, train score = 0.5476
# Avg test loss = 41.4035, test score = 0.5790
# time for epoch: 2.41
#
# epoch 122/200
# -------------------------
# Avg train loss = 38.5442, train score = 0.4982
# Avg test loss = 39.8931, test score = 0.6878
# time for epoch: 2.44
#
# epoch 123/200
# -------------------------
# Avg train loss = 38.3624, train score = 0.5287
# Avg test loss = 40.9121, test score = 0.6467
# time for epoch: 2.42
#
# epoch 124/200
# -------------------------
# Avg train loss = 38.1617, train score = 0.5057
# Avg test loss = 41.1448, test score = 0.6410
# time for epoch: 2.42
#
# epoch 125/200
# -------------------------
# Avg train loss = 38.1717, train score = 0.4722
# Avg test loss = 39.7109, test score = 0.7242
# time for epoch: 2.41
#
# epoch 126/200
# -------------------------
# Avg train loss = 38.0744, train score = 0.5156
# Avg test loss = 39.4792, test score = 0.6535
# time for epoch: 2.42
#
# epoch 127/200
# -------------------------
# Avg train loss = 37.9127, train score = 0.5299
# Avg test loss = 39.7002, test score = 0.6405
# time for epoch: 2.41
#
# epoch 128/200
# -------------------------
# Avg train loss = 37.8027, train score = 0.5016
# Avg test loss = 39.1020, test score = 0.6980
# time for epoch: 2.41
#
# epoch 129/200
# -------------------------
# Avg train loss = 37.7115, train score = 0.5546
# Avg test loss = 39.9050, test score = 0.6707
# time for epoch: 2.42
#
# epoch 130/200
# -------------------------
# Avg train loss = 37.5819, train score = 0.5079
# Avg test loss = 38.8276, test score = 0.6905
# time for epoch: 2.41
#
# epoch 131/200
# -------------------------
# Avg train loss = 37.4221, train score = 0.5134
# Avg test loss = 38.9804, test score = 0.6878
# time for epoch: 2.42
#
# epoch 132/200
# -------------------------
# Avg train loss = 37.2871, train score = 0.5342
# Avg test loss = 38.7376, test score = 0.6882
# time for epoch: 2.41
#
# epoch 133/200
# -------------------------
# Avg train loss = 37.3156, train score = 0.5450
# Avg test loss = 38.7783, test score = 0.7007
# time for epoch: 2.42
#
# epoch 134/200
# -------------------------
# Avg train loss = 37.1095, train score = 0.5229
# Avg test loss = 39.1416, test score = 0.6893
# time for epoch: 2.41
#
# epoch 135/200
# -------------------------
# Avg train loss = 37.0697, train score = 0.5418
# Avg test loss = 38.3392, test score = 0.6860
# time for epoch: 2.42
#
# epoch 136/200
# -------------------------
# Avg train loss = 37.0356, train score = 0.5183
# Avg test loss = 39.1811, test score = 0.6776
# time for epoch: 2.45
#
# epoch 137/200
# -------------------------
# Avg train loss = 36.8832, train score = 0.5181
# Avg test loss = 38.7863, test score = 0.6731
# time for epoch: 2.44
#
# epoch 138/200
# -------------------------
# Avg train loss = 36.7225, train score = 0.5229
# Avg test loss = 39.6602, test score = 0.6151
# time for epoch: 2.41
#
# epoch 139/200
# -------------------------
# Avg train loss = 36.6976, train score = 0.5186
# Avg test loss = 38.1876, test score = 0.6752
# time for epoch: 2.42
#
# epoch 140/200
# -------------------------
# Avg train loss = 36.6029, train score = 0.5119
# Avg test loss = 37.9038, test score = 0.6973
# time for epoch: 2.42
#
# epoch 141/200
# -------------------------
# Avg train loss = 36.5451, train score = 0.5351
# Avg test loss = 38.1066, test score = 0.6776
# time for epoch: 2.42
#
# epoch 142/200
# -------------------------
# Avg train loss = 36.4695, train score = 0.5046
# Avg test loss = 38.1300, test score = 0.6796
# time for epoch: 2.41
#
# epoch 143/200
# -------------------------
# Avg train loss = 36.4443, train score = 0.5305
# Avg test loss = 37.6339, test score = 0.6740
# time for epoch: 2.42
#
# epoch 144/200
# -------------------------
# Avg train loss = 36.2980, train score = 0.5244
# Avg test loss = 38.4813, test score = 0.6559
# time for epoch: 2.41
#
# epoch 145/200
# -------------------------
# Avg train loss = 36.2474, train score = 0.5342
# Avg test loss = 37.9075, test score = 0.6845
# time for epoch: 2.42
#
# epoch 146/200
# -------------------------
# Avg train loss = 36.1507, train score = 0.5334
# Avg test loss = 37.7080, test score = 0.5888
# time for epoch: 2.41
#
# epoch 147/200
# -------------------------
# Avg train loss = 36.0174, train score = 0.5067
# Avg test loss = 37.7568, test score = 0.6728
# time for epoch: 2.42
#
# epoch 148/200
# -------------------------
# Avg train loss = 36.0176, train score = 0.5257
# Avg test loss = 37.7079, test score = 0.6449
# time for epoch: 2.41
#
# epoch 149/200
# -------------------------
# Avg train loss = 35.8494, train score = 0.5044
# Avg test loss = 38.5563, test score = 0.5860
# time for epoch: 2.42
#
# epoch 150/200
# -------------------------
# Avg train loss = 35.8210, train score = 0.5019
# Avg test loss = 37.5491, test score = 0.6629
# time for epoch: 2.41
#
# epoch 151/200
# -------------------------
# Avg train loss = 35.7261, train score = 0.5380
# Avg test loss = 37.3282, test score = 0.6275
# time for epoch: 2.42
#
# epoch 152/200
# -------------------------
# Avg train loss = 35.6609, train score = 0.5367
# Avg test loss = 37.1340, test score = 0.6235
# time for epoch: 2.51
#
# epoch 153/200
# -------------------------
# Avg train loss = 35.6018, train score = 0.5193
# Avg test loss = 36.8314, test score = 0.6573
# time for epoch: 2.41
#
# epoch 154/200
# -------------------------
# Avg train loss = 35.5676, train score = 0.5334
# Avg test loss = 36.8541, test score = 0.6951
# time for epoch: 2.41
#
# epoch 155/200
# -------------------------
# Avg train loss = 35.4659, train score = 0.4939
# Avg test loss = 37.0397, test score = 0.6620
# time for epoch: 2.41
#
# epoch 156/200
# -------------------------
# Avg train loss = 35.3315, train score = 0.5043
# Avg test loss = 36.5879, test score = 0.6525
# time for epoch: 2.41
#
# epoch 157/200
# -------------------------
# Avg train loss = 35.2420, train score = 0.4815
# Avg test loss = 37.1180, test score = 0.6808
# time for epoch: 2.41
#
# epoch 158/200
# -------------------------
# Avg train loss = 35.2090, train score = 0.5163
# Avg test loss = 37.7700, test score = 0.6682
# time for epoch: 2.43
#
# epoch 159/200
# -------------------------
# Avg train loss = 35.2016, train score = 0.5407
# Avg test loss = 37.6842, test score = 0.6558
# time for epoch: 2.43
#
# epoch 160/200
# -------------------------
# Avg train loss = 35.1019, train score = 0.5156
# Avg test loss = 36.7274, test score = 0.6080
# time for epoch: 2.42
#
# epoch 161/200
# -------------------------
# Avg train loss = 35.0097, train score = 0.5342
# Avg test loss = 37.0447, test score = 0.6617
# time for epoch: 2.41
#
# epoch 162/200
# -------------------------
# Avg train loss = 34.9455, train score = 0.5104
# Avg test loss = 36.3851, test score = 0.6730
# time for epoch: 2.44
#
# epoch 163/200
# -------------------------
# Avg train loss = 34.9433, train score = 0.4699
# Avg test loss = 36.2998, test score = 0.6176
# time for epoch: 2.41
#
# epoch 164/200
# -------------------------
# Avg train loss = 34.8489, train score = 0.5394
# Avg test loss = 36.2429, test score = 0.6390
# time for epoch: 2.41
#
# epoch 165/200
# -------------------------
# Avg train loss = 34.8199, train score = 0.5299
# Avg test loss = 36.2995, test score = 0.6305
# time for epoch: 2.41
#
# epoch 166/200
# -------------------------
# Avg train loss = 34.7477, train score = 0.4961
# Avg test loss = 37.2261, test score = 0.6883
# time for epoch: 2.42
#
# epoch 167/200
# -------------------------
# Avg train loss = 34.6973, train score = 0.5667
# Avg test loss = 36.6694, test score = 0.6909
# time for epoch: 2.41
#
# epoch 168/200
# -------------------------
# Avg train loss = 34.6793, train score = 0.4652
# Avg test loss = 36.5117, test score = 0.6457
# time for epoch: 2.42
#
# epoch 169/200
# -------------------------
# Avg train loss = 34.4946, train score = 0.5590
# Avg test loss = 37.7278, test score = 0.6707
# time for epoch: 2.42
#
# epoch 170/200
# -------------------------
# Avg train loss = 34.5460, train score = 0.4923
# Avg test loss = 36.0051, test score = 0.6548
# time for epoch: 2.41
#
# epoch 171/200
# -------------------------
# Avg train loss = 34.4731, train score = 0.5111
# Avg test loss = 36.3035, test score = 0.6608
# time for epoch: 2.42
#
# epoch 172/200
# -------------------------
# Avg train loss = 34.3847, train score = 0.4934
# Avg test loss = 35.8015, test score = 0.6551
# time for epoch: 2.41
#
# epoch 173/200
# -------------------------
# Avg train loss = 34.2383, train score = 0.4928
# Avg test loss = 36.3429, test score = 0.6484
# time for epoch: 2.42
#
# epoch 174/200
# -------------------------
# Avg train loss = 34.2757, train score = 0.5157
# Avg test loss = 35.7664, test score = 0.6556
# time for epoch: 2.42
#
# epoch 175/200
# -------------------------
# Avg train loss = 34.2233, train score = 0.5073
# Avg test loss = 35.4839, test score = 0.6452
# time for epoch: 2.48
#
# epoch 176/200
# -------------------------
# Avg train loss = 34.1504, train score = 0.5194
# Avg test loss = 36.3234, test score = 0.6485
# time for epoch: 2.44
#
# epoch 177/200
# -------------------------
# Avg train loss = 34.2018, train score = 0.4808
# Avg test loss = 35.7483, test score = 0.6512
# time for epoch: 2.44
#
# epoch 178/200
# -------------------------
# Avg train loss = 34.0784, train score = 0.4787
# Avg test loss = 35.6682, test score = 0.6325
# time for epoch: 2.41
#
# epoch 179/200
# -------------------------
# Avg train loss = 34.0019, train score = 0.4989
# Avg test loss = 36.6578, test score = 0.6629
# time for epoch: 2.41
#
# epoch 180/200
# -------------------------
# Avg train loss = 34.0065, train score = 0.5175
# Avg test loss = 35.9555, test score = 0.6388
# time for epoch: 2.41
#
# epoch 181/200
# -------------------------
# Avg train loss = 33.8646, train score = 0.5111
# Avg test loss = 35.4289, test score = 0.6629
# time for epoch: 2.42
#
# epoch 182/200
# -------------------------
# Avg train loss = 33.8441, train score = 0.4907
# Avg test loss = 35.2270, test score = 0.7073
# time for epoch: 2.42
#
# epoch 183/200
# -------------------------
# Avg train loss = 33.8472, train score = 0.5054
# Avg test loss = 35.2462, test score = 0.6488
# time for epoch: 2.47
#
# epoch 184/200
# -------------------------
# Avg train loss = 33.8273, train score = 0.4839
# Avg test loss = 35.6845, test score = 0.6003
# time for epoch: 2.45
#
# epoch 185/200
# -------------------------
# Avg train loss = 33.6598, train score = 0.5042
# Avg test loss = 35.9801, test score = 0.6608
# time for epoch: 2.47
#
# epoch 186/200
# -------------------------
# Avg train loss = 33.6063, train score = 0.4998
# Avg test loss = 35.5920, test score = 0.5838
# time for epoch: 2.56
#
# epoch 187/200
# -------------------------
# Avg train loss = 33.6550, train score = 0.5526
# Avg test loss = 35.7389, test score = 0.6056
# time for epoch: 2.46
#
# epoch 188/200
# -------------------------
# Avg train loss = 33.5045, train score = 0.5040
# Avg test loss = 36.0088, test score = 0.6321
# time for epoch: 2.43
#
# epoch 189/200
# -------------------------
# Avg train loss = 33.5315, train score = 0.5089
# Avg test loss = 35.1429, test score = 0.6067
# time for epoch: 2.46
#
# epoch 190/200
# -------------------------
# Avg train loss = 33.4809, train score = 0.4973
# Avg test loss = 34.9417, test score = 0.6585
# time for epoch: 2.54
#
# epoch 191/200
# -------------------------
# Avg train loss = 33.3819, train score = 0.4882
# Avg test loss = 36.7816, test score = 0.6788
# time for epoch: 2.42
#
# epoch 192/200
# -------------------------
# Avg train loss = 33.4620, train score = 0.4995
# Avg test loss = 34.8312, test score = 0.6710
# time for epoch: 2.42
#
# epoch 193/200
# -------------------------
# Avg train loss = 33.3764, train score = 0.5108
# Avg test loss = 34.7048, test score = 0.6511
# time for epoch: 2.41
#
# epoch 194/200
# -------------------------
# Avg train loss = 33.3461, train score = 0.5151
# Avg test loss = 35.1542, test score = 0.5952
# time for epoch: 2.41
#
# epoch 195/200
# -------------------------
# Avg train loss = 33.2519, train score = 0.4882
# Avg test loss = 35.4923, test score = 0.6172
# time for epoch: 2.41
#
# epoch 196/200
# -------------------------
# Avg train loss = 33.2248, train score = 0.5029
# Avg test loss = 35.4991, test score = 0.6731
# time for epoch: 2.41
#
# epoch 197/200
# -------------------------
# Avg train loss = 33.1187, train score = 0.5044
# Avg test loss = 34.6815, test score = 0.6436
# time for epoch: 2.41
#
# epoch 198/200
# -------------------------
# Avg train loss = 33.1836, train score = 0.5260
# Avg test loss = 35.3289, test score = 0.5922
# time for epoch: 2.41
#
# epoch 199/200
# -------------------------
# Avg train loss = 33.1133, train score = 0.4931
# Avg test loss = 34.6094, test score = 0.6817
# time for epoch: 2.41
#
# epoch 200/200
# -------------------------
# Avg train loss = 33.1875, train score = 0.5327
# Avg test loss = 35.2282, test score = 0.6608
# time for epoch: 2.42

# %%
plt.plot(train_acc_adam, label='Train')
plt.plot(test_acc_adam, label='Test')
plt.axhline(y=0, color='black', linestyle='--', linewidth=0.7)
plt.xlabel('Epochs', fontsize=15)
plt.ylabel('TVD score', fontsize=15)
plt.ylim([-0.5,3])
plt.legend(fontsize=15)
plt.title('TVD score, batch size = 1', fontsize=18)
# Out:
# Text(0.5, 1.0, 'TVD score, batch size = 1')

# %%
for p in model.parameters():
    print(p)
# Out:
# Parameter containing:
# tensor([  2.8058,   2.5287,   2.0749,   2.7211,   4.4355,   4.5518,   4.6839,
#           5.6355,   2.1942,   1.4716,  15.2230,   1.0000,   2.8000,   2.5050,
#           1.8260,   3.9320,   4.3090,   4.7750,   4.5460,   2.8210,   3.8130,
#           3.0100,   0.9080,   3.0000,   4.0000,   2.2570,   0.4800,   0.5000,
#           4.8873,  10.6320,  11.3840,   4.6630,   0.2944,   0.4503,   0.1861,
#           0.7173,   0.6711,   0.3191,   1.2000,   1.5000,   0.4000,   1.8000,
#           0.8000, 142.3060,   1.0000,   0.0000,   1.5310], requires_grad=True)
# Parameter containing:
# tensor([[ 0.2866,  3.8271],
#         [ 1.8956,  2.2077],
#         [ 1.7717,  2.8078],
#         [ 1.8896,  2.6745],
#         [ 2.2063,  3.2248],
#         [ 2.4289,  3.3874],
#         [ 2.0993,  2.1261],
#         [ 2.1018,  2.3076],
#         [ 2.0390,  1.3576],
#         [ 2.1640,  1.3739],
#         [ 2.3415,  1.7447],
#         [ 0.4000, 12.0000],
#         [ 0.1000, 12.0000],
#         [ 0.1000, 12.0000],
#         [ 0.1000, 12.0000]], requires_grad=True)
# Parameter containing:
# tensor([[1.5926, 2.4166],
#         [0.9024, 2.6675],
#         [1.7866, 2.3565],
#         [0.7141, 1.5758],
#         [1.7306, 2.5724],
#         [1.6725, 2.2979],
#         [1.0567, 2.6559],
#         [0.9343, 1.4639],
#         [0.5403, 1.5970],
#         [0.3408, 1.6778],
#         [0.6817, 1.9600],
#         [1.0603, 1.9158],
#         [0.8000, 3.1416]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.6434,  0.1029],
#         [ 1.1161, -3.7262],
#         [ 0.3563, -0.2841],
#         [ 0.7083, -3.5053],
#         [ 0.5857, -2.5549],
#         [ 0.9236, -2.2915],
#         [ 0.5542, -1.9812],
#         [ 0.5166,  1.8445],
#         [ 0.1196, -2.1324],
#         [ 0.9741, -1.7427],
#         [ 0.7144,  1.6419],
#         [ 0.8692, -1.8397],
#         [ 0.7306,  1.5969],
#         [ 0.0368,  2.2801],
#         [ 0.0899,  2.5243],
#         [ 0.2105,  2.5221],
#         [ 0.1992,  2.6514],
#         [ 1.0052, -0.9894],
#         [ 0.9263,  1.5399],
#         [ 0.8754,  2.0181],
#         [ 1.4835,  2.3005],
#         [ 0.8484, -0.2253],
#         [ 0.7073,  2.6563],
#         [ 1.1974,  0.0324],
#         [ 1.1447,  0.0587]], requires_grad=True)

# %%
# try same hyperparameters, but set initial values to 1


model2 = LocalEnergyOpt(fixed_pars,opt_pars,device,set_to_one=True).to(device)
for p in model2.parameters():
    print(p)
lr = 1e-4

adam_optimizer = torch.optim.Adam(model2.parameters(), lr=lr)
my_train = KL_train
my_test = KL_test
epochs = 100

train_loss_adam2 = []
test_loss_adam2 = []
train_acc_adam2 = []
test_acc_adam2 = []

for index_epoch in range(epochs):
    print(f'epoch {index_epoch+1}/{epochs} \n-------------------------')
    t0 = time.time()
    with io.capture_output() as captured:
        train_tmp, train_acc_tmp = my_train(train_dataloader, model2, my_loss, adam_optimizer, amber_hist)
        test_tmp, test_acc_tmp = my_test(test_dataloader, model2, my_loss, amber_hist)
    tf = time.time()
    print(f'Avg train loss = {train_tmp:.4f}, train score = {train_acc_tmp:.4f}')
    print(f'Avg test loss = {test_tmp:.4f}, test score = {test_acc_tmp:.4f}' )
    print(f'time for epoch: {tf-t0:.2f} \n')
    train_loss_adam2.append(train_tmp)
    test_loss_adam2.append(test_tmp)
    train_acc_adam2.append(train_acc_tmp)
    test_acc_adam2.append(test_acc_tmp)
# Out:
# Parameter containing:
# tensor([  2.6080,   2.0730,   1.5190,   2.3550,   4.1900,   4.6980,   4.8240,
#           5.6360,   2.1300,   1.3070,  15.2230,   1.0000,   2.8000,   2.5050,
#           1.8260,   3.9320,   4.3090,   4.7750,   4.5460,   2.8210,   3.8130,
#           3.0100,   0.9080,   3.0000,   4.0000,   2.2570,   0.4800,   0.5000,
#           4.2470,  10.8160,  11.1210,   5.8190,   0.5010,   0.7300,   0.3310,
#           0.2570,   0.2240,   0.2070,   1.2000,   1.5000,   0.4000,   1.8000,
#           0.8000, 142.3060,   1.0000,   0.0000,   1.4830], requires_grad=True)
# Parameter containing:
# tensor([[ 1.0000,  3.8000],
#         [ 1.0000,  2.3440],
#         [ 1.0000,  2.6220],
#         [ 1.0000,  2.6330],
#         [ 1.0000,  3.0620],
#         [ 1.0000,  3.0040],
#         [ 1.0000,  2.4500],
#         [ 1.0000,  2.1800],
#         [ 1.0000,  1.5200],
#         [ 1.0000,  1.5930],
#         [ 1.0000,  1.4300],
#         [ 1.0000, 12.0000],
#         [ 1.0000, 12.0000],
#         [ 1.0000, 12.0000],
#         [ 1.0000, 12.0000]], requires_grad=True)
# Parameter containing:
# tensor([[1.0000, 2.1572],
#         [1.0000, 2.3126],
#         [1.0000, 2.1555],
#         [1.0000, 2.2881],
#         [1.0000, 2.0368],
#         [1.0000, 1.9408],
#         [1.0000, 2.1450],
#         [1.0000, 1.9303],
#         [1.0000, 1.7104],
#         [1.0000, 1.9199],
#         [1.0000, 2.3649],
#         [1.0000, 1.7104],
#         [1.0000, 3.1416]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.0000, -0.3491],
#         [ 1.0000, -2.7925],
#         [ 1.0000, -0.3491],
#         [ 1.0000, -2.7925],
#         [ 1.0000, -2.8798],
#         [ 1.0000, -2.8798],
#         [ 1.0000, -2.6180],
#         [ 1.0000,  2.6180],
#         [ 1.0000, -2.6180],
#         [ 1.0000, -2.6180],
#         [ 1.0000,  2.6180],
#         [ 1.0000, -2.6180],
#         [ 1.0000,  2.6180],
#         [ 1.0000,  1.7453],
#         [ 1.0000,  1.7453],
#         [ 1.0000,  1.7453],
#         [ 1.0000,  1.7453],
#         [ 1.0000,  0.3491],
#         [ 1.0000,  2.7925],
#         [ 1.0000,  1.5708],
#         [ 1.0000,  2.6180],
#         [ 1.0000,  0.0000],
#         [ 1.0000,  3.1416],
#         [ 1.0000,  0.0000],
#         [ 1.0000,  0.0000]], requires_grad=True)
# epoch 1/100
# -------------------------
# Avg train loss = 6952.2283, train score = nan
# Avg test loss = 4089.0399, test score = nan
# time for epoch: 2.45
#
# epoch 2/100
# -------------------------
# Avg train loss = 2604.0775, train score = 2.8573
# Avg test loss = 1276.3185, test score = 2.5199
# time for epoch: 2.48
#
# epoch 3/100
# -------------------------
# Avg train loss = 1060.7050, train score = 1.8184
# Avg test loss = 767.2882, test score = 1.9173
# time for epoch: 2.45
#
# epoch 4/100
# -------------------------
# Avg train loss = 728.0282, train score = 1.8478
# Avg test loss = 602.2304, test score = 1.9629
# time for epoch: 2.43
#
# epoch 5/100
# -------------------------
# Avg train loss = 564.7210, train score = 1.8940
# Avg test loss = 478.8475, test score = 1.9797
# time for epoch: 2.53
#
# epoch 6/100
# -------------------------
# Avg train loss = 447.2915, train score = 1.8561
# Avg test loss = 388.8466, test score = 1.9050
# time for epoch: 2.54
#
# epoch 7/100
# -------------------------
# Avg train loss = 361.2181, train score = 1.8049
# Avg test loss = 319.9195, test score = 1.7885
# time for epoch: 2.66
#
# epoch 8/100
# -------------------------
# Avg train loss = 300.5645, train score = 1.7046
# Avg test loss = 274.2742, test score = 1.6481
# time for epoch: 2.75
#
# epoch 9/100
# -------------------------
# Avg train loss = 256.8856, train score = 1.5812
# Avg test loss = 239.1035, test score = 1.5576
# time for epoch: 2.74
#
# epoch 10/100
# -------------------------
# Avg train loss = 225.7080, train score = 1.4515
# Avg test loss = 214.6840, test score = 1.4172
# time for epoch: 2.67
#
# epoch 11/100
# -------------------------
# Avg train loss = 202.7457, train score = 1.3506
# Avg test loss = 195.7401, test score = 1.3654
# time for epoch: 2.74
#
# epoch 12/100
# -------------------------
# Avg train loss = 185.2180, train score = 1.2483
# Avg test loss = 180.9211, test score = 1.2811
# time for epoch: 2.68
#
# epoch 13/100
# -------------------------
# Avg train loss = 171.0709, train score = 1.1317
# Avg test loss = 168.8778, test score = 1.1982
# time for epoch: 2.48
#
# epoch 14/100
# -------------------------
# Avg train loss = 159.9498, train score = 1.0452
# Avg test loss = 159.9070, test score = 1.0485
# time for epoch: 2.42
#
# epoch 15/100
# -------------------------
# Avg train loss = 150.0205, train score = 0.9013
# Avg test loss = 150.7553, test score = 1.0739
# time for epoch: 2.42
#
# epoch 16/100
# -------------------------
# Avg train loss = 141.9708, train score = 0.8597
# Avg test loss = 142.8984, test score = 0.8692
# time for epoch: 2.42
#
# epoch 17/100
# -------------------------
# Avg train loss = 134.8080, train score = 0.7495
# Avg test loss = 137.2996, test score = 0.8216
# time for epoch: 2.51
#
# epoch 18/100
# -------------------------
# Avg train loss = 128.4767, train score = 0.6659
# Avg test loss = 131.0538, test score = 0.7749
# time for epoch: 2.41
#
# epoch 19/100
# -------------------------
# Avg train loss = 122.7816, train score = 0.6262
# Avg test loss = 125.6211, test score = 0.7572
# time for epoch: 2.41
#
# epoch 20/100
# -------------------------
# Avg train loss = 117.7191, train score = 0.5658
# Avg test loss = 120.8347, test score = 0.7726
# time for epoch: 2.41
#
# epoch 21/100
# -------------------------
# Avg train loss = 113.4811, train score = 0.4978
# Avg test loss = 117.0967, test score = 0.6947
# time for epoch: 2.42
#
# epoch 22/100
# -------------------------
# Avg train loss = 109.6597, train score = 0.4439
# Avg test loss = 113.6756, test score = 0.6831
# time for epoch: 2.42
#
# epoch 23/100
# -------------------------
# Avg train loss = 105.9924, train score = 0.4518
# Avg test loss = 109.7714, test score = 0.6817
# time for epoch: 2.41
#
# epoch 24/100
# -------------------------
# Avg train loss = 103.1577, train score = 0.4568
# Avg test loss = 108.2269, test score = 0.6630
# time for epoch: 2.42
#
# epoch 25/100
# -------------------------
# Avg train loss = 100.1077, train score = 0.4037
# Avg test loss = 103.9875, test score = 0.6204
# time for epoch: 2.42
#
# epoch 26/100
# -------------------------
# Avg train loss = 97.3264, train score = 0.4029
# Avg test loss = 101.4087, test score = 0.6077
# time for epoch: 2.43
#
# epoch 27/100
# -------------------------
# Avg train loss = 95.1441, train score = 0.3826
# Avg test loss = 99.7117, test score = 0.6196
# time for epoch: 2.42
#
# epoch 28/100
# -------------------------
# Avg train loss = 92.7713, train score = 0.3887
# Avg test loss = 98.4760, test score = 0.5807
# time for epoch: 2.42
#
# epoch 29/100
# -------------------------
# Avg train loss = 90.7717, train score = 0.3924
# Avg test loss = 95.5278, test score = 0.5861
# time for epoch: 2.42
#
# epoch 30/100
# -------------------------
# Avg train loss = 88.6875, train score = 0.3852
# Avg test loss = 95.2095, test score = 0.5538
# time for epoch: 2.42
#
# epoch 31/100
# -------------------------
# Avg train loss = 86.9723, train score = 0.3744
# Avg test loss = 91.9617, test score = 0.5906
# time for epoch: 2.42
#
# epoch 32/100
# -------------------------
# Avg train loss = 85.1143, train score = 0.3752
# Avg test loss = 89.4317, test score = 0.6278
# time for epoch: 2.41
#
# epoch 33/100
# -------------------------
# Avg train loss = 83.4889, train score = 0.3844
# Avg test loss = 87.7038, test score = 0.6369
# time for epoch: 2.42
#
# epoch 34/100
# -------------------------
# Avg train loss = 81.9205, train score = 0.4051
# Avg test loss = 86.4164, test score = 0.6269
# time for epoch: 2.42
#
# epoch 35/100
# -------------------------
# Avg train loss = 80.3537, train score = 0.4109
# Avg test loss = 84.4748, test score = 0.6156
# time for epoch: 2.42
#
# epoch 36/100
# -------------------------
# Avg train loss = 79.0009, train score = 0.4078
# Avg test loss = 83.0722, test score = 0.6010
# time for epoch: 2.42
#
# epoch 37/100
# -------------------------
# Avg train loss = 77.5893, train score = 0.4511
# Avg test loss = 84.1043, test score = 0.6906
# time for epoch: 2.42
#
# epoch 38/100
# -------------------------
# Avg train loss = 76.5072, train score = 0.4060
# Avg test loss = 80.5634, test score = 0.6329
# time for epoch: 2.42
#
# epoch 39/100
# -------------------------
# Avg train loss = 75.2151, train score = 0.4277
# Avg test loss = 80.6386, test score = 0.5604
# time for epoch: 2.46
#
# epoch 40/100
# -------------------------
# Avg train loss = 74.0416, train score = 0.3849
# Avg test loss = 78.7508, test score = 0.5528
# time for epoch: 2.43
#
# epoch 41/100
# -------------------------
# Avg train loss = 72.8887, train score = 0.4030
# Avg test loss = 77.4932, test score = 0.5614
# time for epoch: 2.42
#
# epoch 42/100
# -------------------------
# Avg train loss = 71.9899, train score = 0.4187
# Avg test loss = 75.9148, test score = 0.5929
# time for epoch: 2.42
#
# epoch 43/100
# -------------------------
# Avg train loss = 70.9443, train score = 0.3862
# Avg test loss = 74.7602, test score = 0.6571
# time for epoch: 2.42
#
# epoch 44/100
# -------------------------
# Avg train loss = 69.9914, train score = 0.4358
# Avg test loss = 73.9928, test score = 0.6239
# time for epoch: 2.42
#
# epoch 45/100
# -------------------------
# Avg train loss = 69.0347, train score = 0.4466
# Avg test loss = 73.4126, test score = 0.5812
# time for epoch: 2.41
#
# epoch 46/100
# -------------------------
# Avg train loss = 68.1419, train score = 0.4306
# Avg test loss = 72.5934, test score = 0.6201
# time for epoch: 2.42
#
# epoch 47/100
# -------------------------
# Avg train loss = 67.2977, train score = 0.4291
# Avg test loss = 71.3488, test score = 0.5811
# time for epoch: 2.42
#
# epoch 48/100
# -------------------------
# Avg train loss = 66.5762, train score = 0.4075
# Avg test loss = 70.5202, test score = 0.5663
# time for epoch: 2.42
#
# epoch 49/100
# -------------------------
# Avg train loss = 65.7804, train score = 0.3995
# Avg test loss = 70.1038, test score = 0.5932
# time for epoch: 2.42
#
# epoch 50/100
# -------------------------
# Avg train loss = 65.0607, train score = 0.4408
# Avg test loss = 68.8210, test score = 0.6041
# time for epoch: 2.42
#
# epoch 51/100
# -------------------------
# Avg train loss = 64.3854, train score = 0.4357
# Avg test loss = 68.3411, test score = 0.5664
# time for epoch: 2.42
#
# epoch 52/100
# -------------------------
# Avg train loss = 63.5502, train score = 0.4053
# Avg test loss = 67.1748, test score = 0.6307
# time for epoch: 2.43
#
# epoch 53/100
# -------------------------
# Avg train loss = 62.7755, train score = 0.3953
# Avg test loss = 66.1259, test score = 0.6182
# time for epoch: 2.41
#
# epoch 54/100
# -------------------------
# Avg train loss = 62.2960, train score = 0.4301
# Avg test loss = 66.0141, test score = 0.5302
# time for epoch: 2.42
#
# epoch 55/100
# -------------------------
# Avg train loss = 61.5618, train score = 0.4359
# Avg test loss = 64.7621, test score = 0.5965
# time for epoch: 2.42
#
# epoch 56/100
# -------------------------
# Avg train loss = 60.8913, train score = 0.4498
# Avg test loss = 64.6307, test score = 0.5269
# time for epoch: 2.42
#
# epoch 57/100
# -------------------------
# Avg train loss = 60.2746, train score = 0.4199
# Avg test loss = 64.6357, test score = 0.5469
# time for epoch: 2.42
#
# epoch 58/100
# -------------------------
# Avg train loss = 59.8201, train score = 0.4317
# Avg test loss = 63.2826, test score = 0.5295
# time for epoch: 2.42
#
# epoch 59/100
# -------------------------
# Avg train loss = 59.2887, train score = 0.4567
# Avg test loss = 62.8933, test score = 0.5394
# time for epoch: 2.42
#
# epoch 60/100
# -------------------------
# Avg train loss = 58.6889, train score = 0.4135
# Avg test loss = 63.6543, test score = 0.5211
# time for epoch: 2.42
#
# epoch 61/100
# -------------------------
# Avg train loss = 58.2267, train score = 0.4045
# Avg test loss = 61.1687, test score = 0.5921
# time for epoch: 2.41
#
# epoch 62/100
# -------------------------
# Avg train loss = 57.6742, train score = 0.4239
# Avg test loss = 61.9155, test score = 0.5144
# time for epoch: 2.42
#
# epoch 63/100
# -------------------------
# Avg train loss = 57.1524, train score = 0.4153
# Avg test loss = 59.9171, test score = 0.5457
# time for epoch: 2.42
#
# epoch 64/100
# -------------------------
# Avg train loss = 56.7766, train score = 0.4278
# Avg test loss = 59.7271, test score = 0.5551
# time for epoch: 2.42
#
# epoch 65/100
# -------------------------
# Avg train loss = 56.1868, train score = 0.4349
# Avg test loss = 59.3340, test score = 0.5600
# time for epoch: 2.42
#
# epoch 66/100
# -------------------------
# Avg train loss = 55.6969, train score = 0.4307
# Avg test loss = 58.9454, test score = 0.5742
# time for epoch: 2.42
#
# epoch 67/100
# -------------------------
# Avg train loss = 55.3137, train score = 0.4684
# Avg test loss = 58.0875, test score = 0.5881
# time for epoch: 2.42
#
# epoch 68/100
# -------------------------
# Avg train loss = 54.7432, train score = 0.4282
# Avg test loss = 57.4000, test score = 0.5601
# time for epoch: 2.41
#
# epoch 69/100
# -------------------------
# Avg train loss = 54.3764, train score = 0.4484
# Avg test loss = 56.9449, test score = 0.6085
# time for epoch: 2.42
#
# epoch 70/100
# -------------------------
# Avg train loss = 54.0593, train score = 0.4470
# Avg test loss = 57.0169, test score = 0.4846
# time for epoch: 2.41
#
# epoch 71/100
# -------------------------
# Avg train loss = 53.6376, train score = 0.4501
# Avg test loss = 56.7300, test score = 0.5415
# time for epoch: 2.41
#
# epoch 72/100
# -------------------------
# Avg train loss = 53.1080, train score = 0.4632
# Avg test loss = 55.7129, test score = 0.6323
# time for epoch: 2.41
#
# epoch 73/100
# -------------------------
# Avg train loss = 52.6539, train score = 0.4364
# Avg test loss = 57.4486, test score = 0.5901
# time for epoch: 2.41
#
# epoch 74/100
# -------------------------
# Avg train loss = 52.4139, train score = 0.4526
# Avg test loss = 55.0848, test score = 0.5575
# time for epoch: 2.42
#
# epoch 75/100
# -------------------------
# Avg train loss = 52.0613, train score = 0.4595
# Avg test loss = 55.1514, test score = 0.4896
# time for epoch: 2.42
#
# epoch 76/100
# -------------------------
# Avg train loss = 51.6064, train score = 0.4806
# Avg test loss = 56.0329, test score = 0.5011
# time for epoch: 2.41
#
# epoch 77/100
# -------------------------
# Avg train loss = 51.3173, train score = 0.4423
# Avg test loss = 53.9226, test score = 0.5037
# time for epoch: 2.41
#
# epoch 78/100
# -------------------------
# Avg train loss = 50.9852, train score = 0.4705
# Avg test loss = 53.6706, test score = 0.5494
# time for epoch: 2.41
#
# epoch 79/100
# -------------------------
# Avg train loss = 50.6850, train score = 0.4804
# Avg test loss = 53.2850, test score = 0.5449
# time for epoch: 2.41
#
# epoch 80/100
# -------------------------
# Avg train loss = 50.2471, train score = 0.4602
# Avg test loss = 52.8419, test score = 0.5930
# time for epoch: 2.42
#
# epoch 81/100
# -------------------------
# Avg train loss = 49.9499, train score = 0.4635
# Avg test loss = 52.8139, test score = 0.5857
# time for epoch: 2.42
#
# epoch 82/100
# -------------------------
# Avg train loss = 49.5417, train score = 0.4649
# Avg test loss = 52.9698, test score = 0.6510
# time for epoch: 2.42
#
# epoch 83/100
# -------------------------
# Avg train loss = 49.3384, train score = 0.4742
# Avg test loss = 52.1777, test score = 0.5933
# time for epoch: 2.41
#
# epoch 84/100
# -------------------------
# Avg train loss = 49.0921, train score = 0.4634
# Avg test loss = 52.2426, test score = 0.5840
# time for epoch: 2.42
#
# epoch 85/100
# -------------------------
# Avg train loss = 48.6216, train score = 0.4657
# Avg test loss = 50.8058, test score = 0.6002
# time for epoch: 2.41
#
# epoch 86/100
# -------------------------
# Avg train loss = 48.4249, train score = 0.4668
# Avg test loss = 50.8196, test score = 0.5643
# time for epoch: 2.41
#
# epoch 87/100
# -------------------------
# Avg train loss = 48.1368, train score = 0.5004
# Avg test loss = 51.3461, test score = 0.5753
# time for epoch: 2.42
#
# epoch 88/100
# -------------------------
# Avg train loss = 47.8312, train score = 0.4856
# Avg test loss = 50.1394, test score = 0.5489
# time for epoch: 2.43
#
# epoch 89/100
# -------------------------
# Avg train loss = 47.5759, train score = 0.4777
# Avg test loss = 49.8776, test score = 0.6097
# time for epoch: 2.50
#
# epoch 90/100
# -------------------------
# Avg train loss = 47.3350, train score = 0.4708
# Avg test loss = 50.4097, test score = 0.6611
# time for epoch: 2.41
#
# epoch 91/100
# -------------------------
# Avg train loss = 47.0732, train score = 0.4899
# Avg test loss = 49.7977, test score = 0.5860
# time for epoch: 2.43
#
# epoch 92/100
# -------------------------
# Avg train loss = 46.7853, train score = 0.4682
# Avg test loss = 49.7343, test score = 0.6560
# time for epoch: 2.41
#
# epoch 93/100
# -------------------------
# Avg train loss = 46.5526, train score = 0.4939
# Avg test loss = 48.5275, test score = 0.6919
# time for epoch: 2.42
#
# epoch 94/100
# -------------------------
# Avg train loss = 46.1852, train score = 0.4725
# Avg test loss = 49.8256, test score = 0.5490
# time for epoch: 2.42
#
# epoch 95/100
# -------------------------
# Avg train loss = 46.0934, train score = 0.4797
# Avg test loss = 49.3507, test score = 0.5735
# time for epoch: 2.42
#
# epoch 96/100
# -------------------------
# Avg train loss = 45.8569, train score = 0.4988
# Avg test loss = 47.8972, test score = 0.6253
# time for epoch: 2.42
#
# epoch 97/100
# -------------------------
# Avg train loss = 45.5938, train score = 0.4731
# Avg test loss = 48.3381, test score = 0.5949
# time for epoch: 2.42
#
# epoch 98/100
# -------------------------
# Avg train loss = 45.3948, train score = 0.4965
# Avg test loss = 48.1591, test score = 0.5835
# time for epoch: 2.42
#
# epoch 99/100
# -------------------------
# Avg train loss = 45.1143, train score = 0.4822
# Avg test loss = 47.4256, test score = 0.6170
# time for epoch: 2.42
#
# epoch 100/100
# -------------------------
# Avg train loss = 44.8139, train score = 0.4959
# Avg test loss = 47.5702, test score = 0.5639
# time for epoch: 2.42

# %%
plt.plot(train_acc_adam2, label='Train')
plt.plot(test_acc_adam2, label='Test')
plt.axhline(y=0, color='black', linestyle='--', linewidth=0.7)
plt.xlabel('Epochs', fontsize=15)
plt.ylabel('TVD score', fontsize=15)
plt.ylim([-0.5,3])
plt.legend(fontsize=15)
plt.title('TVD score, batch size = 1', fontsize=18)
# Out:
# Text(0.5, 1.0, 'TVD score, batch size = 1')

# %%
for p in model2.parameters():
    print(p)

# %%
_,stats_adam_so = compare_energies(seq_data,model,plot=True)
_,stats_adam_all1 = compare_energies(seq_data,model2,plot=True)
# Out:
# Bonds energy computed
# Angles energy computed
# Torsions energy computed
# Bonds energy computed
# Angles energy computed
# Torsions energy computed

# %% [markdown]
# Starting with same parameters for Adam, but with all initial values for the coupling constants set to 1 leads to a similar score, but unfortunately one of the parameters becomes negative. Nevertheless, it is interesting to notice that, even if the value are different, some patterns can be found, especially in the relations between the coefficients.
# For example, the first bond coupling tends to go to a lower value than the others, independently of the initialization, and similar patterns are obtained also for angle parameters, especially the first ones.

# %%
pars_so = [p.data for p in model.parameters()]
pars_1 = [p.data for p in model2.parameters()]

plt.plot(pars_so[0],'o')
plt.plot(pars_1[0],'o')
plt.ylim(0,7)
plt.show()
print(pars_so[0][0])
print(pars_1[0][0])

# x and y coordinates are coupling constant and equilibrium value, respectively

plt.scatter(pars_so[1][:,0]*pars_so[0][0],pars_so[1][:,1],label='Same Order')
plt.scatter(pars_1[1][:,0]*pars_1[0][0],pars_1[1][:,1],label='All 1')
for i in range(len(pars_so[1])):
    plt.annotate(i+1, (pars_so[1][i,0]*pars_so[0][0],pars_so[1][i,1]))
    plt.annotate(i+1, (pars_1[1][i,0]*pars_1[0][0],pars_1[1][i,1]))
plt.ylim(0,4)
plt.legend()
plt.show()

plt.scatter(pars_so[2][:,0]*pars_so[0][-1],pars_so[2][:,1],label='Same Order')
plt.scatter(pars_1[2][:,0]*pars_1[0][-1],pars_1[2][:,1],label='All 1')
for i in range(len(pars_so[2])):
    plt.annotate(i+1, (pars_so[2][i,0]*pars_so[0][-1],pars_so[2][i,1]))
    plt.annotate(i+1, (pars_1[2][i,0]*pars_1[0][-1],pars_1[2][i,1]))
plt.legend()
plt.show()

plt.scatter(pars_so[3][:,0],pars_so[3][:,1],label='Same Order')
plt.scatter(pars_1[3][:,0],pars_1[3][:,1],label='All 1')
for i in range(len(pars_so[3])):
    plt.annotate(i+1, (pars_so[3][i,0],pars_so[3][i,1]))
    plt.annotate(i+1, (pars_1[3][i,0],pars_1[3][i,1]))
plt.legend()
plt.show()
# Out:
# tensor(2.8058)
# tensor(2.7516)

# %%
amber_hist = get_amber_hist(seq_data)

# %%
plt.plot(train_acc_adam, label='Train')
plt.plot(test_acc_adam, label='Test')
plt.axhline(y=0, color='black', linestyle='--', linewidth=0.7)
plt.xlabel('Epochs', fontsize=15)
plt.ylabel('TVD score', fontsize=15)
plt.ylim([-0.5,3])
plt.legend(fontsize=15)
plt.title('TVD score, batch size = 1', fontsize=18)
# Out:
# Text(0.5, 1.0, 'TVD score, batch size = 16')

# %%
for p in model.parameters():
    print(p)
# Out:
# Parameter containing:
# tensor([2.8089e+00, 2.5654e+00, 2.1013e+00, 2.6720e+00, 4.4203e+00, 4.5115e+00,
#         4.6572e+00, 5.6517e+00, 2.3490e+00, 1.4712e+00, 1.5223e+01, 1.0000e+00,
#         2.8000e+00, 2.5050e+00, 1.8260e+00, 3.9320e+00, 4.3090e+00, 4.7750e+00,
#         4.5460e+00, 2.8210e+00, 3.8130e+00, 3.0100e+00, 9.0800e-01, 3.0000e+00,
#         4.0000e+00, 2.2570e+00, 4.8000e-01, 5.0000e-01, 4.8917e+00, 1.0634e+01,
#         1.1384e+01, 4.6340e+00, 3.0536e-01, 4.7703e-01, 1.3357e-01, 7.4687e-01,
#         6.4262e-01, 3.0974e-01, 1.2000e+00, 1.5000e+00, 4.0000e-01, 1.8000e+00,
#         8.0000e-01, 1.4231e+02, 1.0000e+00, 0.0000e+00, 1.5301e+00],
#        requires_grad=True)
# Parameter containing:
# tensor([[ 0.2715,  3.8056],
#         [ 1.8882,  2.2115],
#         [ 1.7485,  2.8104],
#         [ 1.9380,  2.7021],
#         [ 2.3425,  3.2320],
#         [ 2.4506,  3.3867],
#         [ 2.1027,  2.1211],
#         [ 2.0937,  2.3140],
#         [ 2.0409,  1.3544],
#         [ 2.1658,  1.3713],
#         [ 2.3368,  1.7434],
#         [ 0.4000, 12.0000],
#         [ 0.1000, 12.0000],
#         [ 0.1000, 12.0000],
#         [ 0.1000, 12.0000]], requires_grad=True)
# Parameter containing:
# tensor([[1.7806, 2.3820],
#         [0.9079, 2.6722],
#         [1.7631, 2.3850],
#         [0.7046, 1.5772],
#         [1.7793, 1.5065],
#         [1.6528, 2.2764],
#         [1.0076, 2.6310],
#         [0.9190, 1.4708],
#         [0.5008, 1.5261],
#         [0.3142, 1.6694],
#         [0.6980, 1.9271],
#         [1.2148, 1.8717],
#         [0.8000, 3.1416]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.6554,  0.0976],
#         [ 1.1199, -3.7043],
#         [ 0.3086, -0.2787],
#         [ 0.7110, -3.5072],
#         [ 0.6368, -2.5248],
#         [ 0.9095, -2.3002],
#         [ 0.5627, -1.9733],
#         [ 0.5009,  1.8403],
#         [ 0.0835, -2.1551],
#         [ 0.9790, -1.7618],
#         [ 0.7264,  1.6458],
#         [ 0.9008, -1.8301],
#         [ 0.7266,  1.5983],
#         [ 0.0066,  2.2477],
#         [ 0.1474,  2.5641],
#         [ 0.2190,  2.5390],
#         [ 0.1314,  2.6321],
#         [ 1.0161, -0.9446],
#         [ 0.9530,  1.5810],
#         [ 0.8230,  1.9934],
#         [ 1.5132,  2.3758],
#         [ 0.7284, -0.1545],
#         [ 0.6903,  2.7689],
#         [ 1.1932,  0.0205],
#         [ 1.1348, -0.0917]], requires_grad=True)

# %%
# try same hyperparameters, but set initial values to 1


model2 = LocalEnergyOpt(fixed_pars,opt_pars,device,set_to_one=True).to(device)
for p in model2.parameters():
    print(p)
lr = 1e-4

adam_optimizer = torch.optim.Adam(model2.parameters(), lr=lr)
my_train = KL_train
my_test = KL_test
epochs = 200

train_loss_adam2 = []
test_loss_adam2 = []
train_acc_adam2 = []
test_acc_adam2 = []

for index_epoch in range(epochs):
    print(f'epoch {index_epoch+1}/{epochs} \n-------------------------')
    t0 = time.time()
    with io.capture_output() as captured:
        train_tmp, train_acc_tmp = my_train(train_dataloader, model2, my_loss, adam_optimizer, amber_hist)
        test_tmp, test_acc_tmp = my_test(test_dataloader, model2, my_loss, amber_hist)
    tf = time.time()
    print(f'Avg train loss = {train_tmp:.4f}, train score = {train_acc_tmp:.4f}')
    print(f'Avg test loss = {test_tmp:.4f}, test score = {test_acc_tmp:.4f}' )
    print(f'time for epoch: {tf-t0:.2f} \n')
    train_loss_adam2.append(train_tmp)
    test_loss_adam2.append(test_tmp)
    train_acc_adam2.append(train_acc_tmp)
    test_acc_adam2.append(test_acc_tmp)
# Out:
# Parameter containing:
# tensor([  2.6080,   2.0730,   1.5190,   2.3550,   4.1900,   4.6980,   4.8240,
#           5.6360,   2.1300,   1.3070,  15.2230,   1.0000,   2.8000,   2.5050,
#           1.8260,   3.9320,   4.3090,   4.7750,   4.5460,   2.8210,   3.8130,
#           3.0100,   0.9080,   3.0000,   4.0000,   2.2570,   0.4800,   0.5000,
#           4.2470,  10.8160,  11.1210,   5.8190,   0.5010,   0.7300,   0.3310,
#           0.2570,   0.2240,   0.2070,   1.2000,   1.5000,   0.4000,   1.8000,
#           0.8000, 142.3060,   1.0000,   0.0000,   1.4830], requires_grad=True)
# Parameter containing:
# tensor([[ 1.0000,  3.8000],
#         [ 1.0000,  2.3440],
#         [ 1.0000,  2.6220],
#         [ 1.0000,  2.6330],
#         [ 1.0000,  3.0620],
#         [ 1.0000,  3.0040],
#         [ 1.0000,  2.4500],
#         [ 1.0000,  2.1800],
#         [ 1.0000,  1.5200],
#         [ 1.0000,  1.5930],
#         [ 1.0000,  1.4300],
#         [ 1.0000, 12.0000],
#         [ 1.0000, 12.0000],
#         [ 1.0000, 12.0000],
#         [ 1.0000, 12.0000]], requires_grad=True)
# Parameter containing:
# tensor([[1.0000, 2.1572],
#         [1.0000, 2.3126],
#         [1.0000, 2.1555],
#         [1.0000, 2.2881],
#         [1.0000, 2.0368],
#         [1.0000, 1.9408],
#         [1.0000, 2.1450],
#         [1.0000, 1.9303],
#         [1.0000, 1.7104],
#         [1.0000, 1.9199],
#         [1.0000, 2.3649],
#         [1.0000, 1.7104],
#         [1.0000, 3.1416]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.0000, -0.3491],
#         [ 1.0000, -2.7925],
#         [ 1.0000, -0.3491],
#         [ 1.0000, -2.7925],
#         [ 1.0000, -2.8798],
#         [ 1.0000, -2.8798],
#         [ 1.0000, -2.6180],
#         [ 1.0000,  2.6180],
#         [ 1.0000, -2.6180],
#         [ 1.0000, -2.6180],
#         [ 1.0000,  2.6180],
#         [ 1.0000, -2.6180],
#         [ 1.0000,  2.6180],
#         [ 1.0000,  1.7453],
#         [ 1.0000,  1.7453],
#         [ 1.0000,  1.7453],
#         [ 1.0000,  1.7453],
#         [ 1.0000,  0.3491],
#         [ 1.0000,  2.7925],
#         [ 1.0000,  1.5708],
#         [ 1.0000,  2.6180],
#         [ 1.0000,  0.0000],
#         [ 1.0000,  3.1416],
#         [ 1.0000,  0.0000],
#         [ 1.0000,  0.0000]], requires_grad=True)
# epoch 1/200
# -------------------------
# Avg train loss = 6920.1435, train score = nan
# Avg test loss = 4124.1093, test score = nan
# time for epoch: 4.04
#
# epoch 2/200
# -------------------------
# Avg train loss = 2583.8083, train score = 2.8029
# Avg test loss = 1345.6298, test score = 2.2390
# time for epoch: 3.88
#
# epoch 3/200
# -------------------------
# Avg train loss = 1048.7838, train score = 1.9293
# Avg test loss = 827.8677, test score = 1.8149
# time for epoch: 3.88
#
# epoch 4/200
# -------------------------
# Avg train loss = 723.0361, train score = 1.9387
# Avg test loss = 649.2328, test score = 1.8613
# time for epoch: 3.91
#
# epoch 5/200
# -------------------------
# Avg train loss = 562.9438, train score = 1.9738
# Avg test loss = 510.7519, test score = 1.8729
# time for epoch: 3.91
#
# epoch 6/200
# -------------------------
# Avg train loss = 447.2135, train score = 1.9633
# Avg test loss = 411.1268, test score = 1.7830
# time for epoch: 3.89
#
# epoch 7/200
# -------------------------
# Avg train loss = 361.7569, train score = 1.8530
# Avg test loss = 334.5479, test score = 1.6988
# time for epoch: 3.87
#
# epoch 8/200
# -------------------------
# Avg train loss = 300.3483, train score = 1.7957
# Avg test loss = 279.3519, test score = 1.5098
# time for epoch: 3.93
#
# epoch 9/200
# -------------------------
# Avg train loss = 257.5134, train score = 1.6721
# Avg test loss = 242.3847, test score = 1.3755
# time for epoch: 3.96
#
# epoch 10/200
# -------------------------
# Avg train loss = 227.1830, train score = 1.5360
# Avg test loss = 215.9183, test score = 1.2324
# time for epoch: 3.95
#
# epoch 11/200
# -------------------------
# Avg train loss = 204.4958, train score = 1.3864
# Avg test loss = 194.3799, test score = 1.1056
# time for epoch: 3.96
#
# epoch 12/200
# -------------------------
# Avg train loss = 187.2423, train score = 1.2534
# Avg test loss = 176.8050, test score = 1.0284
# time for epoch: 4.08
#
# epoch 13/200
# -------------------------
# Avg train loss = 173.6256, train score = 1.1476
# Avg test loss = 164.4853, test score = 0.9220
# time for epoch: 4.01
#
# epoch 14/200
# -------------------------
# Avg train loss = 162.2324, train score = 1.0257
# Avg test loss = 153.6591, test score = 0.8744
# time for epoch: 4.14
#
# epoch 15/200
# -------------------------
# Avg train loss = 152.7178, train score = 0.9383
# Avg test loss = 144.3853, test score = 0.7987
# time for epoch: 4.13
#
# epoch 16/200
# -------------------------
# Avg train loss = 144.2689, train score = 0.8408
# Avg test loss = 136.3566, test score = 0.7450
# time for epoch: 4.06
#
# epoch 17/200
# -------------------------
# Avg train loss = 137.3727, train score = 0.7606
# Avg test loss = 130.7894, test score = 0.6564
# time for epoch: 3.94
#
# epoch 18/200
# -------------------------
# Avg train loss = 131.0345, train score = 0.6319
# Avg test loss = 123.7028, test score = 0.6627
# time for epoch: 3.88
#
# epoch 19/200
# -------------------------
# Avg train loss = 125.5092, train score = 0.6133
# Avg test loss = 118.7385, test score = 0.6035
# time for epoch: 3.87
#
# epoch 20/200
# -------------------------
# Avg train loss = 120.1387, train score = 0.5308
# Avg test loss = 113.6328, test score = 0.6125
# time for epoch: 3.86
#
# epoch 21/200
# -------------------------
# Avg train loss = 116.0522, train score = 0.4965
# Avg test loss = 110.0225, test score = 0.6024
# time for epoch: 3.88
#
# epoch 22/200
# -------------------------
# Avg train loss = 112.1473, train score = 0.4441
# Avg test loss = 106.3264, test score = 0.5882
# time for epoch: 3.87
#
# epoch 23/200
# -------------------------
# Avg train loss = 108.5951, train score = 0.4145
# Avg test loss = 103.5895, test score = 0.5695
# time for epoch: 3.87
#
# epoch 24/200
# -------------------------
# Avg train loss = 105.6873, train score = 0.4143
# Avg test loss = 100.4948, test score = 0.5846
# time for epoch: 3.87
#
# epoch 25/200
# -------------------------
# Avg train loss = 102.6060, train score = 0.3970
# Avg test loss = 97.2152, test score = 0.5433
# time for epoch: 3.88
#
# epoch 26/200
# -------------------------
# Avg train loss = 100.0048, train score = 0.4065
# Avg test loss = 94.4642, test score = 0.5390
# time for epoch: 3.87
#
# epoch 27/200
# -------------------------
# Avg train loss = 97.5726, train score = 0.4462
# Avg test loss = 92.3288, test score = 0.5994
# time for epoch: 3.86
#
# epoch 28/200
# -------------------------
# Avg train loss = 95.1935, train score = 0.4303
# Avg test loss = 90.1155, test score = 0.6320
# time for epoch: 3.86
#
# epoch 29/200
# -------------------------
# Avg train loss = 93.0828, train score = 0.4261
# Avg test loss = 87.8003, test score = 0.5745
# time for epoch: 3.85
#
# epoch 30/200
# -------------------------
# Avg train loss = 90.8910, train score = 0.4455
# Avg test loss = 86.2553, test score = 0.5759
# time for epoch: 3.85
#
# epoch 31/200
# -------------------------
# Avg train loss = 88.9895, train score = 0.4664
# Avg test loss = 84.6420, test score = 0.5965
# time for epoch: 3.86
#
# epoch 32/200
# -------------------------
# Avg train loss = 87.3906, train score = 0.4253
# Avg test loss = 82.5467, test score = 0.5792
# time for epoch: 3.86
#
# epoch 33/200
# -------------------------
# Avg train loss = 85.5844, train score = 0.4238
# Avg test loss = 80.5537, test score = 0.6002
# time for epoch: 3.91
#
# epoch 34/200
# -------------------------
# Avg train loss = 83.8783, train score = 0.4559
# Avg test loss = 79.2995, test score = 0.6106
# time for epoch: 3.86
#
# epoch 35/200
# -------------------------
# Avg train loss = 82.3863, train score = 0.4455
# Avg test loss = 77.5554, test score = 0.5972
# time for epoch: 3.86
#
# epoch 36/200
# -------------------------
# Avg train loss = 80.9493, train score = 0.4727
# Avg test loss = 76.2456, test score = 0.6219
# time for epoch: 3.85
#
# epoch 37/200
# -------------------------
# Avg train loss = 79.6173, train score = 0.4543
# Avg test loss = 74.9006, test score = 0.6558
# time for epoch: 3.85
#
# epoch 38/200
# -------------------------
# Avg train loss = 78.1980, train score = 0.4721
# Avg test loss = 73.7887, test score = 0.6577
# time for epoch: 3.90
#
# epoch 39/200
# -------------------------
# Avg train loss = 77.1685, train score = 0.4583
# Avg test loss = 72.6731, test score = 0.6270
# time for epoch: 3.85
#
# epoch 40/200
# -------------------------
# Avg train loss = 75.8345, train score = 0.4663
# Avg test loss = 71.6594, test score = 0.6005
# time for epoch: 3.85
#
# epoch 41/200
# -------------------------
# Avg train loss = 74.7422, train score = 0.4454
# Avg test loss = 70.5735, test score = 0.6981
# time for epoch: 3.85
#
# epoch 42/200
# -------------------------
# Avg train loss = 73.5571, train score = 0.4698
# Avg test loss = 69.8783, test score = 0.7209
# time for epoch: 3.85
#
# epoch 43/200
# -------------------------
# Avg train loss = 72.7613, train score = 0.5185
# Avg test loss = 68.4927, test score = 0.6670
# time for epoch: 3.85
#
# epoch 44/200
# -------------------------
# Avg train loss = 71.6181, train score = 0.4703
# Avg test loss = 67.3698, test score = 0.6156
# time for epoch: 3.84
#
# epoch 45/200
# -------------------------
# Avg train loss = 70.6672, train score = 0.4910
# Avg test loss = 66.5047, test score = 0.5575
# time for epoch: 3.84
#
# epoch 46/200
# -------------------------
# Avg train loss = 69.8935, train score = 0.4553
# Avg test loss = 65.7713, test score = 0.6707
# time for epoch: 3.86
#
# epoch 47/200
# -------------------------
# Avg train loss = 68.8916, train score = 0.4914
# Avg test loss = 65.1478, test score = 0.6763
# time for epoch: 3.85
#
# epoch 48/200
# -------------------------
# Avg train loss = 67.9799, train score = 0.4792
# Avg test loss = 64.2704, test score = 0.6020
# time for epoch: 3.85
#
# epoch 49/200
# -------------------------
# Avg train loss = 67.1891, train score = 0.4752
# Avg test loss = 63.4107, test score = 0.6802
# time for epoch: 3.86
#
# epoch 50/200
# -------------------------
# Avg train loss = 66.5242, train score = 0.5198
# Avg test loss = 62.6920, test score = 0.5550
# time for epoch: 3.83
#
# epoch 51/200
# -------------------------
# Avg train loss = 65.6504, train score = 0.4629
# Avg test loss = 61.9864, test score = 0.6197
# time for epoch: 3.84
#
# epoch 52/200
# -------------------------
# Avg train loss = 64.9933, train score = 0.4932
# Avg test loss = 61.2333, test score = 0.5688
# time for epoch: 3.84
#
# epoch 53/200
# -------------------------
# Avg train loss = 64.2705, train score = 0.4356
# Avg test loss = 60.9938, test score = 0.6525
# time for epoch: 3.87
#
# epoch 54/200
# -------------------------
# Avg train loss = 63.4449, train score = 0.5114
# Avg test loss = 60.0680, test score = 0.6702
# time for epoch: 3.88
#
# epoch 55/200
# -------------------------
# Avg train loss = 62.9599, train score = 0.4502
# Avg test loss = 59.4817, test score = 0.6975
# time for epoch: 3.86
#
# epoch 56/200
# -------------------------
# Avg train loss = 62.2286, train score = 0.5145
# Avg test loss = 59.0593, test score = 0.5914
# time for epoch: 3.85
#
# epoch 57/200
# -------------------------
# Avg train loss = 61.7193, train score = 0.4625
# Avg test loss = 58.2387, test score = 0.6531
# time for epoch: 3.85
#
# epoch 58/200
# -------------------------
# Avg train loss = 61.0590, train score = 0.5163
# Avg test loss = 57.7965, test score = 0.5863
# time for epoch: 3.85
#
# epoch 59/200
# -------------------------
# Avg train loss = 60.3030, train score = 0.4748
# Avg test loss = 57.0848, test score = 0.6060
# time for epoch: 3.91
#
# epoch 60/200
# -------------------------
# Avg train loss = 59.8744, train score = 0.5221
# Avg test loss = 56.5929, test score = 0.6258
# time for epoch: 3.84
#
# epoch 61/200
# -------------------------
# Avg train loss = 59.4223, train score = 0.4920
# Avg test loss = 56.0195, test score = 0.6393
# time for epoch: 3.85
#
# epoch 62/200
# -------------------------
# Avg train loss = 58.8064, train score = 0.4813
# Avg test loss = 55.5882, test score = 0.6558
# time for epoch: 3.85
#
# epoch 63/200
# -------------------------
# Avg train loss = 58.2858, train score = 0.4747
# Avg test loss = 55.6492, test score = 0.6106
# time for epoch: 3.84
#
# epoch 64/200
# -------------------------
# Avg train loss = 57.8766, train score = 0.4979
# Avg test loss = 54.9223, test score = 0.6027
# time for epoch: 3.84
#
# epoch 65/200
# -------------------------
# Avg train loss = 57.3401, train score = 0.4978
# Avg test loss = 54.3560, test score = 0.5978
# time for epoch: 3.83
#
# epoch 66/200
# -------------------------
# Avg train loss = 56.7798, train score = 0.5246
# Avg test loss = 54.2863, test score = 0.5964
# time for epoch: 3.83
#
# epoch 67/200
# -------------------------
# Avg train loss = 56.4012, train score = 0.5041
# Avg test loss = 53.3328, test score = 0.6869
# time for epoch: 3.84
#
# epoch 68/200
# -------------------------
# Avg train loss = 55.8898, train score = 0.4949
# Avg test loss = 53.0413, test score = 0.6444
# time for epoch: 3.84
#
# epoch 69/200
# -------------------------
# Avg train loss = 55.4997, train score = 0.4868
# Avg test loss = 52.8034, test score = 0.6553
# time for epoch: 3.85
#
# epoch 70/200
# -------------------------
# Avg train loss = 54.9667, train score = 0.5103
# Avg test loss = 52.1084, test score = 0.6813
# time for epoch: 3.85
#
# epoch 71/200
# -------------------------
# Avg train loss = 54.5329, train score = 0.5286
# Avg test loss = 51.7261, test score = 0.6610
# time for epoch: 3.86
#
# epoch 72/200
# -------------------------
# Avg train loss = 54.1015, train score = 0.5176
# Avg test loss = 51.3265, test score = 0.6619
# time for epoch: 3.85
#
# epoch 73/200
# -------------------------
# Avg train loss = 53.8107, train score = 0.5170
# Avg test loss = 50.9766, test score = 0.6534
# time for epoch: 3.85
#
# epoch 74/200
# -------------------------
# Avg train loss = 53.4291, train score = 0.5228
# Avg test loss = 50.8360, test score = 0.6986
# time for epoch: 3.89
#
# epoch 75/200
# -------------------------
# Avg train loss = 52.8701, train score = 0.5275
# Avg test loss = 50.3794, test score = 0.6749
# time for epoch: 3.85
#
# epoch 76/200
# -------------------------
# Avg train loss = 52.5342, train score = 0.5120
# Avg test loss = 50.0271, test score = 0.6618
# time for epoch: 3.84
#
# epoch 77/200
# -------------------------
# Avg train loss = 52.2059, train score = 0.5301
# Avg test loss = 49.6934, test score = 0.6871
# time for epoch: 3.86
#
# epoch 78/200
# -------------------------
# Avg train loss = 51.8105, train score = 0.5089
# Avg test loss = 49.2655, test score = 0.6203
# time for epoch: 3.85
#
# epoch 79/200
# -------------------------
# Avg train loss = 51.4652, train score = 0.5373
# Avg test loss = 48.9293, test score = 0.6341
# time for epoch: 3.88
#
# epoch 80/200
# -------------------------
# Avg train loss = 51.1997, train score = 0.5273
# Avg test loss = 48.7947, test score = 0.6560
# time for epoch: 3.86
#
# epoch 81/200
# -------------------------
# Avg train loss = 50.8095, train score = 0.5443
# Avg test loss = 48.4478, test score = 0.6683
# time for epoch: 3.84
#
# epoch 82/200
# -------------------------
# Avg train loss = 50.4703, train score = 0.5507
# Avg test loss = 48.6698, test score = 0.6773
# time for epoch: 3.84
#
# epoch 83/200
# -------------------------
# Avg train loss = 50.2587, train score = 0.5598
# Avg test loss = 47.8183, test score = 0.6436
# time for epoch: 3.85
#
# epoch 84/200
# -------------------------
# Avg train loss = 49.8163, train score = 0.5369
# Avg test loss = 47.7482, test score = 0.6597
# time for epoch: 3.85
#
# epoch 85/200
# -------------------------
# Avg train loss = 49.6091, train score = 0.5640
# Avg test loss = 47.3350, test score = 0.6232
# time for epoch: 3.85
#
# epoch 86/200
# -------------------------
# Avg train loss = 49.1520, train score = 0.5583
# Avg test loss = 47.2988, test score = 0.6549
# time for epoch: 3.85
#
# epoch 87/200
# -------------------------
# Avg train loss = 48.9826, train score = 0.5639
# Avg test loss = 46.6637, test score = 0.5986
# time for epoch: 3.85
#
# epoch 88/200
# -------------------------
# Avg train loss = 48.5975, train score = 0.5778
# Avg test loss = 46.8012, test score = 0.6903
# time for epoch: 3.84
#
# epoch 89/200
# -------------------------
# Avg train loss = 48.3795, train score = 0.5287
# Avg test loss = 46.5848, test score = 0.6894
# time for epoch: 3.84
#
# epoch 90/200
# -------------------------
# Avg train loss = 48.0427, train score = 0.5756
# Avg test loss = 45.9907, test score = 0.6318
# time for epoch: 3.86
#
# epoch 91/200
# -------------------------
# Avg train loss = 47.7910, train score = 0.5155
# Avg test loss = 45.8135, test score = 0.6323
# time for epoch: 3.95
#
# epoch 92/200
# -------------------------
# Avg train loss = 47.4824, train score = 0.5598
# Avg test loss = 45.4796, test score = 0.6345
# time for epoch: 4.14
#
# epoch 93/200
# -------------------------
# Avg train loss = 47.2704, train score = 0.5427
# Avg test loss = 45.1360, test score = 0.6445
# time for epoch: 4.35
#
# epoch 94/200
# -------------------------
# Avg train loss = 46.9518, train score = 0.5584
# Avg test loss = 44.9170, test score = 0.6223
# time for epoch: 4.23
#
# epoch 95/200
# -------------------------
# Avg train loss = 46.7720, train score = 0.5515
# Avg test loss = 44.8342, test score = 0.6190
# time for epoch: 4.26
#
# epoch 96/200
# -------------------------
# Avg train loss = 46.5682, train score = 0.5248
# Avg test loss = 44.4518, test score = 0.6139
# time for epoch: 4.16
#
# epoch 97/200
# -------------------------
# Avg train loss = 46.2591, train score = 0.5565
# Avg test loss = 44.6053, test score = 0.6810
# time for epoch: 3.96
#
# epoch 98/200
# -------------------------
# Avg train loss = 45.9815, train score = 0.5692
# Avg test loss = 44.3998, test score = 0.6926
# time for epoch: 3.96
#
# epoch 99/200
# -------------------------
# Avg train loss = 45.7776, train score = 0.5360
# Avg test loss = 43.8223, test score = 0.6344
# time for epoch: 4.01
#
# epoch 100/200
# -------------------------
# Avg train loss = 45.5211, train score = 0.5238
# Avg test loss = 43.7272, test score = 0.6138
# time for epoch: 4.19
#
# epoch 101/200
# -------------------------
# Avg train loss = 45.3627, train score = 0.5537
# Avg test loss = 43.5108, test score = 0.6516
# time for epoch: 4.26
#
# epoch 102/200
# -------------------------
# Avg train loss = 45.0242, train score = 0.5177
# Avg test loss = 43.3493, test score = 0.5609
# time for epoch: 3.97
#
# epoch 103/200
# -------------------------
# Avg train loss = 44.9168, train score = 0.5289
# Avg test loss = 43.0604, test score = 0.6322
# time for epoch: 4.02
#
# epoch 104/200
# -------------------------
# Avg train loss = 44.7371, train score = 0.5205
# Avg test loss = 43.1044, test score = 0.6682
# time for epoch: 4.06
#
# epoch 105/200
# -------------------------
# Avg train loss = 44.3839, train score = 0.5217
# Avg test loss = 42.6731, test score = 0.6107
# time for epoch: 4.06
#
# epoch 106/200
# -------------------------
# Avg train loss = 44.3060, train score = 0.5494
# Avg test loss = 42.4639, test score = 0.6468
# time for epoch: 3.94
#
# epoch 107/200
# -------------------------
# Avg train loss = 43.9783, train score = 0.5284
# Avg test loss = 42.5424, test score = 0.6329
# time for epoch: 4.16
#
# epoch 108/200
# -------------------------
# Avg train loss = 43.9501, train score = 0.5187
# Avg test loss = 42.3294, test score = 0.7046
# time for epoch: 3.99
#
# epoch 109/200
# -------------------------
# Avg train loss = 43.6288, train score = 0.5713
# Avg test loss = 41.9272, test score = 0.6077
# time for epoch: 4.12
#
# epoch 110/200
# -------------------------
# Avg train loss = 43.5001, train score = 0.5055
# Avg test loss = 41.8634, test score = 0.6510
# time for epoch: 4.06
#
# epoch 111/200
# -------------------------
# Avg train loss = 43.2717, train score = 0.5258
# Avg test loss = 41.8907, test score = 0.6743
# time for epoch: 4.25
#
# epoch 112/200
# -------------------------
# Avg train loss = 43.0560, train score = 0.5216
# Avg test loss = 41.4714, test score = 0.6113
# time for epoch: 4.19
#
# epoch 113/200
# -------------------------
# Avg train loss = 42.9166, train score = 0.5485
# Avg test loss = 41.2734, test score = 0.6064
# time for epoch: 4.13
#
# epoch 114/200
# -------------------------
# Avg train loss = 42.7242, train score = 0.5445
# Avg test loss = 41.1356, test score = 0.5952
# time for epoch: 4.18
#
# epoch 115/200
# -------------------------
# Avg train loss = 42.5185, train score = 0.5012
# Avg test loss = 41.2516, test score = 0.6973
# time for epoch: 3.94
#
# epoch 116/200
# -------------------------
# Avg train loss = 42.3595, train score = 0.5332
# Avg test loss = 41.1294, test score = 0.6183
# time for epoch: 4.04
#
# epoch 117/200
# -------------------------
# Avg train loss = 42.1860, train score = 0.5448
# Avg test loss = 41.4161, test score = 0.6344
# time for epoch: 4.02
#
# epoch 118/200
# -------------------------
# Avg train loss = 42.0197, train score = 0.5104
# Avg test loss = 40.6295, test score = 0.5940
# time for epoch: 4.17
#
# epoch 119/200
# -------------------------
# Avg train loss = 41.9152, train score = 0.5429
# Avg test loss = 40.4794, test score = 0.6161
# time for epoch: 4.18
#
# epoch 120/200
# -------------------------
# Avg train loss = 41.7730, train score = 0.4853
# Avg test loss = 40.4706, test score = 0.6285
# time for epoch: 4.02
#
# epoch 121/200
# -------------------------
# Avg train loss = 41.5993, train score = 0.5405
# Avg test loss = 40.1992, test score = 0.6134
# time for epoch: 3.84
#
# epoch 122/200
# -------------------------
# Avg train loss = 41.4409, train score = 0.5371
# Avg test loss = 40.3724, test score = 0.6453
# time for epoch: 3.87
#
# epoch 123/200
# -------------------------
# Avg train loss = 41.1944, train score = 0.5381
# Avg test loss = 41.6486, test score = 0.7325
# time for epoch: 3.84
#
# epoch 124/200
# -------------------------
# Avg train loss = 41.1827, train score = 0.5512
# Avg test loss = 39.7680, test score = 0.5525
# time for epoch: 3.92
#
# epoch 125/200
# -------------------------
# Avg train loss = 40.9824, train score = 0.5604
# Avg test loss = 39.7305, test score = 0.5989
# time for epoch: 3.83
#
# epoch 126/200
# -------------------------
# Avg train loss = 40.7575, train score = 0.5445
# Avg test loss = 39.7802, test score = 0.6387
# time for epoch: 3.85
#
# epoch 127/200
# -------------------------
# Avg train loss = 40.7007, train score = 0.5228
# Avg test loss = 39.4116, test score = 0.6195
# time for epoch: 3.83
#
# epoch 128/200
# -------------------------
# Avg train loss = 40.4992, train score = 0.5150
# Avg test loss = 39.4639, test score = 0.6627
# time for epoch: 3.85
#
# epoch 129/200
# -------------------------
# Avg train loss = 40.4152, train score = 0.5391
# Avg test loss = 39.4405, test score = 0.6579
# time for epoch: 3.89
#
# epoch 130/200
# -------------------------
# Avg train loss = 40.3647, train score = 0.5490
# Avg test loss = 39.2866, test score = 0.6215
# time for epoch: 3.87
#
# epoch 131/200
# -------------------------
# Avg train loss = 40.1482, train score = 0.5383
# Avg test loss = 39.0261, test score = 0.6408
# time for epoch: 3.85
#
# epoch 132/200
# -------------------------
# Avg train loss = 40.0118, train score = 0.5284
# Avg test loss = 39.5681, test score = 0.7163
# time for epoch: 3.85
#
# epoch 133/200
# -------------------------
# Avg train loss = 39.9289, train score = 0.5525
# Avg test loss = 38.8560, test score = 0.5943
# time for epoch: 3.86
#
# epoch 134/200
# -------------------------
# Avg train loss = 39.7162, train score = 0.5186
# Avg test loss = 38.7584, test score = 0.6515
# time for epoch: 3.89
#
# epoch 135/200
# -------------------------
# Avg train loss = 39.5671, train score = 0.5433
# Avg test loss = 38.5437, test score = 0.6173
# time for epoch: 3.87
#
# epoch 136/200
# -------------------------
# Avg train loss = 39.5369, train score = 0.5359
# Avg test loss = 38.6339, test score = 0.6349
# time for epoch: 3.83
#
# epoch 137/200
# -------------------------
# Avg train loss = 39.3535, train score = 0.5307
# Avg test loss = 38.3919, test score = 0.6307
# time for epoch: 3.86
#
# epoch 138/200
# -------------------------
# Avg train loss = 39.2675, train score = 0.5115
# Avg test loss = 38.4434, test score = 0.6755
# time for epoch: 3.85
#
# epoch 139/200
# -------------------------
# Avg train loss = 39.1645, train score = 0.5341
# Avg test loss = 38.3521, test score = 0.7032
# time for epoch: 3.84
#
# epoch 140/200
# -------------------------
# Avg train loss = 38.9857, train score = 0.5260
# Avg test loss = 38.0035, test score = 0.5964
# time for epoch: 3.87
#
# epoch 141/200
# -------------------------
# Avg train loss = 38.9913, train score = 0.5466
# Avg test loss = 38.0093, test score = 0.6669
# time for epoch: 3.89
#
# epoch 142/200
# -------------------------
# Avg train loss = 38.8036, train score = 0.5160
# Avg test loss = 37.8764, test score = 0.6026
# time for epoch: 3.86
#
# epoch 143/200
# -------------------------
# Avg train loss = 38.6914, train score = 0.5389
# Avg test loss = 37.7444, test score = 0.5738
# time for epoch: 3.85
#
# epoch 144/200
# -------------------------
# Avg train loss = 38.6271, train score = 0.5634
# Avg test loss = 37.6897, test score = 0.6185
# time for epoch: 3.84
#
# epoch 145/200
# -------------------------
# Avg train loss = 38.4944, train score = 0.5314
# Avg test loss = 37.8012, test score = 0.6265
# time for epoch: 3.90
#
# epoch 146/200
# -------------------------
# Avg train loss = 38.2781, train score = 0.5764
# Avg test loss = 37.9295, test score = 0.6456
# time for epoch: 3.84
#
# epoch 147/200
# -------------------------
# Avg train loss = 38.1881, train score = 0.5483
# Avg test loss = 37.4848, test score = 0.6190
# time for epoch: 3.84
#
# epoch 148/200
# -------------------------
# Avg train loss = 38.2701, train score = 0.5390
# Avg test loss = 37.5585, test score = 0.6429
# time for epoch: 3.84
#
# epoch 149/200
# -------------------------
# Avg train loss = 38.1528, train score = 0.5058
# Avg test loss = 37.3381, test score = 0.6312
# time for epoch: 3.83
#
# epoch 150/200
# -------------------------
# Avg train loss = 37.9925, train score = 0.4772
# Avg test loss = 37.5641, test score = 0.6458
# time for epoch: 3.92
#
# epoch 151/200
# -------------------------
# Avg train loss = 37.9711, train score = 0.5405
# Avg test loss = 37.2079, test score = 0.6340
# time for epoch: 3.87
#
# epoch 152/200
# -------------------------
# Avg train loss = 37.8012, train score = 0.5796
# Avg test loss = 37.1183, test score = 0.6483
# time for epoch: 3.83
#
# epoch 153/200
# -------------------------
# Avg train loss = 37.7495, train score = 0.5439
# Avg test loss = 36.9273, test score = 0.6123
# time for epoch: 3.84
#
# epoch 154/200
# -------------------------
# Avg train loss = 37.6053, train score = 0.5372
# Avg test loss = 36.9704, test score = 0.6422
# time for epoch: 3.84
#
# epoch 155/200
# -------------------------
# Avg train loss = 37.5764, train score = 0.5529
# Avg test loss = 36.9144, test score = 0.6116
# time for epoch: 3.85
#
# epoch 156/200
# -------------------------
# Avg train loss = 37.4935, train score = 0.5494
# Avg test loss = 36.8117, test score = 0.6336
# time for epoch: 3.85
#
# epoch 157/200
# -------------------------
# Avg train loss = 37.2025, train score = 0.4933
# Avg test loss = 36.7787, test score = 0.5733
# time for epoch: 3.84
#
# epoch 158/200
# -------------------------
# Avg train loss = 37.2806, train score = 0.5711
# Avg test loss = 36.8243, test score = 0.6601
# time for epoch: 3.84
#
# epoch 159/200
# -------------------------
# Avg train loss = 37.1950, train score = 0.5332
# Avg test loss = 36.6625, test score = 0.6590
# time for epoch: 3.84
#
# epoch 160/200
# -------------------------
# Avg train loss = 37.1140, train score = 0.5401
# Avg test loss = 36.4802, test score = 0.5906
# time for epoch: 3.94
#
# epoch 161/200
# -------------------------
# Avg train loss = 37.1134, train score = 0.5104
# Avg test loss = 36.4879, test score = 0.5932
# time for epoch: 3.88
#
# epoch 162/200
# -------------------------
# Avg train loss = 37.0128, train score = 0.5485
# Avg test loss = 36.4206, test score = 0.6373
# time for epoch: 3.88
#
# epoch 163/200
# -------------------------
# Avg train loss = 36.8508, train score = 0.5213
# Avg test loss = 36.2659, test score = 0.6337
# time for epoch: 3.91
#
# epoch 164/200
# -------------------------
# Avg train loss = 36.8349, train score = 0.5317
# Avg test loss = 36.6089, test score = 0.6673
# time for epoch: 4.10
#
# epoch 165/200
# -------------------------
# Avg train loss = 36.7234, train score = 0.5432
# Avg test loss = 36.2820, test score = 0.6152
# time for epoch: 4.06
#
# epoch 166/200
# -------------------------
# Avg train loss = 36.6011, train score = 0.5458
# Avg test loss = 36.1391, test score = 0.6607
# time for epoch: 4.01
#
# epoch 167/200
# -------------------------
# Avg train loss = 36.6442, train score = 0.5472
# Avg test loss = 36.1725, test score = 0.6237
# time for epoch: 4.00
#
# epoch 168/200
# -------------------------
# Avg train loss = 36.5268, train score = 0.5531
# Avg test loss = 36.2615, test score = 0.6629
# time for epoch: 3.96
#
# epoch 169/200
# -------------------------
# Avg train loss = 36.5000, train score = 0.5238
# Avg test loss = 36.1118, test score = 0.6507
# time for epoch: 3.93
#
# epoch 170/200
# -------------------------
# Avg train loss = 36.3753, train score = 0.5583
# Avg test loss = 35.9339, test score = 0.6175
# time for epoch: 3.90
#
# epoch 171/200
# -------------------------
# Avg train loss = 36.3014, train score = 0.5244
# Avg test loss = 35.7645, test score = 0.6297
# time for epoch: 4.07
#
# epoch 172/200
# -------------------------
# Avg train loss = 36.2245, train score = 0.5452
# Avg test loss = 36.0627, test score = 0.6703
# time for epoch: 3.90
#
# epoch 173/200
# -------------------------
# Avg train loss = 36.1950, train score = 0.5387
# Avg test loss = 35.7411, test score = 0.6153
# time for epoch: 3.91
#
# epoch 174/200
# -------------------------
# Avg train loss = 36.0790, train score = 0.5474
# Avg test loss = 35.9868, test score = 0.5998
# time for epoch: 3.90
#
# epoch 175/200
# -------------------------
# Avg train loss = 35.9215, train score = 0.5116
# Avg test loss = 35.7630, test score = 0.6444
# time for epoch: 3.93
#
# epoch 176/200
# -------------------------
# Avg train loss = 35.9174, train score = 0.5580
# Avg test loss = 35.8583, test score = 0.6264
# time for epoch: 3.90
#
# epoch 177/200
# -------------------------
# Avg train loss = 35.8043, train score = 0.5581
# Avg test loss = 35.5030, test score = 0.6186
# time for epoch: 3.90
#
# epoch 178/200
# -------------------------
# Avg train loss = 35.8418, train score = 0.5215
# Avg test loss = 35.8760, test score = 0.6837
# time for epoch: 4.10
#
# epoch 179/200
# -------------------------
# Avg train loss = 35.7453, train score = 0.5822
# Avg test loss = 35.3960, test score = 0.6053
# time for epoch: 3.93
#
# epoch 180/200
# -------------------------
# Avg train loss = 35.6954, train score = 0.5319
# Avg test loss = 35.3493, test score = 0.5969
# time for epoch: 3.91
#
# epoch 181/200
# -------------------------
# Avg train loss = 35.6619, train score = 0.5236
# Avg test loss = 35.3201, test score = 0.6068
# time for epoch: 4.12
#
# epoch 182/200
# -------------------------
# Avg train loss = 35.6013, train score = 0.5313
# Avg test loss = 35.4270, test score = 0.6373
# time for epoch: 4.20
#
# epoch 183/200
# -------------------------
# Avg train loss = 35.5185, train score = 0.5415
# Avg test loss = 35.2768, test score = 0.6403
# time for epoch: 4.13
#
# epoch 184/200
# -------------------------
# Avg train loss = 35.5019, train score = 0.5382
# Avg test loss = 35.1454, test score = 0.5934
# time for epoch: 4.23
#
# epoch 185/200
# -------------------------
# Avg train loss = 35.4404, train score = 0.5214
# Avg test loss = 35.3716, test score = 0.6335
# time for epoch: 4.03
#
# epoch 186/200
# -------------------------
# Avg train loss = 35.3251, train score = 0.5516
# Avg test loss = 35.0272, test score = 0.6136
# time for epoch: 3.96
#
# epoch 187/200
# -------------------------
# Avg train loss = 35.3145, train score = 0.4933
# Avg test loss = 34.9934, test score = 0.5917
# time for epoch: 4.09
#
# epoch 188/200
# -------------------------
# Avg train loss = 35.2436, train score = 0.5345
# Avg test loss = 35.0416, test score = 0.6215
# time for epoch: 4.09
#
# epoch 189/200
# -------------------------
# Avg train loss = 35.0831, train score = 0.5131
# Avg test loss = 35.2106, test score = 0.6470
# time for epoch: 3.99
#
# epoch 190/200
# -------------------------
# Avg train loss = 35.1505, train score = 0.5574
# Avg test loss = 35.0266, test score = 0.6114
# time for epoch: 4.04
#
# epoch 191/200
# -------------------------
# Avg train loss = 35.0972, train score = 0.5288
# Avg test loss = 35.0180, test score = 0.6805
# time for epoch: 3.97
#
# epoch 192/200
# -------------------------
# Avg train loss = 35.0269, train score = 0.5413
# Avg test loss = 34.8259, test score = 0.6470
# time for epoch: 4.00
#
# epoch 193/200
# -------------------------
# Avg train loss = 34.9325, train score = 0.5575
# Avg test loss = 35.0055, test score = 0.6532
# time for epoch: 3.94
#
# epoch 194/200
# -------------------------
# Avg train loss = 34.9170, train score = 0.5314
# Avg test loss = 34.6959, test score = 0.6347
# time for epoch: 3.88
#
# epoch 195/200
# -------------------------
# Avg train loss = 34.8817, train score = 0.5306
# Avg test loss = 34.6750, test score = 0.6407
# time for epoch: 3.88
#
# epoch 196/200
# -------------------------
# Avg train loss = 34.7938, train score = 0.5252
# Avg test loss = 34.8366, test score = 0.5680
# time for epoch: 3.91
#
# epoch 197/200
# -------------------------
# Avg train loss = 34.7855, train score = 0.5064
# Avg test loss = 34.7511, test score = 0.6044
# time for epoch: 3.92
#
# epoch 198/200
# -------------------------
# Avg train loss = 34.7302, train score = 0.5123
# Avg test loss = 34.6574, test score = 0.6604
# time for epoch: 3.95
#
# epoch 199/200
# -------------------------
# Avg train loss = 34.5996, train score = 0.5528
# Avg test loss = 34.7758, test score = 0.6171
# time for epoch: 3.95
#
# epoch 200/200
# -------------------------
# Avg train loss = 34.5186, train score = 0.4976
# Avg test loss = 34.6808, test score = 0.5979
# time for epoch: 3.94

# %%
plt.plot(train_acc_adam2, label='Train')
plt.plot(test_acc_adam2, label='Test')
plt.axhline(y=0, color='black', linestyle='--', linewidth=0.7)
plt.xlabel('Epochs', fontsize=15)
plt.ylabel('TVD score', fontsize=15)
plt.ylim([-0.5,3])
plt.legend(fontsize=15)
plt.title('TVD score, batch size = 1', fontsize=18)
# Out:
# Text(0.5, 1.0, 'TVD score, batch size = 1')

# %%
for p in model2.parameters():
    print(p)
# Out:
# Parameter containing:
# tensor([  2.7725,   2.4755,   2.0773,   2.6489,   4.3508,   4.3175,   4.2973,
#           5.5131,   2.2504,   1.2996,  15.2230,   1.0000,   2.8000,   2.5050,
#           1.8260,   3.9320,   4.3090,   4.7750,   4.5460,   2.8210,   3.8130,
#           3.0100,   0.9080,   3.0000,   4.0000,   2.2570,   0.4800,   0.5000,
#           4.5933,  10.4980,  11.0516,   4.5752,   0.4295,   0.5033,   0.2130,
#           0.7925,   0.5193,   0.3488,   1.2000,   1.5000,   0.4000,   1.8000,
#           0.8000, 142.3060,   1.0000,   0.0000,   1.3863], requires_grad=True)
# Parameter containing:
# tensor([[ 0.3851,  3.7481],
#         [ 1.1680,  2.1015],
#         [ 0.7543,  2.4554],
#         [ 1.2114,  2.7926],
#         [ 1.3246,  3.2944],
#         [ 1.5620,  3.4879],
#         [ 1.2872,  2.0055],
#         [ 1.0691,  2.3071],
#         [ 1.1666,  1.2750],
#         [ 1.2318,  1.3186],
#         [ 1.4209,  1.8038],
#         [ 1.0000, 12.0000],
#         [ 1.0000, 12.0000],
#         [ 1.0000, 12.0000],
#         [ 1.0000, 12.0000]], requires_grad=True)
# Parameter containing:
# tensor([[1.8137, 2.4456],
#         [1.1448, 2.6359],
#         [1.9191, 2.3959],
#         [0.8960, 1.6233],
#         [1.5326, 2.6062],
#         [1.4657, 2.2986],
#         [1.2891, 2.6215],
#         [1.1544, 1.5021],
#         [0.6113, 1.5807],
#         [0.4594, 1.6736],
#         [0.8686, 1.9630],
#         [1.1162, 1.9871],
#         [1.0000, 3.1416]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.9990,  0.0441],
#         [ 1.4494, -3.4646],
#         [ 0.7260, -0.1295],
#         [ 1.2041, -3.2829],
#         [ 0.5410, -2.5303],
#         [ 0.8059, -2.3958],
#         [ 0.5765, -1.9196],
#         [ 0.5376,  2.2228],
#         [ 0.1451, -2.1174],
#         [ 1.2310, -1.6710],
#         [ 0.9532,  1.9372],
#         [ 1.1074, -1.7380],
#         [ 0.9585,  1.8685],
#         [-0.1246,  1.9798],
#         [ 0.1051,  2.4801],
#         [ 0.1976,  2.5562],
#         [ 0.1350,  2.6285],
#         [ 0.9326, -0.8714],
#         [ 0.7749,  1.6688],
#         [ 0.8921,  1.4106],
#         [ 1.5481,  2.4098],
#         [ 1.0265, -0.2412],
#         [ 1.2514,  2.7529],
#         [ 1.4485,  0.0840],
#         [ 1.1577, -0.1257]], requires_grad=True)

# %% [markdown]
# Starting with same parameters for Adam, but with all initial values for the coupling constants set to 1 leads to a similar score, but unfortunately one of the parameters becomes negative. Nevertheless, it is interesting to notice that, even if the value are different, some patterns can be found, especially in the relations between the coefficients.
# For example, the first bond coupling tends to go to a lower value than the others, independently of the initialization, and similar patterns are obtained also for angle parameters, especially the first ones.
